# %%
from google.colab import drive
import pandas as pd
from sklearn.preprocessing import StandardScaler
from scipy import stats
import numpy as np
import logging
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from datetime import datetime
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime
import matplotlib.dates as mdates
import os

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Set the base path to the desired directory on Google Drive
base_path = '/content/drive/MyDrive/Study_1_Data/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read_csv(file_path):
    data = pd.read_csv(file_path)
    return data

# %%
def process_data(data, columns_to_remove):
    processed_data = data.drop(columns=columns_to_remove).values
    return processed_data

# %%
def construct_3d_array(base_dir, participants, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye):
    """
    Construct 3D array from CSV files.
    """
    num_rows = 180  # Define number of rows to keep (last 180 rows)
    arrays_3d = []

    for participant in participants:
        participant_id = f"{int(participant):02d}"  # Format participant number to two digits

        valid_simulations = []

        for simulation in simulations:
            hr_file_path = os.path.join(base_dir, participant_id, simulation, f'HR{simulation.capitalize()}.csv')
            gsr_file_path = os.path.join(base_dir, participant_id, simulation, f'EDA{simulation.capitalize()}_downsampled.csv')
            head_file_path = os.path.join(base_dir, participant_id, simulation, 'head_tracking_downsampled.csv')
            eye_file_path = os.path.join(base_dir, participant_id, simulation, 'eye_tracking_downsampled.csv')

            # Check if all files exist
            if all(os.path.exists(file) for file in [hr_file_path, gsr_file_path, head_file_path, eye_file_path]):
                valid_simulations.append(simulation)

        num_valid_simulations = len(valid_simulations)
        if num_valid_simulations == 0:
            continue  # Skip this participant if no valid simulations are found

        array_3d = np.zeros((num_valid_simulations, num_rows, 47)) # hr=1, gsr=1, head=15-3, eye=41-8 total columns after removing columns= 48

        for s_idx, simulation in enumerate(valid_simulations):
            # Process hr data
            hr_file_path = os.path.join(base_dir, participant_id, simulation, f'HR{simulation.capitalize()}.csv')
            hr_data = read_csv(hr_file_path)
            processed_hr_data = process_data(hr_data, columns_to_remove_hr)
            processed_hr_data = processed_hr_data[-num_rows:]  # Keep only the last 180 rows

            # Process gsr data
            gsr_file_path = os.path.join(base_dir, participant_id, simulation, f'EDA{simulation.capitalize()}_downsampled.csv')
            gsr_data = read_csv(gsr_file_path)
            processed_gsr_data = process_data(gsr_data, columns_to_remove_gsr)
            processed_gsr_data = processed_gsr_data[-num_rows:]  # Keep only the last 180 rows

            # Process head data
            head_file_path = os.path.join(base_dir, participant_id, simulation, 'head_tracking_downsampled.csv')
            head_data = read_csv(head_file_path)
            processed_head_data = process_data(head_data, columns_to_remove_head)
            processed_head_data = processed_head_data[-num_rows:]  # Keep only the last 180 rows

            # Process eye data
            eye_file_path = os.path.join(base_dir, participant_id, simulation, 'eye_tracking_downsampled.csv')
            eye_data = read_csv(eye_file_path)
            processed_eye_data = process_data(eye_data, columns_to_remove_eye)
            processed_eye_data = processed_eye_data[-num_rows:]  # Keep only the last 180 rows

            # Combine processed data
            combined_data = np.concatenate((processed_hr_data, processed_gsr_data, processed_head_data, processed_eye_data), axis=1)

            array_3d[s_idx, :, :] = combined_data

        arrays_3d.append(array_3d)

    return arrays_3d

# %%
sample_size=60
simulations = ['flat','noise','bumps']
participants = [str(i) for i in range(1, 27)]  # Participants 101 to 127
columns_to_remove_hr = []
columns_to_remove_gsr = []
columns_to_remove_eye = ['#Frame','Time', 'Unnamed: 40','ConvergenceValid','Left_Eye_Closed','Right_Eye_Closed','LocalGazeValid','WorldGazeValid']
columns_to_remove_head = ['#Frame','Time', 'Unnamed: 14']

# %%
def calculate_total_ssq(csv_file):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    n_columns = [0, 5, 6, 7, 8, 14, 15]
    o_columns = [0, 1, 2, 3, 4, 8, 10]
    d_columns = [4, 7, 9, 10, 11, 12, 13]

    # Calculate sum for each specified set of columns
    n_val = df.iloc[0, n_columns].sum()
    o_val = df.iloc[0, o_columns].sum()
    d_val = df.iloc[0, d_columns].sum()

    return n_val, o_val, d_val

# %%
def merge_ssq_column(conditions,participants):
  directories = []
  total_ssq_values = []
  for participant in participants:
      participant = f"{int(participant):02d}"
      for condition in conditions:
          directory = os.path.join(base_path, participant, condition)
          directories.append(directory)

  # Loop through each directory
  for directory in directories:
      # Check if the directory exists
      if not os.path.exists(directory):
          continue

      # Get all CSV files in the directory that are named 'ssq.csv'
      csv_files = [file for file in os.listdir(directory) if file == 'ssq.csv']

      # Loop through each CSV file
      for csv_file in csv_files:
          csv_path = os.path.join(directory, csv_file)
          df = pd.read_csv(csv_path)
          n_val,o_val,d_val = calculate_total_ssq(csv_path)
          total_ssq_values.append([n_val, o_val, d_val])
          #ssq_values_participant = df.iloc[:, 0:17].values.flatten()   # Assuming SSQ values are in columns 1 to 16
          #total_ssq_values.append(ssq_values_participant)
  ssq_array = np.array(total_ssq_values)
  return ssq_array

def merge_total_ssq(conditions,participants):
  directories = []
  total_ssq_values = []
  for participant in participants:
      participant = f"{int(participant):02d}"
      for condition in conditions:
          directory = os.path.join(base_path, participant, condition)
          directories.append(directory)

  # Loop through each directory
  for directory in directories:
      # Check if the directory exists
      if not os.path.exists(directory):
          continue

      # Get all CSV files in the directory that are named 'ssq.csv'
      csv_files = [file for file in os.listdir(directory) if file == 'ssq.csv']

      # Loop through each CSV file
      for csv_file in csv_files:
          csv_path = os.path.join(directory, csv_file)
          n_val,o_val,d_val = calculate_total_ssq(csv_path)
          total_ssq = (n_val+o_val+d_val) * 3.74
          df = pd.read_csv(csv_path)
          df["total-ssq"] = total_ssq
          #print("csv_path: ",csv_path,"   ",total_ssq)
          total_ssq_values.append(total_ssq)
  # Create a DataFrame from the list of total SSQ values
  df_total_ssq = pd.DataFrame(total_ssq_values, columns=["total-ssq"])
  # Convert the list of total SSQ values to a NumPy array
  total_ssq_array = np.array(total_ssq_values)
  return total_ssq_array

# %%
participants_group_1 = [1,3,4,11,25]
participants_group_2 = [2,7,8,9,17]
participants_group_3 = [10,12,13,22,23]
participants_group_4 = [5,14,18,20,21]
participants_group_5 = [6,15,16,19,24,26]

arrays_group_1 = construct_3d_array(base_path, participants_group_1, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_2 = construct_3d_array(base_path, participants_group_2, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_3 = construct_3d_array(base_path, participants_group_3, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_4 = construct_3d_array(base_path, participants_group_4, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_5 = construct_3d_array(base_path, participants_group_5, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)

# %%
# Concatenate arrays along the first axis
input_group_1 = np.concatenate(arrays_group_1, axis=0)
input_group_2 = np.concatenate(arrays_group_2, axis=0)
input_group_3 = np.concatenate(arrays_group_3, axis=0)
input_group_4 = np.concatenate(arrays_group_4, axis=0)
input_group_5 = np.concatenate(arrays_group_5, axis=0)

# %%
output_group_1=merge_ssq_column(simulations,participants_group_1)
output_group_2=merge_ssq_column(simulations,participants_group_2)
output_group_3=merge_ssq_column(simulations,participants_group_3)
output_group_4=merge_ssq_column(simulations,participants_group_4)
output_group_5=merge_ssq_column(simulations,participants_group_5)

output_group_1 = np.squeeze(output_group_1)
output_group_2 = np.squeeze(output_group_2)
output_group_3 = np.squeeze(output_group_3)
output_group_4 = np.squeeze(output_group_4)
output_group_5 = np.squeeze(output_group_5)


output_total_ssq_group_1=merge_total_ssq(simulations,participants_group_1)
output_total_ssq_group_2=merge_total_ssq(simulations,participants_group_2)
output_total_ssq_group_3=merge_total_ssq(simulations,participants_group_3)
output_total_ssq_group_4=merge_total_ssq(simulations,participants_group_4)
output_total_ssq_group_5=merge_total_ssq(simulations,participants_group_5)

output_total_ssq_group_1=output_total_ssq_group_1.reshape(-1, 1)
output_total_ssq_group_2=output_total_ssq_group_2.reshape(-1, 1)
output_total_ssq_group_3=output_total_ssq_group_3.reshape(-1, 1)
output_total_ssq_group_4=output_total_ssq_group_4.reshape(-1, 1)
output_total_ssq_group_5=output_total_ssq_group_5.reshape(-1, 1)

# %%
def scale_input_data(input_train, input_test):
    # Get the shape of the input data
    num_samples_train, time_steps_train, num_features = input_train.shape
    num_samples_test, time_steps_test, _ = input_test.shape

    # Reshape the input data into 2D arrays
    flattened_train_data = input_train.reshape(-1, num_features)
    flattened_test_data = input_test.reshape(-1, num_features)

    # Initialize a MinMaxScaler object
    scaler = MinMaxScaler()

    # Fit the scaler on the training data and transform both train and test data
    scaled_train_data = scaler.fit_transform(flattened_train_data)
    scaled_test_data = scaler.transform(flattened_test_data)

    # Reshape the scaled data back to its original shape
    scaled_train_data = scaled_train_data.reshape(num_samples_train, time_steps_train, num_features)
    scaled_test_data = scaled_test_data.reshape(num_samples_test, time_steps_test, num_features)

    return scaled_train_data, scaled_test_data

def scale_target_var(target_data):
    min_val, max_val = np.min(target_data, axis=0), np.max(target_data, axis=0)
    target_data = (target_data-min_val)/(max_val-min_val)

    return target_data, min_val, max_val

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, GRU, Dense, Dropout
from keras.models import Model
import numpy as np
import sklearn

def soft_parameter_sharing_regularizer(model, alpha=0.01):
    GRU_layers = [layer for layer in model.layers if isinstance(layer, GRU)]
    if not GRU_layers:
        return 0.0

    weights = [tf.convert_to_tensor(layer.weights[0]) for layer in GRU_layers]

    shared_weights = tf.reduce_mean(tf.stack(weights), axis=0)
    return alpha * tf.reduce_sum([tf.reduce_sum(tf.square(w - shared_weights)) for w in weights])

def get_individual_GRU(input_shape1, input_shape2):
    input_layer = Input(shape=(input_shape1, input_shape2))

    GRU_layers = []
    for _ in range(3):
        x = GRU(64, return_sequences=False)(input_layer)
        x = Dense(256, activation='relu')(x)
        x = Dropout(0.2)(x)
        GRU_layers.append(x)

    return GRU_layers, input_layer

def get_output_model(GRU_outputs, output_shape):
    output_models = []
    for i in range(output_shape[1]):
        output_model = Sequential()
        output_model.add(Dense(256, activation='relu'))
        output_model.add(Dropout(0.2))
        output_model.add(Dense(1))
        output_model_output = output_model(GRU_outputs[i])
        output_models.append(output_model_output)
    return output_models

rmse_n=[]
rmse_o=[]
rmse_d=[]
for iteration in range(5):



  # Assuming input_groups and output_groups are lists of arrays for the 5 groups
    input_groups = [input_group_1, input_group_2, input_group_3, input_group_4, input_group_5]
    output_groups = [output_group_1, output_group_2, output_group_3, output_group_4, output_group_5]
    ssq_groups = [output_total_ssq_group_1, output_total_ssq_group_2, output_total_ssq_group_3, output_total_ssq_group_4, output_total_ssq_group_5]

    # Initialize lists for storing training, validation, and test sets
    X_train, X_val, X_test = [], [], []
    y_train, y_val, y_test = [], [], []
    ssq_train, ssq_val, ssq_test = [], [], []

    # Loop over each group
    for input_group, output_group, ssq_group in zip(input_groups, output_groups, ssq_groups):
        # Step 1: Split the group into a training/validation set (80%) and a test set (20%)
        X_temp, X_test_temp, y_temp, y_test_temp, ssq_temp, ssq_test_temp = train_test_split(
            input_group, output_group, ssq_group, test_size=0.2)

        # Step 2: Split the training/validation set into a training set (60%) and a validation set (20%)
        X_train_temp, X_val_temp, y_train_temp, y_val_temp, ssq_train_temp, ssq_val_temp = train_test_split(
            X_temp, y_temp, ssq_temp, test_size=0.25)  # 0.25 * 0.8 = 0.2

        # Step 3: Append the results to the corresponding lists
        X_train.append(X_train_temp)
        X_val.append(X_val_temp)
        X_test.append(X_test_temp)

        y_train.append(y_train_temp)
        y_val.append(y_val_temp)
        y_test.append(y_test_temp)

        ssq_train.append(ssq_train_temp)
        ssq_val.append(ssq_val_temp)
        ssq_test.append(ssq_test_temp)

    # After the loop, concatenate the data for all groups if needed
    input_train = np.concatenate(X_train, axis=0)
    input_val = np.concatenate(X_val, axis=0)
    input_test = np.concatenate(X_test, axis=0)

    output_train = np.concatenate(y_train, axis=0)
    output_val = np.concatenate(y_val, axis=0)
    output_test = np.concatenate(y_test, axis=0)

    output_test_total_ssq = np.concatenate(ssq_test, axis=0)
    # input_train, input_test= scale_input_data(input_train[:, (60-sample_size):(180-sample_size), :], input_test[:, (60-sample_size):(180-sample_size), :])
    # output_train, min_val, max_val = scale_target_var(output_train)


    #  this section for scaling both train and validation set simultaniously
      # Step 1: Combine the training and validation sets
    combined_input = np.concatenate([input_train, input_val], axis=0)
    combined_output = np.concatenate([output_train, output_val], axis=0)

    # Step 2: Scale the combined input data
    # Assuming scale_input_data scales the data based on the combined dataset
    combined_input, input_test = scale_input_data(
        combined_input[:, (60-sample_size):(180-sample_size), :],
        input_test[:, (180-sample_size):(180), :]
    )

    # Step 3: Scale the combined output data
    # Assuming scale_target_var scales the data and returns min_val, max_val
    combined_output, min_val, max_val = scale_target_var(combined_output)

    # Step 4: Split the combined data back into training and validation sets
    # Use the original shapes of input_train and input_val to slice the combined arrays
    input_train = combined_input[:input_train.shape[0], :, :]
    input_val = combined_input[input_train.shape[0]:, :, :]

    output_train = combined_output[:output_train.shape[0], :]
    output_val = combined_output[output_train.shape[0]:, :]



    print("input_train :", input_train.shape)
    print("output_train :", output_train.shape)
    print("input_val :", input_val.shape)
    print("output_val :", output_val.shape)
    print("input_test :", input_test.shape)
    print("output_test :", output_test.shape)



    # Reshape inputs
    train_input_reshaped = input_train.reshape((input_train.shape[0], input_train.shape[1], input_train.shape[2]))
    test_input_reshaped = input_test.reshape((input_test.shape[0], input_test.shape[1], input_test.shape[2]))
    val_input_reshaped = input_val.reshape((input_val.shape[0], input_val.shape[1], input_val.shape[2]))

    # Get individual GRU outputs
    GRU_outputs, input_layer = get_individual_GRU(input_train.shape[1], input_train.shape[2])

    # Create separate output models for each column
    output_models = get_output_model(GRU_outputs, output_train.shape)

    # Create combined model
    model = Model(inputs=input_layer, outputs=output_models)

    # Custom loss function
    def custom_loss(y_true, y_pred):
        mse = tf.keras.losses.mse(y_true, y_pred)
        reg_loss = soft_parameter_sharing_regularizer(model)
        return mse + reg_loss

    # Compile and train the model
    model.compile(loss=custom_loss, optimizer='adam', metrics=[['mse'] for _ in range(output_train.shape[1])])

    best_val = 1000000
    patience = 0
    best_model = None

    for k in range(200):
        model.fit(train_input_reshaped, [output_train[:, i] for i in range(output_train.shape[1])], epochs=1, batch_size=32)
        pred_val = np.array(model.predict(val_input_reshaped))
        pred_val = np.transpose(pred_val.squeeze(), (1, 0))
        print("k:", k, "patience:", patience)

        losses = []
        for i in range(pred_val.shape[0]):
            total_ssq = 0
            for j in range(3):
                total_ssq = np.sum(pred_val[i,j]*(max_val[j]-min_val[j]) + min_val[j])+total_ssq
            total_ssq = total_ssq*3.74
            output_val_ssq = output_val[i,0]
            loss = sklearn.metrics.mean_squared_error([total_ssq], [output_val_ssq], squared=False)
            losses.append(loss)
        tmp_val_loss = np.mean(losses)
        if tmp_val_loss <= best_val:
            best_val = tmp_val_loss
            patience = 0
            best_model = model
        else:
            patience += 1
            if patience > 10:
                break

    # Predict test data
    pred_test = np.array(best_model.predict(test_input_reshaped))
    pred_test = np.transpose(pred_test.squeeze(), (1, 0))
    pred_test_n = np.zeros((pred_test.shape[0], 1))
    pred_test_o = np.zeros((pred_test.shape[0], 1))
    pred_test_d = np.zeros((pred_test.shape[0], 1))
    pred_test_final = np.empty((output_test.shape[0], 0))
    for m in range(pred_test.shape[0]):
      pred_test_n[m,0] = pred_test[m,0]*(max_val[0]-min_val[0]) + min_val[0]
      pred_test_o[m,0] = pred_test[m,1]*(max_val[1]-min_val[1]) + min_val[1]
      pred_test_d[m,0] = pred_test[m,2]*(max_val[2]-min_val[2]) + min_val[2]

    pred_test_final=np.hstack((pred_test_final, pred_test_n))
    pred_test_final=np.hstack((pred_test_final, pred_test_o))
    pred_test_final=np.hstack((pred_test_final, pred_test_d))

    # Overall Test Loss
    loss_n = sklearn.metrics.mean_squared_error(pred_test_final[:,0], output_test[:,0], squared = False)
    rmse_n.append(loss_n)
    loss_o = sklearn.metrics.mean_squared_error(pred_test_final[:,1], output_test[:,1], squared = False)
    rmse_o.append(loss_o)
    loss_d= sklearn.metrics.mean_squared_error(pred_test_final[:,2], output_test[:,2], squared = False)
    rmse_d.append(loss_d)
rmse_combined = np.column_stack((rmse_n, rmse_o, rmse_d))
rmse_n_loss = sum(rmse_n) / len(rmse_n)
rmse_o_loss = sum(rmse_o) / len(rmse_o)
rmse_d_loss = sum(rmse_d) / len(rmse_d)
average_rmse = np.array([rmse_n_loss, rmse_o_loss, rmse_d_loss])

print(rmse_n_loss,rmse_o_loss,rmse_d_loss)
# Out:
# input_train : (38, 120, 47)
# output_train : (38, 3)
# input_val : (14, 120, 47)
# output_val : (14, 3)
# input_test : (16, 60, 47)
# output_test : (16, 3)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - loss: 4.8459 - sequential_15_mse: 0.1809 - sequential_16_mse: 0.1037 - sequential_17_mse: 0.0671
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# k: 0 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 4.6738 - sequential_15_mse: 0.0846 - sequential_16_mse: 0.1638 - sequential_17_mse: 0.0921
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 1 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 4.4177 - sequential_15_mse: 0.0883 - sequential_16_mse: 0.0382 - sequential_17_mse: 0.1160
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# k: 2 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 4.2289 - sequential_15_mse: 0.0420 - sequential_16_mse: 0.0570 - sequential_17_mse: 0.1092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# k: 3 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - loss: 4.0154 - sequential_15_mse: 0.0553 - sequential_16_mse: 0.0629 - sequential_17_mse: 0.0272
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# k: 4 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - loss: 3.8830 - sequential_15_mse: 0.0555 - sequential_16_mse: 0.0450 - sequential_17_mse: 0.0595
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# k: 5 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - loss: 3.7480 - sequential_15_mse: 0.0565 - sequential_16_mse: 0.0339 - sequential_17_mse: 0.0776
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# k: 6 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - loss: 3.5689 - sequential_15_mse: 0.0428 - sequential_16_mse: 0.0360 - sequential_17_mse: 0.0494
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# k: 7 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - loss: 3.4123 - sequential_15_mse: 0.0448 - sequential_16_mse: 0.0350 - sequential_17_mse: 0.0270
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# k: 8 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - loss: 3.3081 - sequential_15_mse: 0.0445 - sequential_16_mse: 0.0330 - sequential_17_mse: 0.0563
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 9 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 3.1765 - sequential_15_mse: 0.0474 - sequential_16_mse: 0.0303 - sequential_17_mse: 0.0520
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# k: 10 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 3.0373 - sequential_15_mse: 0.0418 - sequential_16_mse: 0.0273 - sequential_17_mse: 0.0443
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# k: 11 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 2.9101 - sequential_15_mse: 0.0367 - sequential_16_mse: 0.0324 - sequential_17_mse: 0.0360
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# k: 12 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 2.7910 - sequential_15_mse: 0.0405 - sequential_16_mse: 0.0286 - sequential_17_mse: 0.0318
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# k: 13 patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# input_train : (38, 120, 47)
# output_train : (38, 3)
# input_val : (14, 120, 47)
# output_val : (14, 3)
# input_test : (16, 60, 47)
# output_test : (16, 3)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 145ms/step - loss: 4.9151 - sequential_18_mse: 0.1699 - sequential_19_mse: 0.1396 - sequential_20_mse: 0.0601
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# k: 0 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 4.6341 - sequential_18_mse: 0.0807 - sequential_19_mse: 0.0629 - sequential_20_mse: 0.1106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# k: 1 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 4.3676 - sequential_18_mse: 0.0598 - sequential_19_mse: 0.0490 - sequential_20_mse: 0.0438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# k: 2 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 4.1841 - sequential_18_mse: 0.0565 - sequential_19_mse: 0.0375 - sequential_20_mse: 0.0369
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# k: 3 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 4.0447 - sequential_18_mse: 0.0693 - sequential_19_mse: 0.0429 - sequential_20_mse: 0.0380
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# k: 4 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 3.8610 - sequential_18_mse: 0.0559 - sequential_19_mse: 0.0323 - sequential_20_mse: 0.0326
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# k: 5 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 3.6922 - sequential_18_mse: 0.0490 - sequential_19_mse: 0.0203 - sequential_20_mse: 0.0332
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# k: 6 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 3.5568 - sequential_18_mse: 0.0453 - sequential_19_mse: 0.0235 - sequential_20_mse: 0.0442
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# k: 7 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 3.4199 - sequential_18_mse: 0.0561 - sequential_19_mse: 0.0277 - sequential_20_mse: 0.0337
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# k: 8 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 3.2566 - sequential_18_mse: 0.0396 - sequential_19_mse: 0.0255 - sequential_20_mse: 0.0261
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# k: 9 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 3.1495 - sequential_18_mse: 0.0505 - sequential_19_mse: 0.0297 - sequential_20_mse: 0.0360
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# k: 10 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 2.9949 - sequential_18_mse: 0.0391 - sequential_19_mse: 0.0227 - sequential_20_mse: 0.0272
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# k: 11 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 2.8756 - sequential_18_mse: 0.0402 - sequential_19_mse: 0.0285 - sequential_20_mse: 0.0241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# k: 12 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 2.7631 - sequential_18_mse: 0.0409 - sequential_19_mse: 0.0256 - sequential_20_mse: 0.0323
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# k: 13 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 2.6454 - sequential_18_mse: 0.0418 - sequential_19_mse: 0.0231 - sequential_20_mse: 0.0305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# k: 14 patience: 10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - loss: 2.5433 - sequential_18_mse: 0.0447 - sequential_19_mse: 0.0238 - sequential_20_mse: 0.0347
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# k: 15 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - loss: 2.4326 - sequential_18_mse: 0.0391 - sequential_19_mse: 0.0311 - sequential_20_mse: 0.0279
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# k: 16 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - loss: 2.3168 - sequential_18_mse: 0.0368 - sequential_19_mse: 0.0233 - sequential_20_mse: 0.0237
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# k: 17 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - loss: 2.2209 - sequential_18_mse: 0.0361 - sequential_19_mse: 0.0202 - sequential_20_mse: 0.0291
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# k: 18 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - loss: 2.1283 - sequential_18_mse: 0.0406 - sequential_19_mse: 0.0211 - sequential_20_mse: 0.0249
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# k: 19 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 2.0309 - sequential_18_mse: 0.0295 - sequential_19_mse: 0.0215 - sequential_20_mse: 0.0280
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 20 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.9479 - sequential_18_mse: 0.0354 - sequential_19_mse: 0.0270 - sequential_20_mse: 0.0198
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# k: 21 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8614 - sequential_18_mse: 0.0349 - sequential_19_mse: 0.0229 - sequential_20_mse: 0.0206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# k: 22 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 1.7777 - sequential_18_mse: 0.0269 - sequential_19_mse: 0.0257 - sequential_20_mse: 0.0212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# k: 23 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 1.7007 - sequential_18_mse: 0.0330 - sequential_19_mse: 0.0181 - sequential_20_mse: 0.0216
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# k: 24 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.6113 - sequential_18_mse: 0.0211 - sequential_19_mse: 0.0152 - sequential_20_mse: 0.0197
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# k: 25 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.5461 - sequential_18_mse: 0.0306 - sequential_19_mse: 0.0125 - sequential_20_mse: 0.0175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# k: 26 patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# input_train : (38, 120, 47)
# output_train : (38, 3)
# input_val : (14, 120, 47)
# output_val : (14, 3)
# input_test : (16, 60, 47)
# output_test : (16, 3)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - loss: 5.0374 - sequential_21_mse: 0.0862 - sequential_22_mse: 0.2746 - sequential_23_mse: 0.0830
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# k: 0 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 4.6680 - sequential_21_mse: 0.0629 - sequential_22_mse: 0.0931 - sequential_23_mse: 0.0816
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# k: 1 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 4.5281 - sequential_21_mse: 0.0832 - sequential_22_mse: 0.1106 - sequential_23_mse: 0.0643
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# k: 2 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 4.2951 - sequential_21_mse: 0.0944 - sequential_22_mse: 0.0319 - sequential_23_mse: 0.0561
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# k: 3 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 4.0845 - sequential_21_mse: 0.0362 - sequential_22_mse: 0.0446 - sequential_23_mse: 0.0447
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# k: 4 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 4.0057 - sequential_21_mse: 0.0615 - sequential_22_mse: 0.0675 - sequential_23_mse: 0.0682
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# k: 5 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 3.8057 - sequential_21_mse: 0.0542 - sequential_22_mse: 0.0488 - sequential_23_mse: 0.0408
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# k: 6 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 3.6210 - sequential_21_mse: 0.0425 - sequential_22_mse: 0.0317 - sequential_23_mse: 0.0270
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# k: 7 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 3.4981 - sequential_21_mse: 0.0524 - sequential_22_mse: 0.0323 - sequential_23_mse: 0.0317
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# k: 8 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 3.3783 - sequential_21_mse: 0.0538 - sequential_22_mse: 0.0366 - sequential_23_mse: 0.0405
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 9 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 3.2161 - sequential_21_mse: 0.0384 - sequential_22_mse: 0.0303 - sequential_23_mse: 0.0298
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# k: 10 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 3.0699 - sequential_21_mse: 0.0276 - sequential_22_mse: 0.0226 - sequential_23_mse: 0.0274
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 11 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 2.9648 - sequential_21_mse: 0.0463 - sequential_22_mse: 0.0203 - sequential_23_mse: 0.0265
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# k: 12 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - loss: 2.8554 - sequential_21_mse: 0.0495 - sequential_22_mse: 0.0257 - sequential_23_mse: 0.0247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# k: 13 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - loss: 2.7408 - sequential_21_mse: 0.0454 - sequential_22_mse: 0.0237 - sequential_23_mse: 0.0280
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# k: 14 patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# input_train : (38, 120, 47)
# output_train : (38, 3)
# input_val : (14, 120, 47)
# output_val : (14, 3)
# input_test : (16, 60, 47)
# output_test : (16, 3)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - loss: 4.6674 - sequential_24_mse: 0.0683 - sequential_25_mse: 0.0626 - sequential_26_mse: 0.0485
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# k: 0 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - loss: 4.5046 - sequential_24_mse: 0.0870 - sequential_25_mse: 0.0692 - sequential_26_mse: 0.0311
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# k: 1 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - loss: 4.2679 - sequential_24_mse: 0.0540 - sequential_25_mse: 0.0260 - sequential_26_mse: 0.0350
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# k: 2 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - loss: 4.1521 - sequential_24_mse: 0.0972 - sequential_25_mse: 0.0397 - sequential_26_mse: 0.0236
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# k: 3 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - loss: 3.9702 - sequential_24_mse: 0.0550 - sequential_25_mse: 0.0415 - sequential_26_mse: 0.0394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# k: 4 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - loss: 3.7717 - sequential_24_mse: 0.0359 - sequential_25_mse: 0.0229 - sequential_26_mse: 0.0321
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# k: 5 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 3.6015 - sequential_24_mse: 0.0362 - sequential_25_mse: 0.0184 - sequential_26_mse: 0.0160
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# k: 6 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 3.4708 - sequential_24_mse: 0.0403 - sequential_25_mse: 0.0241 - sequential_26_mse: 0.0213
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# k: 7 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 3.3214 - sequential_24_mse: 0.0346 - sequential_25_mse: 0.0200 - sequential_26_mse: 0.0232
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# k: 8 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 3.1815 - sequential_24_mse: 0.0426 - sequential_25_mse: 0.0152 - sequential_26_mse: 0.0170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# k: 9 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 3.0334 - sequential_24_mse: 0.0331 - sequential_25_mse: 0.0150 - sequential_26_mse: 0.0110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# k: 10 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 2.9142 - sequential_24_mse: 0.0321 - sequential_25_mse: 0.0191 - sequential_26_mse: 0.0165
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 11 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 2.7837 - sequential_24_mse: 0.0274 - sequential_25_mse: 0.0208 - sequential_26_mse: 0.0124
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 12 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 2.6638 - sequential_24_mse: 0.0308 - sequential_25_mse: 0.0152 - sequential_26_mse: 0.0135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# k: 13 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 2.5539 - sequential_24_mse: 0.0319 - sequential_25_mse: 0.0175 - sequential_26_mse: 0.0145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# k: 14 patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# input_train : (38, 120, 47)
# output_train : (38, 3)
# input_val : (14, 120, 47)
# output_val : (14, 3)
# input_test : (16, 60, 47)
# output_test : (16, 3)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 153ms/step - loss: 4.6823 - sequential_27_mse: 0.0541 - sequential_28_mse: 0.1069 - sequential_29_mse: 0.0530
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# k: 0 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 4.5406 - sequential_27_mse: 0.1327 - sequential_28_mse: 0.0546 - sequential_29_mse: 0.0575
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# k: 1 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 4.3793 - sequential_27_mse: 0.0659 - sequential_28_mse: 0.1145 - sequential_29_mse: 0.0635
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# k: 2 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 4.1808 - sequential_27_mse: 0.0848 - sequential_28_mse: 0.0668 - sequential_29_mse: 0.0499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# k: 3 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 3.9595 - sequential_27_mse: 0.0570 - sequential_28_mse: 0.0352 - sequential_29_mse: 0.0401
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# k: 4 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 3.8392 - sequential_27_mse: 0.0493 - sequential_28_mse: 0.0727 - sequential_29_mse: 0.0389
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# k: 5 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 3.6690 - sequential_27_mse: 0.0425 - sequential_28_mse: 0.0504 - sequential_29_mse: 0.0428
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# k: 6 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 3.5014 - sequential_27_mse: 0.0421 - sequential_28_mse: 0.0375 - sequential_29_mse: 0.0292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 7 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 3.3691 - sequential_27_mse: 0.0357 - sequential_28_mse: 0.0456 - sequential_29_mse: 0.0320
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# k: 8 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 3.2347 - sequential_27_mse: 0.0382 - sequential_28_mse: 0.0448 - sequential_29_mse: 0.0284
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# k: 9 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 3.1145 - sequential_27_mse: 0.0329 - sequential_28_mse: 0.0544 - sequential_29_mse: 0.0322
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# k: 10 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - loss: 2.9651 - sequential_27_mse: 0.0343 - sequential_28_mse: 0.0291 - sequential_29_mse: 0.0307
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# k: 11 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - loss: 2.8294 - sequential_27_mse: 0.0274 - sequential_28_mse: 0.0264 - sequential_29_mse: 0.0244
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# k: 12 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - loss: 2.7118 - sequential_27_mse: 0.0262 - sequential_28_mse: 0.0236 - sequential_29_mse: 0.0256
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# k: 13 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - loss: 2.6173 - sequential_27_mse: 0.0293 - sequential_28_mse: 0.0275 - sequential_29_mse: 0.0339
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# k: 14 patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 3.7905510277438887 1.9368525453277996 2.6092169429624925
