# %%
from google.colab import drive
import pandas as pd
from sklearn.preprocessing import StandardScaler
from scipy import stats
import numpy as np
import logging
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from datetime import datetime
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime
import matplotlib.dates as mdates
import os

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Set the base path to the desired directory on Google Drive
base_path = '/content/drive/MyDrive/Study_1_Data/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read_csv(file_path):
    data = pd.read_csv(file_path)
    return data

# %%
def process_data(data, columns_to_remove):
    processed_data = data.drop(columns=columns_to_remove).values
    return processed_data

# %%
def construct_3d_array(base_dir, participants, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye):
    """
    Construct 3D array from CSV files.
    """
    num_rows = 180  # Define number of rows to keep (last 180 rows)
    arrays_3d = []

    for participant in participants:
        participant_id = f"{int(participant):02d}"  # Format participant number to two digits

        valid_simulations = []

        for simulation in simulations:
            hr_file_path = os.path.join(base_dir, participant_id, simulation, f'HR{simulation.capitalize()}.csv')
            gsr_file_path = os.path.join(base_dir, participant_id, simulation, f'EDA{simulation.capitalize()}_downsampled.csv')
            head_file_path = os.path.join(base_dir, participant_id, simulation, 'head_tracking_downsampled.csv')
            eye_file_path = os.path.join(base_dir, participant_id, simulation, 'eye_tracking_downsampled.csv')

            # Check if all files exist
            if all(os.path.exists(file) for file in [hr_file_path, gsr_file_path, head_file_path, eye_file_path]):
                valid_simulations.append(simulation)

        num_valid_simulations = len(valid_simulations)
        if num_valid_simulations == 0:
            continue  # Skip this participant if no valid simulations are found

        array_3d = np.zeros((num_valid_simulations, num_rows, 47)) # hr=1, gsr=1, head=15-3, eye=41-8 total columns after removing columns= 48

        for s_idx, simulation in enumerate(valid_simulations):
            # Process hr data
            hr_file_path = os.path.join(base_dir, participant_id, simulation, f'HR{simulation.capitalize()}.csv')
            hr_data = read_csv(hr_file_path)
            processed_hr_data = process_data(hr_data, columns_to_remove_hr)
            processed_hr_data = processed_hr_data[-num_rows:]  # Keep only the last 180 rows

            # Process gsr data
            gsr_file_path = os.path.join(base_dir, participant_id, simulation, f'EDA{simulation.capitalize()}_downsampled.csv')
            gsr_data = read_csv(gsr_file_path)
            processed_gsr_data = process_data(gsr_data, columns_to_remove_gsr)
            processed_gsr_data = processed_gsr_data[-num_rows:]  # Keep only the last 180 rows

            # Process head data
            head_file_path = os.path.join(base_dir, participant_id, simulation, 'head_tracking_downsampled.csv')
            head_data = read_csv(head_file_path)
            processed_head_data = process_data(head_data, columns_to_remove_head)
            processed_head_data = processed_head_data[-num_rows:]  # Keep only the last 180 rows

            # Process eye data
            eye_file_path = os.path.join(base_dir, participant_id, simulation, 'eye_tracking_downsampled.csv')
            eye_data = read_csv(eye_file_path)
            processed_eye_data = process_data(eye_data, columns_to_remove_eye)
            processed_eye_data = processed_eye_data[-num_rows:]  # Keep only the last 180 rows

            # Combine processed data
            combined_data = np.concatenate((processed_hr_data, processed_gsr_data, processed_head_data, processed_eye_data), axis=1)

            array_3d[s_idx, :, :] = combined_data

        arrays_3d.append(array_3d)

    return arrays_3d

# %%
sample_size=30
simulations = ['flat','noise','bumps']
participants = [str(i) for i in range(1, 27)]  # Participants 101 to 127
columns_to_remove_hr = []
columns_to_remove_gsr = []
columns_to_remove_eye = ['#Frame','Time', 'Unnamed: 40','ConvergenceValid','Left_Eye_Closed','Right_Eye_Closed','LocalGazeValid','WorldGazeValid']
columns_to_remove_head = ['#Frame','Time', 'Unnamed: 14']

# %%
def calculate_total_ssq(csv_file):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    n_columns = [0, 5, 6, 7, 8, 14, 15]
    o_columns = [0, 1, 2, 3, 4, 8, 10]
    d_columns = [4, 7, 9, 10, 11, 12, 13]

    # Calculate sum for each specified set of columns
    n_val = df.iloc[0, n_columns].sum()
    o_val = df.iloc[0, o_columns].sum()
    d_val = df.iloc[0, d_columns].sum()

    return n_val, o_val, d_val

# %%
def merge_ssq_column(conditions,participants):
  directories = []
  total_ssq_values = []
  for participant in participants:
      participant = f"{int(participant):02d}"
      for condition in conditions:
          directory = os.path.join(base_path, participant, condition)
          directories.append(directory)

  # Loop through each directory
  for directory in directories:
      # Check if the directory exists
      if not os.path.exists(directory):
          continue

      # Get all CSV files in the directory that are named 'ssq.csv'
      csv_files = [file for file in os.listdir(directory) if file == 'ssq.csv']

      # Loop through each CSV file
      for csv_file in csv_files:
          csv_path = os.path.join(directory, csv_file)
          df = pd.read_csv(csv_path)
          # n_val,o_val,d_val = calculate_total_ssq(csv_path)
          # total_ssq_values.append([n_val, o_val, d_val])
          ssq_values_participant = df.iloc[:, 0:17].values.flatten()   # Assuming SSQ values are in columns 1 to 16
          total_ssq_values.append(ssq_values_participant)
  ssq_array = np.array(total_ssq_values)
  return ssq_array

def merge_total_ssq(conditions,participants):
  directories = []
  total_ssq_values = []
  for participant in participants:
      participant = f"{int(participant):02d}"
      for condition in conditions:
          directory = os.path.join(base_path, participant, condition)
          directories.append(directory)

  # Loop through each directory
  for directory in directories:
      # Check if the directory exists
      if not os.path.exists(directory):
          continue

      # Get all CSV files in the directory that are named 'ssq.csv'
      csv_files = [file for file in os.listdir(directory) if file == 'ssq.csv']

      # Loop through each CSV file
      for csv_file in csv_files:
          csv_path = os.path.join(directory, csv_file)
          n_val,o_val,d_val = calculate_total_ssq(csv_path)
          total_ssq = (n_val+o_val+d_val) * 3.74
          df = pd.read_csv(csv_path)
          df["total-ssq"] = total_ssq
          #print("csv_path: ",csv_path,"   ",total_ssq)
          total_ssq_values.append(total_ssq)
  # Create a DataFrame from the list of total SSQ values
  df_total_ssq = pd.DataFrame(total_ssq_values, columns=["total-ssq"])
  # Convert the list of total SSQ values to a NumPy array
  total_ssq_array = np.array(total_ssq_values)
  return total_ssq_array

# %%
participants_group_1 = [1,3,4,11,25]
participants_group_2 = [2,7,8,9,17]
participants_group_3 = [10,12,13,22,23]
participants_group_4 = [5,14,18,20,21]
participants_group_5 = [6,15,16,19,24,26]

arrays_group_1 = construct_3d_array(base_path, participants_group_1, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_2 = construct_3d_array(base_path, participants_group_2, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_3 = construct_3d_array(base_path, participants_group_3, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_4 = construct_3d_array(base_path, participants_group_4, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_5 = construct_3d_array(base_path, participants_group_5, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)

# %%
# Concatenate arrays along the first axis
input_group_1 = np.concatenate(arrays_group_1, axis=0)
input_group_2 = np.concatenate(arrays_group_2, axis=0)
input_group_3 = np.concatenate(arrays_group_3, axis=0)
input_group_4 = np.concatenate(arrays_group_4, axis=0)
input_group_5 = np.concatenate(arrays_group_5, axis=0)

# %%
output_group_1=merge_ssq_column(simulations,participants_group_1)
output_group_2=merge_ssq_column(simulations,participants_group_2)
output_group_3=merge_ssq_column(simulations,participants_group_3)
output_group_4=merge_ssq_column(simulations,participants_group_4)
output_group_5=merge_ssq_column(simulations,participants_group_5)

output_group_1 = np.squeeze(output_group_1)
output_group_2 = np.squeeze(output_group_2)
output_group_3 = np.squeeze(output_group_3)
output_group_4 = np.squeeze(output_group_4)
output_group_5 = np.squeeze(output_group_5)


output_total_ssq_group_1=merge_total_ssq(simulations,participants_group_1)
output_total_ssq_group_2=merge_total_ssq(simulations,participants_group_2)
output_total_ssq_group_3=merge_total_ssq(simulations,participants_group_3)
output_total_ssq_group_4=merge_total_ssq(simulations,participants_group_4)
output_total_ssq_group_5=merge_total_ssq(simulations,participants_group_5)

output_total_ssq_group_1=output_total_ssq_group_1.reshape(-1, 1)
output_total_ssq_group_2=output_total_ssq_group_2.reshape(-1, 1)
output_total_ssq_group_3=output_total_ssq_group_3.reshape(-1, 1)
output_total_ssq_group_4=output_total_ssq_group_4.reshape(-1, 1)
output_total_ssq_group_5=output_total_ssq_group_5.reshape(-1, 1)

# %%
def scale_input_data(input_train, input_test):
    # Get the shape of the input data
    num_samples_train, time_steps_train, num_features = input_train.shape
    num_samples_test, time_steps_test, _ = input_test.shape

    # Reshape the input data into 2D arrays
    flattened_train_data = input_train.reshape(-1, num_features)
    flattened_test_data = input_test.reshape(-1, num_features)

    # Initialize a MinMaxScaler object
    scaler = MinMaxScaler()

    # Fit the scaler on the training data and transform both train and test data
    scaled_train_data = scaler.fit_transform(flattened_train_data)
    scaled_test_data = scaler.transform(flattened_test_data)

    # Reshape the scaled data back to its original shape
    scaled_train_data = scaled_train_data.reshape(num_samples_train, time_steps_train, num_features)
    scaled_test_data = scaled_test_data.reshape(num_samples_test, time_steps_test, num_features)

    return scaled_train_data, scaled_test_data

def scale_target_var(target_data):
    min_val, max_val = np.min(target_data, axis=0), np.max(target_data, axis=0)
    target_data = (target_data-min_val)/(max_val-min_val)

    return target_data, min_val, max_val

# %%
from keras.models import Sequential
from keras.layers import Input, GRU, Dense, Dropout
from keras.models import Model
import numpy as np
import sklearn
from keras.utils import to_categorical

total_losses=[]
def get_shared_GRU(input_shape1, input_shape2):
    # Define shared GRU model
    input_layer = Input(shape=(input_shape1, input_shape2))
    x = GRU(64, return_sequences=False)(input_layer)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.2)(x)
    shared_model = Model(inputs=input_layer, outputs=x)
    return shared_model

def get_output_model(shared_GRU_output, output_shape):
    # Define separate output model for each column
    output_models = []
    for i in range(output_shape[1]):
        x = Dense(256, activation='relu')(shared_GRU_output)
        x = Dropout(0.2)(x)
        output = Dense(4, activation='softmax')(x)  # Output shape is (None, 4) for 4 classes
        output_models.append(output)
    return output_models


input_groups = [input_group_1, input_group_2, input_group_3, input_group_4, input_group_5]
output_groups = [output_group_1, output_group_2, output_group_3, output_group_4, output_group_5]
ssq_groups = [output_total_ssq_group_1, output_total_ssq_group_2, output_total_ssq_group_3, output_total_ssq_group_4, output_total_ssq_group_5]


# Specify the number of samples to select for each group in each iteration
samples_per_iteration = [
    [3, 3, 3, 3, 2],  # For input_group_1
    [3, 3, 3, 3, 2],  # For input_group_2
    [3, 3, 3, 2, 2],  # For input_group_3
    [2, 2, 2, 2, 3],  # For input_group_4
    [3, 3, 3, 3, 4]   # For input_group_5
]

# Initialize a list of global indices arrays, one for each group
global_indices = [[] for _ in range(len(input_groups))]
print("global_indices",global_indices)

# Outer loop to repeat the sampling process for 5 iterations
for iteration in range(5):
  X_train, X_val, X_test = [], [], []
  y_train, y_val, y_test = [], [], []
  ssq_train, ssq_val, ssq_test = [], [], []
  print(f"Iteration {iteration + 1}")
  print("global_indices",global_indices)
  # Loop over each group
  for i, (input_group, output_group, ssq_group) in enumerate(zip(input_groups, output_groups, ssq_groups)):
      num_samples = samples_per_iteration[i][iteration]  # Number of samples to select for the current group and iteration

      # Create a set of available indices that haven't been selected yet for the current group
      available_indices = list(set(range(len(input_group))) - set(global_indices[i]))

      # Check if there are fewer available indices than needed
      if len(available_indices) < num_samples:
          print(f"Not enough indices left in group {i + 1} to select {num_samples} new samples.")
          num_samples = len(available_indices)  # Adjust to take whatever is left

      # Select the required number of samples from the available indices for the current group
      selected_indices = np.random.choice(available_indices, num_samples, replace=False)
      global_indices[i].extend(selected_indices)  # Add these indices to the group's global list

      # Remove these selected samples from the input, output, and SSQ groups
      X_test_temp = input_group[selected_indices]
      y_test_temp = output_group[selected_indices]
      ssq_test_temp = ssq_group[selected_indices]

      X_temp = np.delete(input_group, selected_indices, axis=0)
      y_temp = np.delete(output_group, selected_indices, axis=0)
      ssq_temp = np.delete(ssq_group, selected_indices, axis=0)

      # Split the remaining data into a training set (60%) and a validation set (40%)
      X_train_temp, X_val_temp, y_train_temp, y_val_temp, ssq_train_temp, ssq_val_temp = train_test_split(
          X_temp, y_temp, ssq_temp, test_size=0.2)

      # Append the results to the corresponding lists
      X_train.append(X_train_temp)
      X_val.append(X_val_temp)
      X_test.append(X_test_temp)

      y_train.append(y_train_temp)
      y_val.append(y_val_temp)
      y_test.append(y_test_temp)

      ssq_train.append(ssq_train_temp)
      ssq_val.append(ssq_val_temp)
      ssq_test.append(ssq_test_temp)

  # After the loop, concatenate the data for all groups if needed
  input_train = np.concatenate(X_train, axis=0)
  input_val = np.concatenate(X_val, axis=0)
  input_test = np.concatenate(X_test, axis=0)

  output_train = np.concatenate(y_train, axis=0)
  output_val = np.concatenate(y_val, axis=0)
  output_test = np.concatenate(y_test, axis=0)

  ssq_test = np.concatenate(ssq_test, axis=0)
  ssq_val = np.concatenate(ssq_val, axis=0)
  output_test_total_ssq = np.concatenate(ssq_test, axis=0)


  #  this section for scaling both train and validation set simultaniously
  # Step 1: Combine the training and validation sets
  combined_input = np.concatenate([input_train, input_val], axis=0)
  combined_output = np.concatenate([output_train, output_val], axis=0)

  # Step 2: Scale the combined input data
  # Assuming scale_input_data scales the data based on the combined dataset
  combined_input, input_test = scale_input_data(
      combined_input[:, (60-sample_size):(180-sample_size), :],
      input_test[:, (60-sample_size):(180-sample_size), :]
  )


    # Convert the original labels to one-hot encoded format
  output_train_encoded = to_categorical(combined_output, num_classes=4)

  # Step 4: Split the combined data back into training and validation sets
  # Use the original shapes of input_train and input_val to slice the combined arrays
  input_train = combined_input[:input_train.shape[0], :, :]
  input_val = combined_input[input_train.shape[0]:, :, :]

  output_train = output_train_encoded[:output_train.shape[0], :]
  output_val = output_train_encoded[output_train.shape[0]:, :]



  print("input_train :", input_train.shape)
  print("output_train :", output_train.shape)
  print("input_val :", input_val.shape)
  print("output_val :", output_val.shape)
  print("input_test :", input_test.shape)
  print("output_test :", output_test.shape)






  # Reshape train and test inputs to match GRU input shape
  train_input_reshaped = input_train.reshape((input_train.shape[0], input_train.shape[1], input_train.shape[2]))
  test_input_reshaped = input_test.reshape((input_test.shape[0], input_test.shape[1], input_test.shape[2]))
  val_input_reshaped = input_val.reshape((input_val.shape[0], input_val.shape[1], input_val.shape[2]))
  # Get shared GRU model
  shared_GRU = get_shared_GRU(input_train.shape[1], input_train.shape[2])

  # Create separate output models for each column
  output_models = get_output_model(shared_GRU.output, output_train.shape)

  # Create combined model
  model = Model(inputs=shared_GRU.input, outputs=output_models)

  # Compile and train the model
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=[['accuracy'] for _ in range(output_train.shape[1])])

  best_val_loss = float('inf')
  patience = 0
  best_model = None

  # Early stopping based on validation loss
  for k in range(200):
      model.fit(train_input_reshaped, [output_train[:, i] for i in range(output_train.shape[1])], epochs=1, batch_size=32)
      pred_val = np.array(model.predict(val_input_reshaped))
      pred_val = np.transpose(pred_val.squeeze(), (1, 0, 2))
      pred_val = np.argmax(pred_val, axis=-1).reshape(pred_val.shape[:-1])

      print(f"k: {k}, patience: {patience}")

      # Evaluate the model based on SSQ for validation data
      losses = []
      for i in range(pred_val.shape[0]):
          total_ssq = 0
          for j in [0, 5, 6, 7, 8, 14, 15]:
              total_ssq += np.sum(pred_val[i, j])

          for j in [0, 1, 2, 3, 4, 8, 10]:
              total_ssq += np.sum(pred_val[i, j])

          for j in [4, 7, 9, 10, 11, 12, 13]:
              total_ssq += np.sum(pred_val[i, j])

          total_ssq *= 3.74
          output_val_ssq = ssq_val[i, 0]
          loss = sklearn.metrics.mean_squared_error([total_ssq], [output_val_ssq], squared=False)
          losses.append(loss)

      tmp_val_loss = np.mean(losses)
      if tmp_val_loss <= best_val_loss:
          best_val_loss = tmp_val_loss
          patience = 0
          best_model = model
      else:
          patience += 1
          if patience > 10:
              break

  # Predict and evaluate test data using the best model
  pred_test = np.array(best_model.predict(test_input_reshaped))
  pred_test = np.transpose(pred_test.squeeze(), (1, 0, 2))
  pred_test = np.argmax(pred_test, axis=-1).reshape(pred_test.shape[:-1])

  pred_total_ssq = []
  for i in range(pred_test.shape[0]):
      total_ssq = 0
      for j in [0, 5, 6, 7, 8, 14, 15]:
          total_ssq += np.sum(pred_test[i, j])

      for j in [0, 1, 2, 3, 4, 8, 10]:
          total_ssq += np.sum(pred_test[i, j])

      for j in [4, 7, 9, 10, 11, 12, 13]:
          total_ssq += np.sum(pred_test[i, j])

      total_ssq *= 3.74
      pred_total_ssq.append(total_ssq)

  # Overall Test Loss
  loss = sklearn.metrics.mean_squared_error(pred_total_ssq, output_test_total_ssq, squared=False)
  print(f"Test Loss iteration {iteration}: {loss}")
  total_losses.append(loss)

average_loss = sum(total_losses) / len(total_losses)
total_losses.append(average_loss)
print("average_loss:", average_loss)
# Out:
# global_indices [[], [], [], [], []]
# Iteration 1
# global_indices [[], [], [], [], []]
# input_train : (41, 120, 47)
# output_train : (41, 16, 4)
# input_val : (13, 120, 47)
# output_val : (13, 16, 4)
# input_test : (14, 120, 47)
# output_test : (14, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 93ms/step - dense_167_accuracy: 0.2726 - dense_169_accuracy: 0.2088 - dense_171_accuracy: 0.2739 - dense_173_accuracy: 0.2205 - dense_175_accuracy: 0.2576 - dense_177_accuracy: 0.6474 - dense_179_accuracy: 0.3377 - dense_181_accuracy: 0.2843 - dense_183_accuracy: 0.3377 - dense_185_accuracy: 0.3481 - dense_187_accuracy: 0.1939 - dense_189_accuracy: 0.1717 - dense_191_accuracy: 0.4815 - dense_193_accuracy: 0.1880 - dense_195_accuracy: 0.1555 - dense_197_accuracy: 0.0592 - loss: 22.0583
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# k: 0, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - dense_167_accuracy: 0.5511 - dense_169_accuracy: 0.7645 - dense_171_accuracy: 0.8933 - dense_173_accuracy: 0.5882 - dense_175_accuracy: 0.7807 - dense_177_accuracy: 0.7703 - dense_179_accuracy: 0.5940 - dense_181_accuracy: 0.6636 - dense_183_accuracy: 0.7912 - dense_185_accuracy: 0.8504 - dense_187_accuracy: 0.9304 - dense_189_accuracy: 0.7807 - dense_191_accuracy: 0.7007 - dense_193_accuracy: 0.9037 - dense_195_accuracy: 0.4606 - dense_197_accuracy: 0.6369 - loss: 17.3514
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 1, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - dense_167_accuracy: 0.5244 - dense_169_accuracy: 0.7436 - dense_171_accuracy: 0.9037 - dense_173_accuracy: 0.5673 - dense_175_accuracy: 0.7703 - dense_177_accuracy: 0.7912 - dense_179_accuracy: 0.6148 - dense_181_accuracy: 0.6207 - dense_183_accuracy: 0.7599 - dense_185_accuracy: 0.8504 - dense_187_accuracy: 0.9200 - dense_189_accuracy: 0.7599 - dense_191_accuracy: 0.6903 - dense_193_accuracy: 0.8933 - dense_195_accuracy: 0.4652 - dense_197_accuracy: 0.8341 - loss: 13.6432
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 2, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - dense_167_accuracy: 0.5556 - dense_169_accuracy: 0.7749 - dense_171_accuracy: 0.9141 - dense_173_accuracy: 0.5673 - dense_175_accuracy: 0.7703 - dense_177_accuracy: 0.7912 - dense_179_accuracy: 0.6253 - dense_181_accuracy: 0.6519 - dense_183_accuracy: 0.7807 - dense_185_accuracy: 0.8608 - dense_187_accuracy: 0.9304 - dense_189_accuracy: 0.7807 - dense_191_accuracy: 0.7215 - dense_193_accuracy: 0.9037 - dense_195_accuracy: 0.5081 - dense_197_accuracy: 0.8341 - loss: 12.0935
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# k: 3, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - dense_167_accuracy: 0.5452 - dense_169_accuracy: 0.7436 - dense_171_accuracy: 0.9037 - dense_173_accuracy: 0.5986 - dense_175_accuracy: 0.8016 - dense_177_accuracy: 0.7703 - dense_179_accuracy: 0.6148 - dense_181_accuracy: 0.6415 - dense_183_accuracy: 0.7912 - dense_185_accuracy: 0.8504 - dense_187_accuracy: 0.9200 - dense_189_accuracy: 0.7599 - dense_191_accuracy: 0.6903 - dense_193_accuracy: 0.9037 - dense_195_accuracy: 0.5023 - dense_197_accuracy: 0.8237 - loss: 13.0189
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 4, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - dense_167_accuracy: 0.5244 - dense_169_accuracy: 0.7436 - dense_171_accuracy: 0.8933 - dense_173_accuracy: 0.5569 - dense_175_accuracy: 0.7807 - dense_177_accuracy: 0.7807 - dense_179_accuracy: 0.6044 - dense_181_accuracy: 0.6311 - dense_183_accuracy: 0.7807 - dense_185_accuracy: 0.8399 - dense_187_accuracy: 0.9200 - dense_189_accuracy: 0.7912 - dense_191_accuracy: 0.7007 - dense_193_accuracy: 0.8933 - dense_195_accuracy: 0.4815 - dense_197_accuracy: 0.8237 - loss: 12.4971
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# k: 5, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - dense_167_accuracy: 0.5244 - dense_169_accuracy: 0.7436 - dense_171_accuracy: 0.9037 - dense_173_accuracy: 0.6519 - dense_175_accuracy: 0.7703 - dense_177_accuracy: 0.7599 - dense_179_accuracy: 0.6044 - dense_181_accuracy: 0.6103 - dense_183_accuracy: 0.7703 - dense_185_accuracy: 0.8712 - dense_187_accuracy: 0.9200 - dense_189_accuracy: 0.7912 - dense_191_accuracy: 0.7007 - dense_193_accuracy: 0.8933 - dense_195_accuracy: 0.4977 - dense_197_accuracy: 0.8237 - loss: 11.9316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 6, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dense_167_accuracy: 0.5244 - dense_169_accuracy: 0.7541 - dense_171_accuracy: 0.9037 - dense_173_accuracy: 0.5302 - dense_175_accuracy: 0.7703 - dense_177_accuracy: 0.7703 - dense_179_accuracy: 0.6044 - dense_181_accuracy: 0.6311 - dense_183_accuracy: 0.7703 - dense_185_accuracy: 0.8504 - dense_187_accuracy: 0.9200 - dense_189_accuracy: 0.7599 - dense_191_accuracy: 0.7111 - dense_193_accuracy: 0.8933 - dense_195_accuracy: 0.4281 - dense_197_accuracy: 0.8341 - loss: 11.7529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# k: 7, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - dense_167_accuracy: 0.5986 - dense_169_accuracy: 0.7541 - dense_171_accuracy: 0.8933 - dense_173_accuracy: 0.6415 - dense_175_accuracy: 0.7912 - dense_177_accuracy: 0.7912 - dense_179_accuracy: 0.6357 - dense_181_accuracy: 0.6728 - dense_183_accuracy: 0.7703 - dense_185_accuracy: 0.8399 - dense_187_accuracy: 0.9304 - dense_189_accuracy: 0.7807 - dense_191_accuracy: 0.7111 - dense_193_accuracy: 0.9037 - dense_195_accuracy: 0.5394 - dense_197_accuracy: 0.8549 - loss: 11.1364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 8, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - dense_167_accuracy: 0.5348 - dense_169_accuracy: 0.7436 - dense_171_accuracy: 0.8933 - dense_173_accuracy: 0.5719 - dense_175_accuracy: 0.7807 - dense_177_accuracy: 0.7912 - dense_179_accuracy: 0.6148 - dense_181_accuracy: 0.6311 - dense_183_accuracy: 0.7807 - dense_185_accuracy: 0.8504 - dense_187_accuracy: 0.9304 - dense_189_accuracy: 0.7703 - dense_191_accuracy: 0.7007 - dense_193_accuracy: 0.9141 - dense_195_accuracy: 0.5348 - dense_197_accuracy: 0.8237 - loss: 11.3900
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 9, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - dense_167_accuracy: 0.5348 - dense_169_accuracy: 0.7436 - dense_171_accuracy: 0.9037 - dense_173_accuracy: 0.5882 - dense_175_accuracy: 0.7703 - dense_177_accuracy: 0.7703 - dense_179_accuracy: 0.6044 - dense_181_accuracy: 0.6311 - dense_183_accuracy: 0.7807 - dense_185_accuracy: 0.8608 - dense_187_accuracy: 0.9200 - dense_189_accuracy: 0.7599 - dense_191_accuracy: 0.7215 - dense_193_accuracy: 0.9037 - dense_195_accuracy: 0.5569 - dense_197_accuracy: 0.8237 - loss: 11.0368
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 10, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - dense_167_accuracy: 0.5140 - dense_169_accuracy: 0.7436 - dense_171_accuracy: 0.8933 - dense_173_accuracy: 0.5777 - dense_175_accuracy: 0.7703 - dense_177_accuracy: 0.7599 - dense_179_accuracy: 0.6044 - dense_181_accuracy: 0.6207 - dense_183_accuracy: 0.7599 - dense_185_accuracy: 0.8399 - dense_187_accuracy: 0.9200 - dense_189_accuracy: 0.7599 - dense_191_accuracy: 0.6903 - dense_193_accuracy: 0.8933 - dense_195_accuracy: 0.5673 - dense_197_accuracy: 0.8237 - loss: 11.2718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# k: 11, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Test Loss iteration 0: 34.58236255665596
# Iteration 2
# global_indices [[12, 3, 11], [7, 10, 8], [2, 5, 4], [5, 1], [6, 7, 5]]
# input_train : (41, 120, 47)
# output_train : (41, 16, 4)
# input_val : (13, 120, 47)
# output_val : (13, 16, 4)
# input_test : (14, 120, 47)
# output_test : (14, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - dense_200_accuracy: 0.1880 - dense_202_accuracy: 0.3539 - dense_204_accuracy: 0.3539 - dense_206_accuracy: 0.2414 - dense_208_accuracy: 0.1080 - dense_210_accuracy: 0.7436 - dense_212_accuracy: 0.3481 - dense_214_accuracy: 0.4385 - dense_216_accuracy: 0.3377 - dense_218_accuracy: 0.4444 - dense_220_accuracy: 0.8504 - dense_222_accuracy: 0.0000e+00 - dense_224_accuracy: 0.2147 - dense_226_accuracy: 0.2518 - dense_228_accuracy: 0.0859 - dense_230_accuracy: 0.3006 - loss: 21.7741
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 757ms/step
# k: 0, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dense_200_accuracy: 0.5185 - dense_202_accuracy: 0.6949 - dense_204_accuracy: 0.9141 - dense_206_accuracy: 0.5348 - dense_208_accuracy: 0.7645 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6148 - dense_214_accuracy: 0.5986 - dense_216_accuracy: 0.8178 - dense_218_accuracy: 0.8712 - dense_220_accuracy: 0.8874 - dense_222_accuracy: 0.5986 - dense_224_accuracy: 0.7691 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.5661 - dense_230_accuracy: 0.8608 - loss: 16.8381
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# k: 1, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - dense_200_accuracy: 0.5719 - dense_202_accuracy: 0.7215 - dense_204_accuracy: 0.8933 - dense_206_accuracy: 0.6682 - dense_208_accuracy: 0.7749 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6253 - dense_214_accuracy: 0.5882 - dense_216_accuracy: 0.8178 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8874 - dense_222_accuracy: 0.7215 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8445 - dense_228_accuracy: 0.5615 - dense_230_accuracy: 0.8608 - loss: 13.3583
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# k: 2, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - dense_200_accuracy: 0.4223 - dense_202_accuracy: 0.7007 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.6578 - dense_208_accuracy: 0.7749 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.5940 - dense_214_accuracy: 0.5882 - dense_216_accuracy: 0.8178 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8770 - dense_222_accuracy: 0.7007 - dense_224_accuracy: 0.7170 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.5511 - dense_230_accuracy: 0.8504 - loss: 12.3056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 3, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - dense_200_accuracy: 0.4652 - dense_202_accuracy: 0.6903 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.6682 - dense_208_accuracy: 0.7541 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6044 - dense_214_accuracy: 0.5394 - dense_216_accuracy: 0.7866 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8666 - dense_222_accuracy: 0.7007 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8133 - dense_228_accuracy: 0.5452 - dense_230_accuracy: 0.8399 - loss: 12.4518
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 4, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - dense_200_accuracy: 0.4919 - dense_202_accuracy: 0.7111 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.6474 - dense_208_accuracy: 0.7541 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.5940 - dense_214_accuracy: 0.5185 - dense_216_accuracy: 0.8074 - dense_218_accuracy: 0.8608 - dense_220_accuracy: 0.8666 - dense_222_accuracy: 0.6903 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8133 - dense_228_accuracy: 0.5511 - dense_230_accuracy: 0.8399 - loss: 12.8670
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 5, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - dense_200_accuracy: 0.4977 - dense_202_accuracy: 0.6903 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.6636 - dense_208_accuracy: 0.7541 - dense_210_accuracy: 0.7970 - dense_212_accuracy: 0.6148 - dense_214_accuracy: 0.5023 - dense_216_accuracy: 0.7970 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8666 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.5511 - dense_230_accuracy: 0.8504 - loss: 11.8290
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 6, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - dense_200_accuracy: 0.5185 - dense_202_accuracy: 0.7378 - dense_204_accuracy: 0.9141 - dense_206_accuracy: 0.6949 - dense_208_accuracy: 0.7645 - dense_210_accuracy: 0.7970 - dense_212_accuracy: 0.6044 - dense_214_accuracy: 0.5823 - dense_216_accuracy: 0.7970 - dense_218_accuracy: 0.8712 - dense_220_accuracy: 0.8770 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7378 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.5511 - dense_230_accuracy: 0.8504 - loss: 11.6801
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 7, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - dense_200_accuracy: 0.5348 - dense_202_accuracy: 0.7215 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.6949 - dense_208_accuracy: 0.7541 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6044 - dense_214_accuracy: 0.5673 - dense_216_accuracy: 0.8178 - dense_218_accuracy: 0.8608 - dense_220_accuracy: 0.8770 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.5882 - dense_230_accuracy: 0.8608 - loss: 11.0474
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 8, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - dense_200_accuracy: 0.4444 - dense_202_accuracy: 0.7215 - dense_204_accuracy: 0.8933 - dense_206_accuracy: 0.6682 - dense_208_accuracy: 0.7645 - dense_210_accuracy: 0.7970 - dense_212_accuracy: 0.6044 - dense_214_accuracy: 0.5882 - dense_216_accuracy: 0.8178 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8770 - dense_222_accuracy: 0.7215 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.5407 - dense_230_accuracy: 0.8399 - loss: 11.2980
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 9, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - dense_200_accuracy: 0.5081 - dense_202_accuracy: 0.7111 - dense_204_accuracy: 0.8933 - dense_206_accuracy: 0.6578 - dense_208_accuracy: 0.7436 - dense_210_accuracy: 0.7970 - dense_212_accuracy: 0.5940 - dense_214_accuracy: 0.5673 - dense_216_accuracy: 0.7970 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8770 - dense_222_accuracy: 0.6903 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.5615 - dense_230_accuracy: 0.8399 - loss: 11.2841
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 10, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dense_200_accuracy: 0.4710 - dense_202_accuracy: 0.7007 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.6578 - dense_208_accuracy: 0.7541 - dense_210_accuracy: 0.7970 - dense_212_accuracy: 0.6044 - dense_214_accuracy: 0.5673 - dense_216_accuracy: 0.8074 - dense_218_accuracy: 0.8608 - dense_220_accuracy: 0.8874 - dense_222_accuracy: 0.7007 - dense_224_accuracy: 0.7170 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.5407 - dense_230_accuracy: 0.8608 - loss: 10.7979
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 11, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - dense_200_accuracy: 0.5244 - dense_202_accuracy: 0.6903 - dense_204_accuracy: 0.8933 - dense_206_accuracy: 0.6740 - dense_208_accuracy: 0.7541 - dense_210_accuracy: 0.7866 - dense_212_accuracy: 0.5836 - dense_214_accuracy: 0.5882 - dense_216_accuracy: 0.7866 - dense_218_accuracy: 0.8399 - dense_220_accuracy: 0.8666 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7170 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.5407 - dense_230_accuracy: 0.8399 - loss: 11.1118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 12, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - dense_200_accuracy: 0.4919 - dense_202_accuracy: 0.7170 - dense_204_accuracy: 0.9141 - dense_206_accuracy: 0.6845 - dense_208_accuracy: 0.7332 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6044 - dense_214_accuracy: 0.5986 - dense_216_accuracy: 0.7970 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8666 - dense_222_accuracy: 0.7007 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.5823 - dense_230_accuracy: 0.8504 - loss: 10.9470
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 13, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - dense_200_accuracy: 0.4977 - dense_202_accuracy: 0.7111 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.6903 - dense_208_accuracy: 0.7436 - dense_210_accuracy: 0.7970 - dense_212_accuracy: 0.6148 - dense_214_accuracy: 0.5777 - dense_216_accuracy: 0.8074 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8666 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.5719 - dense_230_accuracy: 0.8504 - loss: 10.6227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 14, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - dense_200_accuracy: 0.5081 - dense_202_accuracy: 0.7274 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.6903 - dense_208_accuracy: 0.7436 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6044 - dense_214_accuracy: 0.6148 - dense_216_accuracy: 0.8074 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8666 - dense_222_accuracy: 0.7007 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8133 - dense_228_accuracy: 0.5452 - dense_230_accuracy: 0.8399 - loss: 10.3616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# k: 15, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - dense_200_accuracy: 0.5244 - dense_202_accuracy: 0.7332 - dense_204_accuracy: 0.8933 - dense_206_accuracy: 0.7378 - dense_208_accuracy: 0.7436 - dense_210_accuracy: 0.7970 - dense_212_accuracy: 0.5732 - dense_214_accuracy: 0.5244 - dense_216_accuracy: 0.7970 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8666 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7170 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.5511 - dense_230_accuracy: 0.8399 - loss: 10.4832
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# k: 16, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - dense_200_accuracy: 0.6090 - dense_202_accuracy: 0.7215 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.7215 - dense_208_accuracy: 0.7436 - dense_210_accuracy: 0.7970 - dense_212_accuracy: 0.6207 - dense_214_accuracy: 0.6369 - dense_216_accuracy: 0.8074 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.8770 - dense_222_accuracy: 0.6903 - dense_224_accuracy: 0.7170 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.6578 - dense_230_accuracy: 0.8399 - loss: 9.9400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# k: 17, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - dense_200_accuracy: 0.5511 - dense_202_accuracy: 0.7274 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.7586 - dense_208_accuracy: 0.7541 - dense_210_accuracy: 0.7970 - dense_212_accuracy: 0.6044 - dense_214_accuracy: 0.6148 - dense_216_accuracy: 0.7970 - dense_218_accuracy: 0.8712 - dense_220_accuracy: 0.8770 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.5836 - dense_230_accuracy: 0.8504 - loss: 9.8345
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 18, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - dense_200_accuracy: 0.5511 - dense_202_accuracy: 0.7274 - dense_204_accuracy: 0.8933 - dense_206_accuracy: 0.7749 - dense_208_accuracy: 0.7645 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6253 - dense_214_accuracy: 0.5940 - dense_216_accuracy: 0.8074 - dense_218_accuracy: 0.8712 - dense_220_accuracy: 0.8770 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.5986 - dense_230_accuracy: 0.8504 - loss: 9.3649
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 19, patience: 10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - dense_200_accuracy: 0.5615 - dense_202_accuracy: 0.8341 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.7866 - dense_208_accuracy: 0.7436 - dense_210_accuracy: 0.7866 - dense_212_accuracy: 0.6265 - dense_214_accuracy: 0.5777 - dense_216_accuracy: 0.8133 - dense_218_accuracy: 0.8399 - dense_220_accuracy: 0.8666 - dense_222_accuracy: 0.7007 - dense_224_accuracy: 0.7378 - dense_226_accuracy: 0.8133 - dense_228_accuracy: 0.5882 - dense_230_accuracy: 0.8399 - loss: 9.7468
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# k: 20, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - dense_200_accuracy: 0.6253 - dense_202_accuracy: 0.8237 - dense_204_accuracy: 0.8933 - dense_206_accuracy: 0.7541 - dense_208_accuracy: 0.7970 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6578 - dense_214_accuracy: 0.5986 - dense_216_accuracy: 0.8504 - dense_218_accuracy: 0.8399 - dense_220_accuracy: 0.8874 - dense_222_accuracy: 0.7215 - dense_224_accuracy: 0.7378 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.5777 - dense_230_accuracy: 0.8608 - loss: 8.9448
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 21, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - dense_200_accuracy: 0.5615 - dense_202_accuracy: 0.7970 - dense_204_accuracy: 0.8933 - dense_206_accuracy: 0.7436 - dense_208_accuracy: 0.7703 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6207 - dense_214_accuracy: 0.5986 - dense_216_accuracy: 0.8133 - dense_218_accuracy: 0.8399 - dense_220_accuracy: 0.8874 - dense_222_accuracy: 0.7007 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.5719 - dense_230_accuracy: 0.8504 - loss: 9.1486
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# k: 22, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - dense_200_accuracy: 0.5556 - dense_202_accuracy: 0.8237 - dense_204_accuracy: 0.9037 - dense_206_accuracy: 0.7111 - dense_208_accuracy: 0.8074 - dense_210_accuracy: 0.8283 - dense_212_accuracy: 0.7053 - dense_214_accuracy: 0.5986 - dense_216_accuracy: 0.8237 - dense_218_accuracy: 0.8874 - dense_220_accuracy: 0.9037 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7274 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.5986 - dense_230_accuracy: 0.8712 - loss: 8.3818
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# k: 23, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - dense_200_accuracy: 0.5511 - dense_202_accuracy: 0.8504 - dense_204_accuracy: 0.8933 - dense_206_accuracy: 0.7436 - dense_208_accuracy: 0.8237 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6740 - dense_214_accuracy: 0.6474 - dense_216_accuracy: 0.8399 - dense_218_accuracy: 0.8399 - dense_220_accuracy: 0.9466 - dense_222_accuracy: 0.7170 - dense_224_accuracy: 0.7170 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.5673 - dense_230_accuracy: 0.8504 - loss: 8.4254
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# k: 24, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - dense_200_accuracy: 0.6148 - dense_202_accuracy: 0.8341 - dense_204_accuracy: 0.8933 - dense_206_accuracy: 0.8178 - dense_208_accuracy: 0.8074 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.7007 - dense_214_accuracy: 0.6845 - dense_216_accuracy: 0.8666 - dense_218_accuracy: 0.8770 - dense_220_accuracy: 0.9466 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7482 - dense_226_accuracy: 0.8341 - dense_228_accuracy: 0.6740 - dense_230_accuracy: 0.8504 - loss: 8.5555
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# k: 25, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - dense_200_accuracy: 0.5394 - dense_202_accuracy: 0.8770 - dense_204_accuracy: 0.9200 - dense_206_accuracy: 0.7807 - dense_208_accuracy: 0.7912 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6786 - dense_214_accuracy: 0.5127 - dense_216_accuracy: 0.8504 - dense_218_accuracy: 0.8608 - dense_220_accuracy: 0.9571 - dense_222_accuracy: 0.7111 - dense_224_accuracy: 0.7645 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.6845 - dense_230_accuracy: 0.8874 - loss: 8.2051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# k: 26, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - dense_200_accuracy: 0.6148 - dense_202_accuracy: 0.8237 - dense_204_accuracy: 0.9304 - dense_206_accuracy: 0.7541 - dense_208_accuracy: 0.8341 - dense_210_accuracy: 0.7970 - dense_212_accuracy: 0.7007 - dense_214_accuracy: 0.6148 - dense_216_accuracy: 0.8608 - dense_218_accuracy: 0.8608 - dense_220_accuracy: 0.8933 - dense_222_accuracy: 0.7007 - dense_224_accuracy: 0.7378 - dense_226_accuracy: 0.8133 - dense_228_accuracy: 0.6578 - dense_230_accuracy: 0.8770 - loss: 8.0250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 27, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - dense_200_accuracy: 0.6474 - dense_202_accuracy: 0.8399 - dense_204_accuracy: 0.9466 - dense_206_accuracy: 0.8770 - dense_208_accuracy: 0.8666 - dense_210_accuracy: 0.8074 - dense_212_accuracy: 0.6903 - dense_214_accuracy: 0.6578 - dense_216_accuracy: 0.8933 - dense_218_accuracy: 0.8666 - dense_220_accuracy: 0.9733 - dense_222_accuracy: 0.7436 - dense_224_accuracy: 0.7436 - dense_226_accuracy: 0.8237 - dense_228_accuracy: 0.6903 - dense_230_accuracy: 0.8874 - loss: 7.8085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# k: 28, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - dense_200_accuracy: 0.6682 - dense_202_accuracy: 0.8504 - dense_204_accuracy: 0.9466 - dense_206_accuracy: 0.8933 - dense_208_accuracy: 0.8504 - dense_210_accuracy: 0.8283 - dense_212_accuracy: 0.7378 - dense_214_accuracy: 0.7215 - dense_216_accuracy: 0.9037 - dense_218_accuracy: 0.8874 - dense_220_accuracy: 0.9571 - dense_222_accuracy: 0.7912 - dense_224_accuracy: 0.7645 - dense_226_accuracy: 0.8874 - dense_228_accuracy: 0.7215 - dense_230_accuracy: 0.9141 - loss: 7.3541
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# k: 29, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - dense_200_accuracy: 0.6740 - dense_202_accuracy: 0.8504 - dense_204_accuracy: 0.9466 - dense_206_accuracy: 0.8074 - dense_208_accuracy: 0.8979 - dense_210_accuracy: 0.8341 - dense_212_accuracy: 0.7378 - dense_214_accuracy: 0.5986 - dense_216_accuracy: 0.9037 - dense_218_accuracy: 0.9245 - dense_220_accuracy: 0.9571 - dense_222_accuracy: 0.8178 - dense_224_accuracy: 0.7807 - dense_226_accuracy: 0.8608 - dense_228_accuracy: 0.6474 - dense_230_accuracy: 0.8666 - loss: 7.3651
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 30, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dense_200_accuracy: 0.6148 - dense_202_accuracy: 0.8178 - dense_204_accuracy: 0.9200 - dense_206_accuracy: 0.8133 - dense_208_accuracy: 0.9141 - dense_210_accuracy: 0.8445 - dense_212_accuracy: 0.7482 - dense_214_accuracy: 0.6786 - dense_216_accuracy: 0.9200 - dense_218_accuracy: 0.8666 - dense_220_accuracy: 0.9733 - dense_222_accuracy: 0.7703 - dense_224_accuracy: 0.7970 - dense_226_accuracy: 0.8504 - dense_228_accuracy: 0.6903 - dense_230_accuracy: 0.9304 - loss: 6.9789
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 31, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - dense_200_accuracy: 0.6474 - dense_202_accuracy: 0.8504 - dense_204_accuracy: 0.9733 - dense_206_accuracy: 0.8666 - dense_208_accuracy: 0.7970 - dense_210_accuracy: 0.8770 - dense_212_accuracy: 0.7170 - dense_214_accuracy: 0.6519 - dense_216_accuracy: 0.9571 - dense_218_accuracy: 0.9304 - dense_220_accuracy: 0.9733 - dense_222_accuracy: 0.7436 - dense_224_accuracy: 0.7970 - dense_226_accuracy: 0.8933 - dense_228_accuracy: 0.7436 - dense_230_accuracy: 0.8933 - loss: 7.0985
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 32, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - dense_200_accuracy: 0.6311 - dense_202_accuracy: 0.8237 - dense_204_accuracy: 0.9733 - dense_206_accuracy: 0.8666 - dense_208_accuracy: 0.7970 - dense_210_accuracy: 0.8770 - dense_212_accuracy: 0.7541 - dense_214_accuracy: 0.7215 - dense_216_accuracy: 0.9466 - dense_218_accuracy: 0.9037 - dense_220_accuracy: 0.9733 - dense_222_accuracy: 0.8237 - dense_224_accuracy: 0.8074 - dense_226_accuracy: 0.8933 - dense_228_accuracy: 0.7599 - dense_230_accuracy: 0.9037 - loss: 6.6411
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# k: 33, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - dense_200_accuracy: 0.6740 - dense_202_accuracy: 0.8237 - dense_204_accuracy: 0.9733 - dense_206_accuracy: 0.8074 - dense_208_accuracy: 0.8874 - dense_210_accuracy: 0.8770 - dense_212_accuracy: 0.7274 - dense_214_accuracy: 0.6740 - dense_216_accuracy: 0.9571 - dense_218_accuracy: 0.8770 - dense_220_accuracy: 0.9571 - dense_222_accuracy: 0.7586 - dense_224_accuracy: 0.7807 - dense_226_accuracy: 0.8770 - dense_228_accuracy: 0.7703 - dense_230_accuracy: 0.9037 - loss: 6.6231
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 34, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - dense_200_accuracy: 0.6949 - dense_202_accuracy: 0.8237 - dense_204_accuracy: 0.9733 - dense_206_accuracy: 0.8504 - dense_208_accuracy: 0.8504 - dense_210_accuracy: 0.9304 - dense_212_accuracy: 0.7912 - dense_214_accuracy: 0.7170 - dense_216_accuracy: 0.9200 - dense_218_accuracy: 0.8504 - dense_220_accuracy: 0.9733 - dense_222_accuracy: 0.7853 - dense_224_accuracy: 0.7970 - dense_226_accuracy: 0.9037 - dense_228_accuracy: 0.8074 - dense_230_accuracy: 0.8770 - loss: 6.2439
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 35, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - dense_200_accuracy: 0.7378 - dense_202_accuracy: 0.8504 - dense_204_accuracy: 0.9733 - dense_206_accuracy: 0.8874 - dense_208_accuracy: 0.8770 - dense_210_accuracy: 0.9037 - dense_212_accuracy: 0.7970 - dense_214_accuracy: 0.7215 - dense_216_accuracy: 0.9200 - dense_218_accuracy: 0.9304 - dense_220_accuracy: 1.0000 - dense_222_accuracy: 0.8283 - dense_224_accuracy: 0.8445 - dense_226_accuracy: 0.9200 - dense_228_accuracy: 0.7970 - dense_230_accuracy: 0.9141 - loss: 6.0249
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 36, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - dense_200_accuracy: 0.7007 - dense_202_accuracy: 0.8237 - dense_204_accuracy: 0.9837 - dense_206_accuracy: 0.8874 - dense_208_accuracy: 0.9037 - dense_210_accuracy: 0.8712 - dense_212_accuracy: 0.7807 - dense_214_accuracy: 0.7541 - dense_216_accuracy: 0.9571 - dense_218_accuracy: 0.9408 - dense_220_accuracy: 1.0000 - dense_222_accuracy: 0.8074 - dense_224_accuracy: 0.8549 - dense_226_accuracy: 0.8933 - dense_228_accuracy: 0.7970 - dense_230_accuracy: 0.9200 - loss: 6.1431
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# k: 37, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - dense_200_accuracy: 0.6682 - dense_202_accuracy: 0.8341 - dense_204_accuracy: 0.9571 - dense_206_accuracy: 0.8237 - dense_208_accuracy: 0.9037 - dense_210_accuracy: 0.9037 - dense_212_accuracy: 0.7970 - dense_214_accuracy: 0.7645 - dense_216_accuracy: 0.9466 - dense_218_accuracy: 0.9408 - dense_220_accuracy: 0.9837 - dense_222_accuracy: 0.7703 - dense_224_accuracy: 0.8341 - dense_226_accuracy: 0.9200 - dense_228_accuracy: 0.7703 - dense_230_accuracy: 0.9037 - loss: 5.8149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 38, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - dense_200_accuracy: 0.6578 - dense_202_accuracy: 0.8770 - dense_204_accuracy: 0.9733 - dense_206_accuracy: 0.7599 - dense_208_accuracy: 0.8666 - dense_210_accuracy: 0.9200 - dense_212_accuracy: 0.8133 - dense_214_accuracy: 0.7274 - dense_216_accuracy: 0.9304 - dense_218_accuracy: 0.8933 - dense_220_accuracy: 0.9733 - dense_222_accuracy: 0.8504 - dense_224_accuracy: 0.8445 - dense_226_accuracy: 0.9466 - dense_228_accuracy: 0.7378 - dense_230_accuracy: 0.9200 - loss: 5.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 39, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - dense_200_accuracy: 0.7599 - dense_202_accuracy: 0.8770 - dense_204_accuracy: 0.9733 - dense_206_accuracy: 0.8770 - dense_208_accuracy: 0.8933 - dense_210_accuracy: 0.9200 - dense_212_accuracy: 0.8178 - dense_214_accuracy: 0.7436 - dense_216_accuracy: 0.9200 - dense_218_accuracy: 0.9466 - dense_220_accuracy: 0.9733 - dense_222_accuracy: 0.7807 - dense_224_accuracy: 0.8666 - dense_226_accuracy: 0.9571 - dense_228_accuracy: 0.7807 - dense_230_accuracy: 0.8874 - loss: 5.2989
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 40, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - dense_200_accuracy: 0.7053 - dense_202_accuracy: 0.8237 - dense_204_accuracy: 0.9733 - dense_206_accuracy: 0.8237 - dense_208_accuracy: 0.9466 - dense_210_accuracy: 0.8933 - dense_212_accuracy: 0.7912 - dense_214_accuracy: 0.6845 - dense_216_accuracy: 0.9466 - dense_218_accuracy: 0.8770 - dense_220_accuracy: 0.9837 - dense_222_accuracy: 0.7703 - dense_224_accuracy: 0.8504 - dense_226_accuracy: 0.9571 - dense_228_accuracy: 0.7599 - dense_230_accuracy: 0.8979 - loss: 5.3831
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# k: 41, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dense_200_accuracy: 0.6578 - dense_202_accuracy: 0.8666 - dense_204_accuracy: 0.9733 - dense_206_accuracy: 0.8399 - dense_208_accuracy: 0.9466 - dense_210_accuracy: 0.9304 - dense_212_accuracy: 0.8133 - dense_214_accuracy: 0.7274 - dense_216_accuracy: 0.9304 - dense_218_accuracy: 0.9037 - dense_220_accuracy: 1.0000 - dense_222_accuracy: 0.7970 - dense_224_accuracy: 0.8341 - dense_226_accuracy: 0.9733 - dense_228_accuracy: 0.7866 - dense_230_accuracy: 0.9200 - loss: 5.0866
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 42, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - dense_200_accuracy: 0.7541 - dense_202_accuracy: 0.8874 - dense_204_accuracy: 1.0000 - dense_206_accuracy: 0.9466 - dense_208_accuracy: 0.9466 - dense_210_accuracy: 0.9304 - dense_212_accuracy: 0.8074 - dense_214_accuracy: 0.7436 - dense_216_accuracy: 0.9304 - dense_218_accuracy: 0.9200 - dense_220_accuracy: 1.0000 - dense_222_accuracy: 0.8504 - dense_224_accuracy: 0.8133 - dense_226_accuracy: 1.0000 - dense_228_accuracy: 0.7274 - dense_230_accuracy: 0.9733 - loss: 4.8626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 43, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - dense_200_accuracy: 0.7007 - dense_202_accuracy: 0.8933 - dense_204_accuracy: 0.9837 - dense_206_accuracy: 0.9037 - dense_208_accuracy: 0.9304 - dense_210_accuracy: 0.9571 - dense_212_accuracy: 0.8074 - dense_214_accuracy: 0.6949 - dense_216_accuracy: 0.9408 - dense_218_accuracy: 0.8933 - dense_220_accuracy: 1.0000 - dense_222_accuracy: 0.8608 - dense_224_accuracy: 0.8237 - dense_226_accuracy: 1.0000 - dense_228_accuracy: 0.8074 - dense_230_accuracy: 0.9571 - loss: 4.7876
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 44, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - dense_200_accuracy: 0.7378 - dense_202_accuracy: 0.8608 - dense_204_accuracy: 0.9733 - dense_206_accuracy: 0.8770 - dense_208_accuracy: 0.9200 - dense_210_accuracy: 0.9571 - dense_212_accuracy: 0.8178 - dense_214_accuracy: 0.7970 - dense_216_accuracy: 0.9466 - dense_218_accuracy: 0.8933 - dense_220_accuracy: 1.0000 - dense_222_accuracy: 0.8178 - dense_224_accuracy: 0.8237 - dense_226_accuracy: 1.0000 - dense_228_accuracy: 0.8074 - dense_230_accuracy: 0.9037 - loss: 4.6530
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# k: 45, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# Test Loss iteration 1: 35.46667288757554
# Iteration 3
# global_indices [[12, 3, 11, 1, 5, 2], [7, 10, 8, 3, 6, 5], [2, 5, 4, 11, 7, 8], [5, 1, 0, 7], [6, 7, 5, 15, 8, 1]]
# input_train : (41, 120, 47)
# output_train : (41, 16, 4)
# input_val : (13, 120, 47)
# output_val : (13, 16, 4)
# input_test : (14, 120, 47)
# output_test : (14, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 103ms/step - dense_233_accuracy: 0.3747 - dense_235_accuracy: 0.2193 - dense_237_accuracy: 0.3435 - dense_239_accuracy: 0.3214 - dense_241_accuracy: 0.1555 - dense_243_accuracy: 0.5140 - dense_245_accuracy: 0.2355 - dense_247_accuracy: 0.1555 - dense_249_accuracy: 0.5302 - dense_251_accuracy: 0.1405 - dense_253_accuracy: 0.6103 - dense_255_accuracy: 0.2251 - dense_257_accuracy: 0.2843 - dense_259_accuracy: 0.2472 - dense_261_accuracy: 0.2088 - dense_263_accuracy: 0.1939 - loss: 22.2324
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# k: 0, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - dense_233_accuracy: 0.5023 - dense_235_accuracy: 0.8283 - dense_237_accuracy: 0.9037 - dense_239_accuracy: 0.6148 - dense_241_accuracy: 0.7378 - dense_243_accuracy: 0.8178 - dense_245_accuracy: 0.5244 - dense_247_accuracy: 0.6148 - dense_249_accuracy: 0.8445 - dense_251_accuracy: 0.8237 - dense_253_accuracy: 0.9304 - dense_255_accuracy: 0.7645 - dense_257_accuracy: 0.7111 - dense_259_accuracy: 0.9408 - dense_261_accuracy: 0.4919 - dense_263_accuracy: 0.9037 - loss: 18.0291
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 1, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - dense_233_accuracy: 0.4652 - dense_235_accuracy: 0.8074 - dense_237_accuracy: 0.8933 - dense_239_accuracy: 0.6044 - dense_241_accuracy: 0.7170 - dense_243_accuracy: 0.7970 - dense_245_accuracy: 0.5777 - dense_247_accuracy: 0.5940 - dense_249_accuracy: 0.8133 - dense_251_accuracy: 0.8237 - dense_253_accuracy: 0.9200 - dense_255_accuracy: 0.7599 - dense_257_accuracy: 0.6903 - dense_259_accuracy: 0.9304 - dense_261_accuracy: 0.4977 - dense_263_accuracy: 0.8933 - loss: 14.3804
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# k: 2, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - dense_233_accuracy: 0.4756 - dense_235_accuracy: 0.7970 - dense_237_accuracy: 0.8933 - dense_239_accuracy: 0.6357 - dense_241_accuracy: 0.7274 - dense_243_accuracy: 0.7970 - dense_245_accuracy: 0.5882 - dense_247_accuracy: 0.6148 - dense_249_accuracy: 0.8237 - dense_251_accuracy: 0.8341 - dense_253_accuracy: 0.9200 - dense_255_accuracy: 0.7703 - dense_257_accuracy: 0.7007 - dense_259_accuracy: 0.9200 - dense_261_accuracy: 0.5452 - dense_263_accuracy: 0.8933 - loss: 12.3898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 3, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - dense_233_accuracy: 0.4385 - dense_235_accuracy: 0.8074 - dense_237_accuracy: 0.9037 - dense_239_accuracy: 0.6044 - dense_241_accuracy: 0.7274 - dense_243_accuracy: 0.8178 - dense_245_accuracy: 0.5569 - dense_247_accuracy: 0.6148 - dense_249_accuracy: 0.8341 - dense_251_accuracy: 0.8237 - dense_253_accuracy: 0.9200 - dense_255_accuracy: 0.7703 - dense_257_accuracy: 0.7111 - dense_259_accuracy: 0.9200 - dense_261_accuracy: 0.5348 - dense_263_accuracy: 0.8933 - loss: 12.5954
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 4, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - dense_233_accuracy: 0.4223 - dense_235_accuracy: 0.8178 - dense_237_accuracy: 0.9037 - dense_239_accuracy: 0.6148 - dense_241_accuracy: 0.7274 - dense_243_accuracy: 0.8178 - dense_245_accuracy: 0.5986 - dense_247_accuracy: 0.5940 - dense_249_accuracy: 0.8341 - dense_251_accuracy: 0.8341 - dense_253_accuracy: 0.9304 - dense_255_accuracy: 0.7703 - dense_257_accuracy: 0.7007 - dense_259_accuracy: 0.9200 - dense_261_accuracy: 0.5348 - dense_263_accuracy: 0.8933 - loss: 12.7839
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# k: 5, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - dense_233_accuracy: 0.3852 - dense_235_accuracy: 0.7866 - dense_237_accuracy: 0.8933 - dense_239_accuracy: 0.6148 - dense_241_accuracy: 0.7378 - dense_243_accuracy: 0.8074 - dense_245_accuracy: 0.5777 - dense_247_accuracy: 0.6253 - dense_249_accuracy: 0.8341 - dense_251_accuracy: 0.8237 - dense_253_accuracy: 0.9200 - dense_255_accuracy: 0.7912 - dense_257_accuracy: 0.7215 - dense_259_accuracy: 0.9200 - dense_261_accuracy: 0.5823 - dense_263_accuracy: 0.9037 - loss: 12.2617
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# k: 6, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - dense_233_accuracy: 0.5185 - dense_235_accuracy: 0.8074 - dense_237_accuracy: 0.8933 - dense_239_accuracy: 0.4919 - dense_241_accuracy: 0.7274 - dense_243_accuracy: 0.8178 - dense_245_accuracy: 0.6044 - dense_247_accuracy: 0.6253 - dense_249_accuracy: 0.8237 - dense_251_accuracy: 0.8237 - dense_253_accuracy: 0.9304 - dense_255_accuracy: 0.7807 - dense_257_accuracy: 0.7320 - dense_259_accuracy: 0.9304 - dense_261_accuracy: 0.5452 - dense_263_accuracy: 0.9037 - loss: 11.6588
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 7, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - dense_233_accuracy: 0.5140 - dense_235_accuracy: 0.8074 - dense_237_accuracy: 0.9037 - dense_239_accuracy: 0.4652 - dense_241_accuracy: 0.7274 - dense_243_accuracy: 0.8074 - dense_245_accuracy: 0.5244 - dense_247_accuracy: 0.6044 - dense_249_accuracy: 0.8237 - dense_251_accuracy: 0.8237 - dense_253_accuracy: 0.9304 - dense_255_accuracy: 0.7912 - dense_257_accuracy: 0.7482 - dense_259_accuracy: 0.9304 - dense_261_accuracy: 0.5452 - dense_263_accuracy: 0.9037 - loss: 11.1056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 8, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - dense_233_accuracy: 0.5348 - dense_235_accuracy: 0.7866 - dense_237_accuracy: 0.9037 - dense_239_accuracy: 0.6682 - dense_241_accuracy: 0.7170 - dense_243_accuracy: 0.7866 - dense_245_accuracy: 0.5615 - dense_247_accuracy: 0.6044 - dense_249_accuracy: 0.8133 - dense_251_accuracy: 0.8237 - dense_253_accuracy: 0.9200 - dense_255_accuracy: 0.7807 - dense_257_accuracy: 0.7274 - dense_259_accuracy: 0.9304 - dense_261_accuracy: 0.5081 - dense_263_accuracy: 0.8933 - loss: 11.4844
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 9, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - dense_233_accuracy: 0.4652 - dense_235_accuracy: 0.8341 - dense_237_accuracy: 0.9037 - dense_239_accuracy: 0.6357 - dense_241_accuracy: 0.7645 - dense_243_accuracy: 0.7970 - dense_245_accuracy: 0.5673 - dense_247_accuracy: 0.5940 - dense_249_accuracy: 0.8341 - dense_251_accuracy: 0.8445 - dense_253_accuracy: 0.9304 - dense_255_accuracy: 0.7703 - dense_257_accuracy: 0.7007 - dense_259_accuracy: 0.9408 - dense_261_accuracy: 0.4977 - dense_263_accuracy: 0.9037 - loss: 10.8150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 10, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - dense_233_accuracy: 0.4548 - dense_235_accuracy: 0.8178 - dense_237_accuracy: 0.8933 - dense_239_accuracy: 0.6044 - dense_241_accuracy: 0.7170 - dense_243_accuracy: 0.7866 - dense_245_accuracy: 0.5882 - dense_247_accuracy: 0.5836 - dense_249_accuracy: 0.8133 - dense_251_accuracy: 0.8133 - dense_253_accuracy: 0.9304 - dense_255_accuracy: 0.7807 - dense_257_accuracy: 0.7170 - dense_259_accuracy: 0.9200 - dense_261_accuracy: 0.5036 - dense_263_accuracy: 0.8933 - loss: 11.2642
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 11, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# Test Loss iteration 2: 37.838218396597
# Iteration 4
# global_indices [[12, 3, 11, 1, 5, 2, 9, 4, 0], [7, 10, 8, 3, 6, 5, 2, 1, 11], [2, 5, 4, 11, 7, 8, 9, 1, 6], [5, 1, 0, 7, 4, 3], [6, 7, 5, 15, 8, 1, 14, 3, 9]]
# input_train : (41, 120, 47)
# output_train : (41, 16, 4)
# input_val : (14, 120, 47)
# output_val : (14, 16, 4)
# input_test : (13, 120, 47)
# output_test : (13, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - dense_266_accuracy: 0.3956 - dense_268_accuracy: 0.3585 - dense_270_accuracy: 0.2576 - dense_272_accuracy: 0.0755 - dense_274_accuracy: 0.2088 - dense_276_accuracy: 0.2414 - dense_278_accuracy: 0.6357 - dense_280_accuracy: 0.4548 - dense_282_accuracy: 0.1822 - dense_284_accuracy: 0.3702 - dense_286_accuracy: 0.5244 - dense_288_accuracy: 0.1288 - dense_290_accuracy: 0.3852 - dense_292_accuracy: 0.2576 - dense_294_accuracy: 0.1288 - dense_296_accuracy: 0.7482 - loss: 21.8543
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 792ms/step
# k: 0, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - dense_266_accuracy: 0.5140 - dense_268_accuracy: 0.6311 - dense_270_accuracy: 0.9304 - dense_272_accuracy: 0.6311 - dense_274_accuracy: 0.7215 - dense_276_accuracy: 0.7703 - dense_278_accuracy: 0.5940 - dense_280_accuracy: 0.6474 - dense_282_accuracy: 0.6740 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8399 - dense_288_accuracy: 0.7703 - dense_290_accuracy: 0.7436 - dense_292_accuracy: 0.8399 - dense_294_accuracy: 0.4873 - dense_296_accuracy: 0.8399 - loss: 17.9059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# k: 1, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - dense_266_accuracy: 0.5348 - dense_268_accuracy: 0.7007 - dense_270_accuracy: 0.9200 - dense_272_accuracy: 0.6044 - dense_274_accuracy: 0.7170 - dense_276_accuracy: 0.7807 - dense_278_accuracy: 0.5836 - dense_280_accuracy: 0.6578 - dense_282_accuracy: 0.7807 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8504 - dense_288_accuracy: 0.7807 - dense_290_accuracy: 0.7541 - dense_292_accuracy: 0.8504 - dense_294_accuracy: 0.4873 - dense_296_accuracy: 0.8504 - loss: 14.4922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 2, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - dense_266_accuracy: 0.5244 - dense_268_accuracy: 0.7111 - dense_270_accuracy: 0.9200 - dense_272_accuracy: 0.6044 - dense_274_accuracy: 0.7274 - dense_276_accuracy: 0.7807 - dense_278_accuracy: 0.6044 - dense_280_accuracy: 0.6474 - dense_282_accuracy: 0.7912 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8504 - dense_288_accuracy: 0.7807 - dense_290_accuracy: 0.7436 - dense_292_accuracy: 0.8504 - dense_294_accuracy: 0.5244 - dense_296_accuracy: 0.8504 - loss: 12.6720
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 3, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - dense_266_accuracy: 0.5140 - dense_268_accuracy: 0.6903 - dense_270_accuracy: 0.9200 - dense_272_accuracy: 0.6044 - dense_274_accuracy: 0.7274 - dense_276_accuracy: 0.7599 - dense_278_accuracy: 0.5836 - dense_280_accuracy: 0.6369 - dense_282_accuracy: 0.7807 - dense_284_accuracy: 0.8666 - dense_286_accuracy: 0.8399 - dense_288_accuracy: 0.7703 - dense_290_accuracy: 0.7332 - dense_292_accuracy: 0.8399 - dense_294_accuracy: 0.5036 - dense_296_accuracy: 0.8399 - loss: 13.5046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 4, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - dense_266_accuracy: 0.5348 - dense_268_accuracy: 0.7007 - dense_270_accuracy: 0.9200 - dense_272_accuracy: 0.6253 - dense_274_accuracy: 0.7274 - dense_276_accuracy: 0.7807 - dense_278_accuracy: 0.6044 - dense_280_accuracy: 0.6474 - dense_282_accuracy: 0.7807 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8608 - dense_288_accuracy: 0.7807 - dense_290_accuracy: 0.7541 - dense_292_accuracy: 0.8712 - dense_294_accuracy: 0.5244 - dense_296_accuracy: 0.8608 - loss: 13.2242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 5, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - dense_266_accuracy: 0.6253 - dense_268_accuracy: 0.7215 - dense_270_accuracy: 0.9304 - dense_272_accuracy: 0.6623 - dense_274_accuracy: 0.7482 - dense_276_accuracy: 0.7912 - dense_278_accuracy: 0.6357 - dense_280_accuracy: 0.6786 - dense_282_accuracy: 0.7807 - dense_284_accuracy: 0.8874 - dense_286_accuracy: 0.8608 - dense_288_accuracy: 0.7912 - dense_290_accuracy: 0.7749 - dense_292_accuracy: 0.8608 - dense_294_accuracy: 0.5452 - dense_296_accuracy: 0.8504 - loss: 11.8347
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 6, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dense_266_accuracy: 0.4860 - dense_268_accuracy: 0.7111 - dense_270_accuracy: 0.9408 - dense_272_accuracy: 0.5673 - dense_274_accuracy: 0.7378 - dense_276_accuracy: 0.7807 - dense_278_accuracy: 0.5719 - dense_280_accuracy: 0.6682 - dense_282_accuracy: 0.7703 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8504 - dense_288_accuracy: 0.7912 - dense_290_accuracy: 0.7541 - dense_292_accuracy: 0.8504 - dense_294_accuracy: 0.5452 - dense_296_accuracy: 0.8608 - loss: 11.8065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 7, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - dense_266_accuracy: 0.4548 - dense_268_accuracy: 0.7111 - dense_270_accuracy: 0.9304 - dense_272_accuracy: 0.4815 - dense_274_accuracy: 0.7274 - dense_276_accuracy: 0.7703 - dense_278_accuracy: 0.6148 - dense_280_accuracy: 0.6578 - dense_282_accuracy: 0.7807 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8504 - dense_288_accuracy: 0.7807 - dense_290_accuracy: 0.7436 - dense_292_accuracy: 0.8504 - dense_294_accuracy: 0.5290 - dense_296_accuracy: 0.8504 - loss: 11.8983
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 8, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - dense_266_accuracy: 0.5452 - dense_268_accuracy: 0.6682 - dense_270_accuracy: 0.9200 - dense_272_accuracy: 0.4919 - dense_274_accuracy: 0.7320 - dense_276_accuracy: 0.7807 - dense_278_accuracy: 0.5823 - dense_280_accuracy: 0.7111 - dense_282_accuracy: 0.7807 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8608 - dense_288_accuracy: 0.7912 - dense_290_accuracy: 0.7645 - dense_292_accuracy: 0.8608 - dense_294_accuracy: 0.5081 - dense_296_accuracy: 0.8504 - loss: 11.7839
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 9, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - dense_266_accuracy: 0.5452 - dense_268_accuracy: 0.6903 - dense_270_accuracy: 0.9408 - dense_272_accuracy: 0.7111 - dense_274_accuracy: 0.7170 - dense_276_accuracy: 0.7703 - dense_278_accuracy: 0.6103 - dense_280_accuracy: 0.6740 - dense_282_accuracy: 0.7703 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8399 - dense_288_accuracy: 0.7599 - dense_290_accuracy: 0.7541 - dense_292_accuracy: 0.8399 - dense_294_accuracy: 0.5185 - dense_296_accuracy: 0.8399 - loss: 11.8329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 10, patience: 1
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# k: 13, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - dense_266_accuracy: 0.5452 - dense_268_accuracy: 0.7111 - dense_270_accuracy: 0.9200 - dense_272_accuracy: 0.6461 - dense_274_accuracy: 0.7482 - dense_276_accuracy: 0.7703 - dense_278_accuracy: 0.6461 - dense_280_accuracy: 0.6682 - dense_282_accuracy: 0.7703 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8504 - dense_288_accuracy: 0.7912 - dense_290_accuracy: 0.7645 - dense_292_accuracy: 0.8504 - dense_294_accuracy: 0.5348 - dense_296_accuracy: 0.8504 - loss: 10.7661
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# k: 14, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - dense_266_accuracy: 0.5927 - dense_268_accuracy: 0.7320 - dense_270_accuracy: 0.9408 - dense_272_accuracy: 0.6148 - dense_274_accuracy: 0.7378 - dense_276_accuracy: 0.8016 - dense_278_accuracy: 0.6357 - dense_280_accuracy: 0.6890 - dense_282_accuracy: 0.7807 - dense_284_accuracy: 0.8874 - dense_286_accuracy: 0.8712 - dense_288_accuracy: 0.7912 - dense_290_accuracy: 0.7749 - dense_292_accuracy: 0.8712 - dense_294_accuracy: 0.5661 - dense_296_accuracy: 0.8608 - loss: 10.2134
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 15, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - dense_266_accuracy: 0.6357 - dense_268_accuracy: 0.7215 - dense_270_accuracy: 0.9304 - dense_272_accuracy: 0.6253 - dense_274_accuracy: 0.7274 - dense_276_accuracy: 0.7807 - dense_278_accuracy: 0.6148 - dense_280_accuracy: 0.6578 - dense_282_accuracy: 0.7703 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8504 - dense_288_accuracy: 0.7807 - dense_290_accuracy: 0.7541 - dense_292_accuracy: 0.8504 - dense_294_accuracy: 0.5882 - dense_296_accuracy: 0.8504 - loss: 10.4498
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 16, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - dense_266_accuracy: 0.6623 - dense_268_accuracy: 0.8237 - dense_270_accuracy: 0.9200 - dense_272_accuracy: 0.6207 - dense_274_accuracy: 0.7378 - dense_276_accuracy: 0.7703 - dense_278_accuracy: 0.6148 - dense_280_accuracy: 0.6740 - dense_282_accuracy: 0.7807 - dense_284_accuracy: 0.8666 - dense_286_accuracy: 0.8399 - dense_288_accuracy: 0.7703 - dense_290_accuracy: 0.7436 - dense_292_accuracy: 0.8399 - dense_294_accuracy: 0.5348 - dense_296_accuracy: 0.8399 - loss: 10.6846
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 17, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - dense_266_accuracy: 0.5882 - dense_268_accuracy: 0.9037 - dense_270_accuracy: 0.9304 - dense_272_accuracy: 0.7111 - dense_274_accuracy: 0.7170 - dense_276_accuracy: 0.7807 - dense_278_accuracy: 0.6148 - dense_280_accuracy: 0.6949 - dense_282_accuracy: 0.7807 - dense_284_accuracy: 0.8770 - dense_286_accuracy: 0.8504 - dense_288_accuracy: 0.7703 - dense_290_accuracy: 0.7541 - dense_292_accuracy: 0.8504 - dense_294_accuracy: 0.5452 - dense_296_accuracy: 0.8608 - loss: 10.5085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# k: 18, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - dense_266_accuracy: 0.5719 - dense_268_accuracy: 0.8283 - dense_270_accuracy: 0.9200 - dense_272_accuracy: 0.6636 - dense_274_accuracy: 0.7482 - dense_276_accuracy: 0.8120 - dense_278_accuracy: 0.6415 - dense_280_accuracy: 0.6786 - dense_282_accuracy: 0.8016 - dense_284_accuracy: 0.8666 - dense_286_accuracy: 0.8712 - dense_288_accuracy: 0.8016 - dense_290_accuracy: 0.7749 - dense_292_accuracy: 0.8712 - dense_294_accuracy: 0.6194 - dense_296_accuracy: 0.8608 - loss: 9.9887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# k: 19, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# Test Loss iteration 3: 33.20946343346218
# Iteration 5
# global_indices [[12, 3, 11, 1, 5, 2, 9, 4, 0, 6, 10, 8], [7, 10, 8, 3, 6, 5, 2, 1, 11, 0, 13, 12], [2, 5, 4, 11, 7, 8, 9, 1, 6, 0, 12], [5, 1, 0, 7, 4, 3, 2, 8], [6, 7, 5, 15, 8, 1, 14, 3, 9, 12, 0, 2]]
# input_train : (41, 120, 47)
# output_train : (41, 16, 4)
# input_val : (14, 120, 47)
# output_val : (14, 16, 4)
# input_test : (13, 120, 47)
# output_test : (13, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 94ms/step - dense_299_accuracy: 0.2414 - dense_301_accuracy: 0.4548 - dense_303_accuracy: 0.1880 - dense_305_accuracy: 0.0650 - dense_307_accuracy: 0.2355 - dense_309_accuracy: 0.3168 - dense_311_accuracy: 0.3910 - dense_313_accuracy: 0.2726 - dense_315_accuracy: 0.1138 - dense_317_accuracy: 0.0917 - dense_319_accuracy: 0.3864 - dense_321_accuracy: 0.2030 - dense_323_accuracy: 0.0650 - dense_325_accuracy: 0.8237 - dense_327_accuracy: 0.3526 - dense_329_accuracy: 0.1776 - loss: 22.0494
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# k: 0, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - dense_299_accuracy: 0.4118 - dense_301_accuracy: 0.7378 - dense_303_accuracy: 0.9304 - dense_305_accuracy: 0.6311 - dense_307_accuracy: 0.6311 - dense_309_accuracy: 0.8341 - dense_311_accuracy: 0.4977 - dense_313_accuracy: 0.6311 - dense_315_accuracy: 0.8074 - dense_317_accuracy: 0.8237 - dense_319_accuracy: 0.9304 - dense_321_accuracy: 0.5140 - dense_323_accuracy: 0.6740 - dense_325_accuracy: 0.9037 - dense_327_accuracy: 0.3155 - dense_329_accuracy: 0.8712 - loss: 17.9881
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 1, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - dense_299_accuracy: 0.4919 - dense_301_accuracy: 0.7586 - dense_303_accuracy: 0.9408 - dense_305_accuracy: 0.6682 - dense_307_accuracy: 0.6578 - dense_309_accuracy: 0.8341 - dense_311_accuracy: 0.5081 - dense_313_accuracy: 0.6090 - dense_315_accuracy: 0.8237 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9304 - dense_321_accuracy: 0.7853 - dense_323_accuracy: 0.7053 - dense_325_accuracy: 0.9037 - dense_327_accuracy: 0.3956 - dense_329_accuracy: 0.8608 - loss: 14.1393
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# k: 2, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - dense_299_accuracy: 0.4815 - dense_301_accuracy: 0.7274 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.6578 - dense_307_accuracy: 0.7215 - dense_309_accuracy: 0.8237 - dense_311_accuracy: 0.5081 - dense_313_accuracy: 0.5673 - dense_315_accuracy: 0.8237 - dense_317_accuracy: 0.8933 - dense_319_accuracy: 0.9200 - dense_321_accuracy: 0.7541 - dense_323_accuracy: 0.6845 - dense_325_accuracy: 0.8933 - dense_327_accuracy: 0.4652 - dense_329_accuracy: 0.8504 - loss: 11.8239
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# k: 3, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - dense_299_accuracy: 0.4593 - dense_301_accuracy: 0.7586 - dense_303_accuracy: 0.9304 - dense_305_accuracy: 0.6890 - dense_307_accuracy: 0.7320 - dense_309_accuracy: 0.8341 - dense_311_accuracy: 0.4977 - dense_313_accuracy: 0.5882 - dense_315_accuracy: 0.8341 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9304 - dense_321_accuracy: 0.7436 - dense_323_accuracy: 0.6740 - dense_325_accuracy: 0.9141 - dense_327_accuracy: 0.5081 - dense_329_accuracy: 0.8504 - loss: 11.4617
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 4, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - dense_299_accuracy: 0.5556 - dense_301_accuracy: 0.7378 - dense_303_accuracy: 0.9304 - dense_305_accuracy: 0.6474 - dense_307_accuracy: 0.7111 - dense_309_accuracy: 0.8341 - dense_311_accuracy: 0.4977 - dense_313_accuracy: 0.5777 - dense_315_accuracy: 0.8445 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9304 - dense_321_accuracy: 0.7645 - dense_323_accuracy: 0.6740 - dense_325_accuracy: 0.9037 - dense_327_accuracy: 0.4977 - dense_329_accuracy: 0.8399 - loss: 11.3028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 5, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - dense_299_accuracy: 0.5452 - dense_301_accuracy: 0.7378 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.6578 - dense_307_accuracy: 0.6845 - dense_309_accuracy: 0.8341 - dense_311_accuracy: 0.5081 - dense_313_accuracy: 0.5882 - dense_315_accuracy: 0.8341 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9408 - dense_321_accuracy: 0.7541 - dense_323_accuracy: 0.6740 - dense_325_accuracy: 0.9141 - dense_327_accuracy: 0.4815 - dense_329_accuracy: 0.8504 - loss: 10.9181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# k: 6, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - dense_299_accuracy: 0.4815 - dense_301_accuracy: 0.6903 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.5452 - dense_307_accuracy: 0.6949 - dense_309_accuracy: 0.8237 - dense_311_accuracy: 0.5140 - dense_313_accuracy: 0.5511 - dense_315_accuracy: 0.8341 - dense_317_accuracy: 0.8933 - dense_319_accuracy: 0.9304 - dense_321_accuracy: 0.7436 - dense_323_accuracy: 0.6903 - dense_325_accuracy: 0.9037 - dense_327_accuracy: 0.4444 - dense_329_accuracy: 0.8504 - loss: 10.9428
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# k: 7, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - dense_299_accuracy: 0.4014 - dense_301_accuracy: 0.6148 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.5511 - dense_307_accuracy: 0.6740 - dense_309_accuracy: 0.8341 - dense_311_accuracy: 0.4223 - dense_313_accuracy: 0.6415 - dense_315_accuracy: 0.8237 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9304 - dense_321_accuracy: 0.7541 - dense_323_accuracy: 0.6682 - dense_325_accuracy: 0.9141 - dense_327_accuracy: 0.4652 - dense_329_accuracy: 0.8399 - loss: 10.6024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# k: 8, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - dense_299_accuracy: 0.4223 - dense_301_accuracy: 0.7007 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.5777 - dense_307_accuracy: 0.6949 - dense_309_accuracy: 0.8341 - dense_311_accuracy: 0.4756 - dense_313_accuracy: 0.6728 - dense_315_accuracy: 0.8341 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9304 - dense_321_accuracy: 0.7645 - dense_323_accuracy: 0.6845 - dense_325_accuracy: 0.9037 - dense_327_accuracy: 0.4964 - dense_329_accuracy: 0.8712 - loss: 10.1126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 9, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - dense_299_accuracy: 0.5719 - dense_301_accuracy: 0.7170 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.6949 - dense_307_accuracy: 0.7007 - dense_309_accuracy: 0.8237 - dense_311_accuracy: 0.5185 - dense_313_accuracy: 0.5348 - dense_315_accuracy: 0.8237 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9200 - dense_321_accuracy: 0.7436 - dense_323_accuracy: 0.6845 - dense_325_accuracy: 0.8933 - dense_327_accuracy: 0.4756 - dense_329_accuracy: 0.8608 - loss: 10.0655
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# k: 10, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - dense_299_accuracy: 0.4548 - dense_301_accuracy: 0.7378 - dense_303_accuracy: 0.9304 - dense_305_accuracy: 0.6474 - dense_307_accuracy: 0.6903 - dense_309_accuracy: 0.8237 - dense_311_accuracy: 0.5185 - dense_313_accuracy: 0.5882 - dense_315_accuracy: 0.8133 - dense_317_accuracy: 0.8933 - dense_319_accuracy: 0.9200 - dense_321_accuracy: 0.7332 - dense_323_accuracy: 0.6636 - dense_325_accuracy: 0.8933 - dense_327_accuracy: 0.5081 - dense_329_accuracy: 0.8608 - loss: 10.1589
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# k: 11, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - dense_299_accuracy: 0.5927 - dense_301_accuracy: 0.7378 - dense_303_accuracy: 0.9304 - dense_305_accuracy: 0.6578 - dense_307_accuracy: 0.7111 - dense_309_accuracy: 0.8237 - dense_311_accuracy: 0.5185 - dense_313_accuracy: 0.5882 - dense_315_accuracy: 0.8133 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9200 - dense_321_accuracy: 0.7436 - dense_323_accuracy: 0.6845 - dense_325_accuracy: 0.8933 - dense_327_accuracy: 0.5140 - dense_329_accuracy: 0.8608 - loss: 9.8014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# k: 12, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - dense_299_accuracy: 0.5081 - dense_301_accuracy: 0.7170 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.6578 - dense_307_accuracy: 0.7215 - dense_309_accuracy: 0.8133 - dense_311_accuracy: 0.4873 - dense_313_accuracy: 0.5777 - dense_315_accuracy: 0.8341 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9200 - dense_321_accuracy: 0.7436 - dense_323_accuracy: 0.6740 - dense_325_accuracy: 0.8933 - dense_327_accuracy: 0.4444 - dense_329_accuracy: 0.8504 - loss: 10.2181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# k: 13, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - dense_299_accuracy: 0.5348 - dense_301_accuracy: 0.7482 - dense_303_accuracy: 0.9408 - dense_305_accuracy: 0.6682 - dense_307_accuracy: 0.7111 - dense_309_accuracy: 0.8445 - dense_311_accuracy: 0.4873 - dense_313_accuracy: 0.5882 - dense_315_accuracy: 0.8341 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9304 - dense_321_accuracy: 0.7541 - dense_323_accuracy: 0.6845 - dense_325_accuracy: 0.9037 - dense_327_accuracy: 0.5185 - dense_329_accuracy: 0.8504 - loss: 9.7527
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 14, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - dense_299_accuracy: 0.5719 - dense_301_accuracy: 0.7274 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.6474 - dense_307_accuracy: 0.7274 - dense_309_accuracy: 0.8341 - dense_311_accuracy: 0.4977 - dense_313_accuracy: 0.5673 - dense_315_accuracy: 0.8341 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9304 - dense_321_accuracy: 0.7436 - dense_323_accuracy: 0.6740 - dense_325_accuracy: 0.9037 - dense_327_accuracy: 0.4652 - dense_329_accuracy: 0.8399 - loss: 9.6684
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# k: 15, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - dense_299_accuracy: 0.4710 - dense_301_accuracy: 0.7274 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.6474 - dense_307_accuracy: 0.7111 - dense_309_accuracy: 0.8341 - dense_311_accuracy: 0.5081 - dense_313_accuracy: 0.5777 - dense_315_accuracy: 0.8549 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9408 - dense_321_accuracy: 0.7645 - dense_323_accuracy: 0.6845 - dense_325_accuracy: 0.9141 - dense_327_accuracy: 0.4073 - dense_329_accuracy: 0.8504 - loss: 9.5765
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# k: 16, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - dense_299_accuracy: 0.6311 - dense_301_accuracy: 0.7170 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.6845 - dense_307_accuracy: 0.7274 - dense_309_accuracy: 0.8237 - dense_311_accuracy: 0.5185 - dense_313_accuracy: 0.5882 - dense_315_accuracy: 0.8237 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9200 - dense_321_accuracy: 0.7541 - dense_323_accuracy: 0.6578 - dense_325_accuracy: 0.8933 - dense_327_accuracy: 0.4919 - dense_329_accuracy: 0.8504 - loss: 9.6171
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# k: 17, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - dense_299_accuracy: 0.5615 - dense_301_accuracy: 0.6903 - dense_303_accuracy: 0.9200 - dense_305_accuracy: 0.6578 - dense_307_accuracy: 0.8074 - dense_309_accuracy: 0.8133 - dense_311_accuracy: 0.5081 - dense_313_accuracy: 0.6148 - dense_315_accuracy: 0.8445 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9200 - dense_321_accuracy: 0.7436 - dense_323_accuracy: 0.7541 - dense_325_accuracy: 0.8933 - dense_327_accuracy: 0.4444 - dense_329_accuracy: 0.8504 - loss: 9.4979
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# k: 18, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - dense_299_accuracy: 0.5615 - dense_301_accuracy: 0.7378 - dense_303_accuracy: 0.9304 - dense_305_accuracy: 0.7007 - dense_307_accuracy: 0.7912 - dense_309_accuracy: 0.8341 - dense_311_accuracy: 0.4815 - dense_313_accuracy: 0.6253 - dense_315_accuracy: 0.8237 - dense_317_accuracy: 0.9037 - dense_319_accuracy: 0.9200 - dense_321_accuracy: 0.7436 - dense_323_accuracy: 0.7007 - dense_325_accuracy: 0.9037 - dense_327_accuracy: 0.4652 - dense_329_accuracy: 0.8399 - loss: 9.0793
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# k: 19, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# Test Loss iteration 4: 67.50355318283395
# average_loss: 41.72005409142493
