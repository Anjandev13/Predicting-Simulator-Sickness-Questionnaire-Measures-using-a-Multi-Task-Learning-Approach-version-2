# %%
from google.colab import drive
import pandas as pd
from sklearn.preprocessing import StandardScaler
from scipy import stats
import numpy as np
import logging
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from datetime import datetime
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime
import matplotlib.dates as mdates
import os

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Set the base path to the desired directory on Google Drive
base_path = '/content/drive/MyDrive/Study_1_Data/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read_csv(file_path):
    data = pd.read_csv(file_path)
    return data

# %%
def process_data(data, columns_to_remove):
    processed_data = data.drop(columns=columns_to_remove).values
    return processed_data

# %%
def construct_3d_array(base_dir, participants, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye):
    """
    Construct 3D array from CSV files.
    """
    num_rows = 180  # Define number of rows to keep (last 180 rows)
    arrays_3d = []

    for participant in participants:
        participant_id = f"{int(participant):02d}"  # Format participant number to two digits

        valid_simulations = []

        for simulation in simulations:
            hr_file_path = os.path.join(base_dir, participant_id, simulation, f'HR{simulation.capitalize()}.csv')
            gsr_file_path = os.path.join(base_dir, participant_id, simulation, f'EDA{simulation.capitalize()}_downsampled.csv')
            head_file_path = os.path.join(base_dir, participant_id, simulation, 'head_tracking_downsampled.csv')
            eye_file_path = os.path.join(base_dir, participant_id, simulation, 'eye_tracking_downsampled.csv')

            # Check if all files exist
            if all(os.path.exists(file) for file in [hr_file_path, gsr_file_path, head_file_path, eye_file_path]):
                valid_simulations.append(simulation)

        num_valid_simulations = len(valid_simulations)
        if num_valid_simulations == 0:
            continue  # Skip this participant if no valid simulations are found

        array_3d = np.zeros((num_valid_simulations, num_rows, 47)) # hr=1, gsr=1, head=15-3, eye=41-8 total columns after removing columns= 48

        for s_idx, simulation in enumerate(valid_simulations):
            # Process hr data
            hr_file_path = os.path.join(base_dir, participant_id, simulation, f'HR{simulation.capitalize()}.csv')
            hr_data = read_csv(hr_file_path)
            processed_hr_data = process_data(hr_data, columns_to_remove_hr)
            processed_hr_data = processed_hr_data[-num_rows:]  # Keep only the last 180 rows

            # Process gsr data
            gsr_file_path = os.path.join(base_dir, participant_id, simulation, f'EDA{simulation.capitalize()}_downsampled.csv')
            gsr_data = read_csv(gsr_file_path)
            processed_gsr_data = process_data(gsr_data, columns_to_remove_gsr)
            processed_gsr_data = processed_gsr_data[-num_rows:]  # Keep only the last 180 rows

            # Process head data
            head_file_path = os.path.join(base_dir, participant_id, simulation, 'head_tracking_downsampled.csv')
            head_data = read_csv(head_file_path)
            processed_head_data = process_data(head_data, columns_to_remove_head)
            processed_head_data = processed_head_data[-num_rows:]  # Keep only the last 180 rows

            # Process eye data
            eye_file_path = os.path.join(base_dir, participant_id, simulation, 'eye_tracking_downsampled.csv')
            eye_data = read_csv(eye_file_path)
            processed_eye_data = process_data(eye_data, columns_to_remove_eye)
            processed_eye_data = processed_eye_data[-num_rows:]  # Keep only the last 180 rows

            # Combine processed data
            combined_data = np.concatenate((processed_hr_data, processed_gsr_data, processed_head_data, processed_eye_data), axis=1)

            array_3d[s_idx, :, :] = combined_data

        arrays_3d.append(array_3d)

    return arrays_3d

# %%
sample_size=30
simulations = ['flat','noise','bumps']
participants = [str(i) for i in range(1, 27)]  # Participants 101 to 127
columns_to_remove_hr = []
columns_to_remove_gsr = []
columns_to_remove_eye = ['#Frame','Time', 'Unnamed: 40','ConvergenceValid','Left_Eye_Closed','Right_Eye_Closed','LocalGazeValid','WorldGazeValid']
columns_to_remove_head = ['#Frame','Time', 'Unnamed: 14']

# %%
def calculate_total_ssq(csv_file):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    n_columns = [0, 5, 6, 7, 8, 14, 15]
    o_columns = [0, 1, 2, 3, 4, 8, 10]
    d_columns = [4, 7, 9, 10, 11, 12, 13]

    # Calculate sum for each specified set of columns
    n_val = df.iloc[0, n_columns].sum()
    o_val = df.iloc[0, o_columns].sum()
    d_val = df.iloc[0, d_columns].sum()

    return n_val, o_val, d_val

# %%
def merge_ssq_column(conditions,participants):
  directories = []
  total_ssq_values = []
  for participant in participants:
      participant = f"{int(participant):02d}"
      for condition in conditions:
          directory = os.path.join(base_path, participant, condition)
          directories.append(directory)

  # Loop through each directory
  for directory in directories:
      # Check if the directory exists
      if not os.path.exists(directory):
          continue

      # Get all CSV files in the directory that are named 'ssq.csv'
      csv_files = [file for file in os.listdir(directory) if file == 'ssq.csv']

      # Loop through each CSV file
      for csv_file in csv_files:
          csv_path = os.path.join(directory, csv_file)
          df = pd.read_csv(csv_path)
          # n_val,o_val,d_val = calculate_total_ssq(csv_path)
          # total_ssq_values.append([n_val, o_val, d_val])
          ssq_values_participant = df.iloc[:, 0:17].values.flatten()   # Assuming SSQ values are in columns 1 to 16
          total_ssq_values.append(ssq_values_participant)
  ssq_array = np.array(total_ssq_values)
  return ssq_array

def merge_total_ssq(conditions,participants):
  directories = []
  total_ssq_values = []
  for participant in participants:
      participant = f"{int(participant):02d}"
      for condition in conditions:
          directory = os.path.join(base_path, participant, condition)
          directories.append(directory)

  # Loop through each directory
  for directory in directories:
      # Check if the directory exists
      if not os.path.exists(directory):
          continue

      # Get all CSV files in the directory that are named 'ssq.csv'
      csv_files = [file for file in os.listdir(directory) if file == 'ssq.csv']

      # Loop through each CSV file
      for csv_file in csv_files:
          csv_path = os.path.join(directory, csv_file)
          n_val,o_val,d_val = calculate_total_ssq(csv_path)
          total_ssq = (n_val+o_val+d_val) * 3.74
          df = pd.read_csv(csv_path)
          df["total-ssq"] = total_ssq
          #print("csv_path: ",csv_path,"   ",total_ssq)
          total_ssq_values.append(total_ssq)
  # Create a DataFrame from the list of total SSQ values
  df_total_ssq = pd.DataFrame(total_ssq_values, columns=["total-ssq"])
  # Convert the list of total SSQ values to a NumPy array
  total_ssq_array = np.array(total_ssq_values)
  return total_ssq_array

# %%
participants_group_1 = [1,3,4,11,25]
participants_group_2 = [2,7,8,9,17]
participants_group_3 = [10,12,13,22,23]
participants_group_4 = [5,14,18,20,21]
participants_group_5 = [6,15,16,19,24,26]

arrays_group_1 = construct_3d_array(base_path, participants_group_1, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_2 = construct_3d_array(base_path, participants_group_2, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_3 = construct_3d_array(base_path, participants_group_3, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_4 = construct_3d_array(base_path, participants_group_4, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_5 = construct_3d_array(base_path, participants_group_5, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)

# %%
# Concatenate arrays along the first axis
input_group_1 = np.concatenate(arrays_group_1, axis=0)
input_group_2 = np.concatenate(arrays_group_2, axis=0)
input_group_3 = np.concatenate(arrays_group_3, axis=0)
input_group_4 = np.concatenate(arrays_group_4, axis=0)
input_group_5 = np.concatenate(arrays_group_5, axis=0)

# %%
output_group_1=merge_ssq_column(simulations,participants_group_1)
output_group_2=merge_ssq_column(simulations,participants_group_2)
output_group_3=merge_ssq_column(simulations,participants_group_3)
output_group_4=merge_ssq_column(simulations,participants_group_4)
output_group_5=merge_ssq_column(simulations,participants_group_5)

output_group_1 = np.squeeze(output_group_1)
output_group_2 = np.squeeze(output_group_2)
output_group_3 = np.squeeze(output_group_3)
output_group_4 = np.squeeze(output_group_4)
output_group_5 = np.squeeze(output_group_5)


output_total_ssq_group_1=merge_total_ssq(simulations,participants_group_1)
output_total_ssq_group_2=merge_total_ssq(simulations,participants_group_2)
output_total_ssq_group_3=merge_total_ssq(simulations,participants_group_3)
output_total_ssq_group_4=merge_total_ssq(simulations,participants_group_4)
output_total_ssq_group_5=merge_total_ssq(simulations,participants_group_5)

output_total_ssq_group_1=output_total_ssq_group_1.reshape(-1, 1)
output_total_ssq_group_2=output_total_ssq_group_2.reshape(-1, 1)
output_total_ssq_group_3=output_total_ssq_group_3.reshape(-1, 1)
output_total_ssq_group_4=output_total_ssq_group_4.reshape(-1, 1)
output_total_ssq_group_5=output_total_ssq_group_5.reshape(-1, 1)

# %%
def scale_input_data(input_train, input_test):
    # Get the shape of the input data
    num_samples_train, time_steps_train, num_features = input_train.shape
    num_samples_test, time_steps_test, _ = input_test.shape

    # Reshape the input data into 2D arrays
    flattened_train_data = input_train.reshape(-1, num_features)
    flattened_test_data = input_test.reshape(-1, num_features)

    # Initialize a MinMaxScaler object
    scaler = MinMaxScaler()

    # Fit the scaler on the training data and transform both train and test data
    scaled_train_data = scaler.fit_transform(flattened_train_data)
    scaled_test_data = scaler.transform(flattened_test_data)

    # Reshape the scaled data back to its original shape
    scaled_train_data = scaled_train_data.reshape(num_samples_train, time_steps_train, num_features)
    scaled_test_data = scaled_test_data.reshape(num_samples_test, time_steps_test, num_features)

    return scaled_train_data, scaled_test_data

def scale_target_var(target_data):
    min_val, max_val = np.min(target_data, axis=0), np.max(target_data, axis=0)
    target_data = (target_data-min_val)/(max_val-min_val)

    return target_data, min_val, max_val

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, LSTM, Dense, Dropout
from keras.models import Model
import numpy as np
import sklearn
from keras.utils import to_categorical

def soft_parameter_sharing_regularizer(model, alpha=0.01):
    LSTM_layers = [layer for layer in model.layers if isinstance(layer, LSTM)]
    if not LSTM_layers:
        return 0.0

    weights = [tf.convert_to_tensor(layer.weights[0]) for layer in LSTM_layers]

    shared_weights = tf.reduce_mean(tf.stack(weights), axis=0)
    return alpha * tf.reduce_sum([tf.reduce_sum(tf.square(w - shared_weights)) for w in weights])


def get_individual_LSTM(input_shape1, input_shape2):
    input_layer = Input(shape=(input_shape1, input_shape2))

    LSTM_layers = []
    for _ in range(output_train.shape[1]):
        x = LSTM(64, return_sequences=False)(input_layer)
        x = Dense(256, activation='relu')(x)
        x = Dropout(0.2)(x)
        LSTM_layers.append(x)

    return LSTM_layers, input_layer


def get_output_model(LSTM_outputs, output_shape):
    output_models = []
    for i in range(output_shape[1]):
        output = Dense(256, activation='relu')(LSTM_outputs[i])
        output = Dropout(0.2)(output)
        output = Dense(4, activation='softmax')(output)  # Output shape is (None, 4) for 4 classes
        output_models.append(output)
    return output_models

total_losses = []
for iteration in range(5):



  # Assuming input_groups and output_groups are lists of arrays for the 5 groups
    input_groups = [input_group_1, input_group_2, input_group_3, input_group_4, input_group_5]
    output_groups = [output_group_1, output_group_2, output_group_3, output_group_4, output_group_5]
    ssq_groups = [output_total_ssq_group_1, output_total_ssq_group_2, output_total_ssq_group_3, output_total_ssq_group_4, output_total_ssq_group_5]

    # Initialize lists for storing training, validation, and test sets
    X_train, X_val, X_test = [], [], []
    y_train, y_val, y_test = [], [], []
    ssq_train, ssq_val, ssq_test = [], [], []

    # Loop over each group
    for input_group, output_group, ssq_group in zip(input_groups, output_groups, ssq_groups):
        # Step 1: Split the group into a training/validation set (80%) and a test set (20%)
        X_temp, X_test_temp, y_temp, y_test_temp, ssq_temp, ssq_test_temp = train_test_split(
            input_group, output_group, ssq_group, test_size=0.2)

        # Step 2: Split the training/validation set into a training set (60%) and a validation set (20%)
        X_train_temp, X_val_temp, y_train_temp, y_val_temp, ssq_train_temp, ssq_val_temp = train_test_split(
            X_temp, y_temp, ssq_temp, test_size=0.25)  # 0.25 * 0.8 = 0.2

        # Step 3: Append the results to the corresponding lists
        X_train.append(X_train_temp)
        X_val.append(X_val_temp)
        X_test.append(X_test_temp)

        y_train.append(y_train_temp)
        y_val.append(y_val_temp)
        y_test.append(y_test_temp)

        ssq_train.append(ssq_train_temp)
        ssq_val.append(ssq_val_temp)
        ssq_test.append(ssq_test_temp)

    # After the loop, concatenate the data for all groups if needed
    input_train = np.concatenate(X_train, axis=0)
    input_val = np.concatenate(X_val, axis=0)
    input_test = np.concatenate(X_test, axis=0)

    output_train = np.concatenate(y_train, axis=0)
    output_val = np.concatenate(y_val, axis=0)
    output_test = np.concatenate(y_test, axis=0)


    output_val_total_ssq = np.concatenate(ssq_val, axis=0)
    output_test_total_ssq = np.concatenate(ssq_test, axis=0)
    # input_train, input_test= scale_input_data(input_train[:, (60-sample_size):(180-sample_size), :], input_test[:, (60-sample_size):(180-sample_size), :])
    # output_train, min_val, max_val = scale_target_var(output_train)


    #  this section for scaling both train and validation set simultaniously
      # Step 1: Combine the training and validation sets
    combined_input = np.concatenate([input_train, input_val], axis=0)
    combined_output = np.concatenate([output_train, output_val], axis=0)

    # Step 2: Scale the combined input data
    # Assuming scale_input_data scales the data based on the combined dataset
    combined_input, input_test = scale_input_data(
        combined_input[:, (60-sample_size):(180-sample_size), :],
        input_test[:, (60-sample_size):(180-sample_size), :]
    )

    # Convert the original labels to one-hot encoded format
    output_train_encoded = to_categorical(combined_output, num_classes=4)

    # Step 4: Split the combined data back into training and validation sets
    # Use the original shapes of input_train and input_val to slice the combined arrays
    input_train = combined_input[:input_train.shape[0], :, :]
    input_val = combined_input[input_train.shape[0]:, :, :]

    output_train = output_train_encoded[:output_train.shape[0], :]
    output_val = output_train_encoded[output_train.shape[0]:, :]



    print("input_train :", input_train.shape)
    print("output_train :", output_train.shape)
    print("input_val :", input_val.shape)
    print("output_val :", output_val.shape)
    print("input_test :", input_test.shape)
    print("output_test :", output_test.shape)



    train_input_reshaped = input_train.reshape((input_train.shape[0], input_train.shape[1], input_train.shape[2]))
    test_input_reshaped = input_test.reshape((input_test.shape[0], input_test.shape[1], input_test.shape[2]))
    val_input_reshaped = input_val.reshape((input_val.shape[0], input_val.shape[1], input_val.shape[2]))

    # Get individual LSTM outputs
    LSTM_outputs, input_layer = get_individual_LSTM(input_train.shape[1], input_train.shape[2])

    # Create separate output models for each column
    output_models = get_output_model(LSTM_outputs, output_train.shape)

    # Create combined model
    model = Model(inputs=input_layer, outputs=output_models)

    # Custom loss function
    def custom_loss(y_true, y_pred):
        cce = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        reg_loss = soft_parameter_sharing_regularizer(model)
        return cce + reg_loss

    # Compile and train the model
    model.compile(loss=custom_loss, optimizer='adam', metrics=[['accuracy'] for _ in range(output_train.shape[1])])

    best_val_loss = float('inf')
    patience = 0
    best_model = None

    for k in range(200):
        model.fit(train_input_reshaped, [output_train[:, i] for i in range(output_train.shape[1])], epochs=1, batch_size=32)
        pred_val = np.array(model.predict(val_input_reshaped))
        pred_val = np.transpose(pred_val.squeeze(), (1, 0, 2))
        pred_val = np.argmax(pred_val, axis=-1).reshape(pred_val.shape[:-1])

        print(f"k: {k}, patience: {patience}")

        # SSQ Calculation logic...


        # Evaluate the model based on SSQ for validation data
        losses = []
        for i in range(pred_val.shape[0]):
            total_ssq = 0
            for j in [0, 5, 6, 7, 8, 14, 15]:
                total_ssq += np.sum(pred_val[i, j])

            for j in [0, 1, 2, 3, 4, 8, 10]:
                total_ssq += np.sum(pred_val[i, j])

            for j in [4, 7, 9, 10, 11, 12, 13]:
                total_ssq += np.sum(pred_val[i, j])

            total_ssq *= 3.74
            output_val_ssq = output_val_total_ssq[i, 0]
            loss = sklearn.metrics.mean_squared_error([total_ssq], [output_val_ssq], squared=False)
            losses.append(loss)

        tmp_val_loss = np.mean(losses)
        if tmp_val_loss <= best_val_loss:
            best_val_loss = tmp_val_loss
            patience = 0
            best_model = model
        else:
            patience += 1
            if patience > 10:
                break

    # Predict and evaluate test data using the best model
    pred_test = np.array(best_model.predict(test_input_reshaped))
    pred_test = np.transpose(pred_test.squeeze(), (1, 0, 2))
    pred_test = np.argmax(pred_test, axis=-1).reshape(pred_test.shape[:-1])

    pred_total_ssq = []
    for i in range(pred_test.shape[0]):
        total_ssq = 0
        for j in [0, 5, 6, 7, 8, 14, 15]:
            total_ssq += np.sum(pred_test[i, j])

        for j in [0, 1, 2, 3, 4, 8, 10]:
            total_ssq += np.sum(pred_test[i, j])

        for j in [4, 7, 9, 10, 11, 12, 13]:
            total_ssq += np.sum(pred_test[i, j])

        total_ssq *= 3.74
        pred_total_ssq.append(total_ssq)

    # Overall Test Loss
    loss = sklearn.metrics.mean_squared_error(pred_total_ssq, output_test_total_ssq, squared=False)
    print(f"Test Loss iteration {iteration}: {loss}")
    total_losses.append(loss)
average_loss = sum(total_losses) / len(total_losses)
total_losses.append(average_loss)
print("average_loss:", average_loss)
# Out:
# input_train : (38, 120, 47)
# output_train : (38, 16, 4)
# input_val : (14, 120, 47)
# output_val : (14, 16, 4)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 64s 517ms/step - dense_257_accuracy: 0.1749 - dense_259_accuracy: 0.5071 - dense_261_accuracy: 0.0981 - dense_263_accuracy: 0.1573 - dense_265_accuracy: 0.5071 - dense_267_accuracy: 0.0735 - dense_269_accuracy: 0.1365 - dense_271_accuracy: 0.0455 - dense_273_accuracy: 0.4792 - dense_275_accuracy: 0.2484 - dense_277_accuracy: 0.1996 - dense_279_accuracy: 0.2867 - dense_281_accuracy: 0.4545 - dense_283_accuracy: 0.5910 - dense_285_accuracy: 0.4545 - dense_287_accuracy: 0.0702 - loss: 211.9865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# k: 0, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - dense_257_accuracy: 0.4441 - dense_259_accuracy: 0.7029 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.4057 - dense_265_accuracy: 0.7588 - dense_267_accuracy: 0.7692 - dense_269_accuracy: 0.6118 - dense_271_accuracy: 0.6678 - dense_273_accuracy: 0.7867 - dense_275_accuracy: 0.8427 - dense_277_accuracy: 0.8986 - dense_279_accuracy: 0.8355 - dense_281_accuracy: 0.7341 - dense_283_accuracy: 0.8986 - dense_285_accuracy: 0.5559 - dense_287_accuracy: 0.8810 - loss: 199.6763
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# k: 1, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step - dense_257_accuracy: 0.4616 - dense_259_accuracy: 0.6924 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.5630 - dense_265_accuracy: 0.7588 - dense_267_accuracy: 0.7867 - dense_269_accuracy: 0.6223 - dense_271_accuracy: 0.6573 - dense_273_accuracy: 0.7763 - dense_275_accuracy: 0.8322 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8251 - dense_281_accuracy: 0.7133 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.5663 - dense_287_accuracy: 0.8810 - loss: 188.8762
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# k: 2, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 881ms/step - dense_257_accuracy: 0.4825 - dense_259_accuracy: 0.7133 - dense_261_accuracy: 0.8986 - dense_263_accuracy: 0.5559 - dense_265_accuracy: 0.7692 - dense_267_accuracy: 0.7971 - dense_269_accuracy: 0.6118 - dense_271_accuracy: 0.6678 - dense_273_accuracy: 0.7971 - dense_275_accuracy: 0.8427 - dense_277_accuracy: 0.9090 - dense_279_accuracy: 0.8355 - dense_281_accuracy: 0.7133 - dense_283_accuracy: 0.9090 - dense_285_accuracy: 0.5455 - dense_287_accuracy: 0.8810 - loss: 179.4303
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# k: 3, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 633ms/step - dense_257_accuracy: 0.4616 - dense_259_accuracy: 0.7029 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.5455 - dense_265_accuracy: 0.7588 - dense_267_accuracy: 0.7867 - dense_269_accuracy: 0.6118 - dense_271_accuracy: 0.6573 - dense_273_accuracy: 0.7867 - dense_275_accuracy: 0.8322 - dense_277_accuracy: 0.8986 - dense_279_accuracy: 0.8043 - dense_281_accuracy: 0.6924 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.5351 - dense_287_accuracy: 0.8602 - loss: 171.7651
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 4, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - dense_257_accuracy: 0.4825 - dense_259_accuracy: 0.7237 - dense_261_accuracy: 0.9090 - dense_263_accuracy: 0.5663 - dense_265_accuracy: 0.8004 - dense_267_accuracy: 0.7971 - dense_269_accuracy: 0.6014 - dense_271_accuracy: 0.6678 - dense_273_accuracy: 0.8076 - dense_275_accuracy: 0.8531 - dense_277_accuracy: 0.8986 - dense_279_accuracy: 0.8147 - dense_281_accuracy: 0.7133 - dense_283_accuracy: 0.8986 - dense_285_accuracy: 0.5559 - dense_287_accuracy: 0.8706 - loss: 164.0691
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# k: 5, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step - dense_257_accuracy: 0.4825 - dense_259_accuracy: 0.7029 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.5839 - dense_265_accuracy: 0.7588 - dense_267_accuracy: 0.7867 - dense_269_accuracy: 0.5910 - dense_271_accuracy: 0.6573 - dense_273_accuracy: 0.7763 - dense_275_accuracy: 0.8322 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8043 - dense_281_accuracy: 0.6924 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.5455 - dense_287_accuracy: 0.8602 - loss: 157.9514
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 6, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - dense_257_accuracy: 0.4720 - dense_259_accuracy: 0.7237 - dense_261_accuracy: 0.9090 - dense_263_accuracy: 0.5384 - dense_265_accuracy: 0.7588 - dense_267_accuracy: 0.7971 - dense_269_accuracy: 0.5806 - dense_271_accuracy: 0.6678 - dense_273_accuracy: 0.7971 - dense_275_accuracy: 0.8427 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8147 - dense_281_accuracy: 0.7029 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.5559 - dense_287_accuracy: 0.8602 - loss: 150.9469
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# k: 7, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - dense_257_accuracy: 0.4825 - dense_259_accuracy: 0.7133 - dense_261_accuracy: 0.8986 - dense_263_accuracy: 0.4825 - dense_265_accuracy: 0.7692 - dense_267_accuracy: 0.7763 - dense_269_accuracy: 0.6118 - dense_271_accuracy: 0.6573 - dense_273_accuracy: 0.7867 - dense_275_accuracy: 0.8531 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8147 - dense_281_accuracy: 0.7029 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.5559 - dense_287_accuracy: 0.8602 - loss: 144.4286
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# k: 8, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step - dense_257_accuracy: 0.5455 - dense_259_accuracy: 0.7237 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.4616 - dense_265_accuracy: 0.7796 - dense_267_accuracy: 0.7867 - dense_269_accuracy: 0.6223 - dense_271_accuracy: 0.6573 - dense_273_accuracy: 0.7971 - dense_275_accuracy: 0.8322 - dense_277_accuracy: 0.9090 - dense_279_accuracy: 0.8147 - dense_281_accuracy: 0.7029 - dense_283_accuracy: 0.9090 - dense_285_accuracy: 0.5735 - dense_287_accuracy: 0.8706 - loss: 138.0330
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# k: 9, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - dense_257_accuracy: 0.4616 - dense_259_accuracy: 0.6924 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.4792 - dense_265_accuracy: 0.7692 - dense_267_accuracy: 0.7763 - dense_269_accuracy: 0.6118 - dense_271_accuracy: 0.6573 - dense_273_accuracy: 0.7971 - dense_275_accuracy: 0.8531 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8355 - dense_281_accuracy: 0.7133 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.5559 - dense_287_accuracy: 0.8706 - loss: 132.0095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# k: 10, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 869ms/step - dense_257_accuracy: 0.4057 - dense_259_accuracy: 0.7412 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.4825 - dense_265_accuracy: 0.7796 - dense_267_accuracy: 0.7971 - dense_269_accuracy: 0.6223 - dense_271_accuracy: 0.6678 - dense_273_accuracy: 0.8076 - dense_275_accuracy: 0.8531 - dense_277_accuracy: 0.9090 - dense_279_accuracy: 0.8355 - dense_281_accuracy: 0.7237 - dense_283_accuracy: 0.9090 - dense_285_accuracy: 0.5943 - dense_287_accuracy: 0.8706 - loss: 125.9947
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# k: 11, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 511ms/step - dense_257_accuracy: 0.4616 - dense_259_accuracy: 0.7621 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.5280 - dense_265_accuracy: 0.7692 - dense_267_accuracy: 0.8076 - dense_269_accuracy: 0.6118 - dense_271_accuracy: 0.6678 - dense_273_accuracy: 0.8076 - dense_275_accuracy: 0.8322 - dense_277_accuracy: 0.9090 - dense_279_accuracy: 0.8355 - dense_281_accuracy: 0.7341 - dense_283_accuracy: 0.9090 - dense_285_accuracy: 0.6118 - dense_287_accuracy: 0.8706 - loss: 120.6123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# k: 12, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step - dense_257_accuracy: 0.7237 - dense_259_accuracy: 0.7237 - dense_261_accuracy: 0.9090 - dense_263_accuracy: 0.7029 - dense_265_accuracy: 0.7692 - dense_267_accuracy: 0.8076 - dense_269_accuracy: 0.6014 - dense_271_accuracy: 0.6678 - dense_273_accuracy: 0.7971 - dense_275_accuracy: 0.8635 - dense_277_accuracy: 0.9090 - dense_279_accuracy: 0.8355 - dense_281_accuracy: 0.7341 - dense_283_accuracy: 0.9090 - dense_285_accuracy: 0.6782 - dense_287_accuracy: 0.8810 - loss: 115.0127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# k: 13, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - dense_257_accuracy: 0.4616 - dense_259_accuracy: 0.7484 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.6190 - dense_265_accuracy: 0.7588 - dense_267_accuracy: 0.7867 - dense_269_accuracy: 0.6014 - dense_271_accuracy: 0.6469 - dense_273_accuracy: 0.7867 - dense_275_accuracy: 0.8322 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8147 - dense_281_accuracy: 0.8147 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.6014 - dense_287_accuracy: 0.8706 - loss: 110.7418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 14, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - dense_257_accuracy: 0.5280 - dense_259_accuracy: 0.7484 - dense_261_accuracy: 0.8986 - dense_263_accuracy: 0.5351 - dense_265_accuracy: 0.7588 - dense_267_accuracy: 0.7867 - dense_269_accuracy: 0.6014 - dense_271_accuracy: 0.6469 - dense_273_accuracy: 0.7763 - dense_275_accuracy: 0.8427 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8043 - dense_281_accuracy: 0.7588 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.6398 - dense_287_accuracy: 0.8706 - loss: 105.6591
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# k: 15, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - dense_257_accuracy: 0.5208 - dense_259_accuracy: 0.7763 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.5663 - dense_265_accuracy: 0.7484 - dense_267_accuracy: 0.7763 - dense_269_accuracy: 0.6014 - dense_271_accuracy: 0.6469 - dense_273_accuracy: 0.7867 - dense_275_accuracy: 0.8427 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8251 - dense_281_accuracy: 0.7867 - dense_283_accuracy: 0.8986 - dense_285_accuracy: 0.5839 - dense_287_accuracy: 0.8706 - loss: 100.9952
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# k: 16, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - dense_257_accuracy: 0.5104 - dense_259_accuracy: 0.7971 - dense_261_accuracy: 0.8986 - dense_263_accuracy: 0.5663 - dense_265_accuracy: 0.7796 - dense_267_accuracy: 0.7971 - dense_269_accuracy: 0.6118 - dense_271_accuracy: 0.6782 - dense_273_accuracy: 0.7971 - dense_275_accuracy: 0.8427 - dense_277_accuracy: 0.9090 - dense_279_accuracy: 0.8459 - dense_281_accuracy: 0.7867 - dense_283_accuracy: 0.9090 - dense_285_accuracy: 0.5559 - dense_287_accuracy: 0.8706 - loss: 95.9949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# k: 17, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 899ms/step - dense_257_accuracy: 0.5104 - dense_259_accuracy: 0.8043 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.5663 - dense_265_accuracy: 0.7588 - dense_267_accuracy: 0.7763 - dense_269_accuracy: 0.5910 - dense_271_accuracy: 0.6469 - dense_273_accuracy: 0.7867 - dense_275_accuracy: 0.8427 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8043 - dense_281_accuracy: 0.6749 - dense_283_accuracy: 0.8986 - dense_285_accuracy: 0.6190 - dense_287_accuracy: 0.8706 - loss: 92.2287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# k: 18, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 504ms/step - dense_257_accuracy: 0.5455 - dense_259_accuracy: 0.8147 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.6782 - dense_265_accuracy: 0.7484 - dense_267_accuracy: 0.7867 - dense_269_accuracy: 0.5910 - dense_271_accuracy: 0.6469 - dense_273_accuracy: 0.7763 - dense_275_accuracy: 0.8427 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8251 - dense_281_accuracy: 0.8427 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.6398 - dense_287_accuracy: 0.8602 - loss: 88.0468
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# k: 19, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step - dense_257_accuracy: 0.5280 - dense_259_accuracy: 0.8531 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.5910 - dense_265_accuracy: 0.8147 - dense_267_accuracy: 0.7867 - dense_269_accuracy: 0.6118 - dense_271_accuracy: 0.6469 - dense_273_accuracy: 0.7763 - dense_275_accuracy: 0.8322 - dense_277_accuracy: 0.8986 - dense_279_accuracy: 0.8043 - dense_281_accuracy: 0.8322 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.6014 - dense_287_accuracy: 0.8706 - loss: 84.2529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# k: 20, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step - dense_257_accuracy: 0.5351 - dense_259_accuracy: 0.8427 - dense_261_accuracy: 0.8882 - dense_263_accuracy: 0.6678 - dense_265_accuracy: 0.7484 - dense_267_accuracy: 0.7763 - dense_269_accuracy: 0.6014 - dense_271_accuracy: 0.6469 - dense_273_accuracy: 0.7763 - dense_275_accuracy: 0.8427 - dense_277_accuracy: 0.8986 - dense_279_accuracy: 0.8251 - dense_281_accuracy: 0.8882 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.6086 - dense_287_accuracy: 0.8602 - loss: 80.4147
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# k: 21, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - dense_257_accuracy: 0.5872 - dense_259_accuracy: 0.8602 - dense_261_accuracy: 0.8986 - dense_263_accuracy: 0.6645 - dense_265_accuracy: 0.7484 - dense_267_accuracy: 0.7971 - dense_269_accuracy: 0.6014 - dense_271_accuracy: 0.6678 - dense_273_accuracy: 0.7763 - dense_275_accuracy: 0.8427 - dense_277_accuracy: 0.8882 - dense_279_accuracy: 0.8147 - dense_281_accuracy: 0.8427 - dense_283_accuracy: 0.8882 - dense_285_accuracy: 0.6223 - dense_287_accuracy: 0.8706 - loss: 76.7990
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# k: 22, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Test Loss iteration 0: 34.468417065481844
# input_train : (38, 120, 47)
# output_train : (38, 16, 4)
# input_val : (14, 120, 47)
# output_val : (14, 16, 4)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 61s 521ms/step - dense_305_accuracy: 0.3602 - dense_307_accuracy: 0.1365 - dense_309_accuracy: 0.3114 - dense_311_accuracy: 0.2100 - dense_313_accuracy: 0.4161 - dense_315_accuracy: 0.1261 - dense_317_accuracy: 0.3043 - dense_319_accuracy: 0.1365 - dense_321_accuracy: 0.0351 - dense_323_accuracy: 0.4128 - dense_325_accuracy: 0.0526 - dense_327_accuracy: 0.4337 - dense_329_accuracy: 0.1261 - dense_331_accuracy: 0.1261 - dense_333_accuracy: 0.1294 - dense_335_accuracy: 0.6469 - loss: 212.6159
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# k: 0, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 848ms/step - dense_305_accuracy: 0.5280 - dense_307_accuracy: 0.6398 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6502 - dense_313_accuracy: 0.7412 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.6118 - dense_319_accuracy: 0.6853 - dense_321_accuracy: 0.7308 - dense_323_accuracy: 0.8531 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7484 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5630 - dense_335_accuracy: 0.8602 - loss: 200.0480
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# k: 1, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 648ms/step - dense_305_accuracy: 0.5384 - dense_307_accuracy: 0.6853 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6294 - dense_313_accuracy: 0.7308 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.6118 - dense_319_accuracy: 0.6853 - dense_321_accuracy: 0.7484 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5455 - dense_335_accuracy: 0.8602 - loss: 189.0784
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# k: 2, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - dense_305_accuracy: 0.5384 - dense_307_accuracy: 0.7029 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6294 - dense_313_accuracy: 0.7308 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.6118 - dense_319_accuracy: 0.6957 - dense_321_accuracy: 0.7484 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5455 - dense_335_accuracy: 0.8706 - loss: 179.5645
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# k: 3, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step - dense_305_accuracy: 0.5384 - dense_307_accuracy: 0.7237 - dense_309_accuracy: 0.9370 - dense_311_accuracy: 0.6398 - dense_313_accuracy: 0.7308 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.5910 - dense_319_accuracy: 0.6853 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6749 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5455 - dense_335_accuracy: 0.8602 - loss: 171.5402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# k: 4, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step - dense_305_accuracy: 0.5280 - dense_307_accuracy: 0.7237 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6294 - dense_313_accuracy: 0.7412 - dense_315_accuracy: 0.8251 - dense_317_accuracy: 0.6118 - dense_319_accuracy: 0.6957 - dense_321_accuracy: 0.7692 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.9090 - dense_327_accuracy: 0.7692 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.5663 - dense_335_accuracy: 0.8706 - loss: 164.3598
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 5, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step - dense_305_accuracy: 0.5104 - dense_307_accuracy: 0.7133 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6502 - dense_313_accuracy: 0.7412 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.6014 - dense_319_accuracy: 0.6853 - dense_321_accuracy: 0.7692 - dense_323_accuracy: 0.8531 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6749 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.5455 - dense_335_accuracy: 0.8706 - loss: 157.5393
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# k: 6, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step - dense_305_accuracy: 0.5280 - dense_307_accuracy: 0.6924 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6398 - dense_313_accuracy: 0.7204 - dense_315_accuracy: 0.8043 - dense_317_accuracy: 0.5910 - dense_319_accuracy: 0.6645 - dense_321_accuracy: 0.7484 - dense_323_accuracy: 0.8635 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5351 - dense_335_accuracy: 0.8602 - loss: 150.9578
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# k: 7, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step - dense_305_accuracy: 0.5559 - dense_307_accuracy: 0.7133 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.4825 - dense_313_accuracy: 0.7692 - dense_315_accuracy: 0.8251 - dense_317_accuracy: 0.5910 - dense_319_accuracy: 0.6957 - dense_321_accuracy: 0.7796 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5559 - dense_335_accuracy: 0.8602 - loss: 144.0830
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# k: 8, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 894ms/step - dense_305_accuracy: 0.5768 - dense_307_accuracy: 0.7133 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.7237 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.5910 - dense_319_accuracy: 0.6957 - dense_321_accuracy: 0.7484 - dense_323_accuracy: 0.8531 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5663 - dense_335_accuracy: 0.8602 - loss: 137.4861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# k: 9, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - dense_305_accuracy: 0.5735 - dense_307_accuracy: 0.7412 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6294 - dense_313_accuracy: 0.7412 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.5910 - dense_319_accuracy: 0.6749 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6749 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5630 - dense_335_accuracy: 0.8602 - loss: 131.7045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# k: 10, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step - dense_305_accuracy: 0.6502 - dense_307_accuracy: 0.7133 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6398 - dense_313_accuracy: 0.7308 - dense_315_accuracy: 0.8251 - dense_317_accuracy: 0.6118 - dense_319_accuracy: 0.7061 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7796 - dense_329_accuracy: 0.6957 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.5559 - dense_335_accuracy: 0.8706 - loss: 125.7363
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# k: 11, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step - dense_305_accuracy: 0.6573 - dense_307_accuracy: 0.7308 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6190 - dense_313_accuracy: 0.7412 - dense_315_accuracy: 0.8251 - dense_317_accuracy: 0.5910 - dense_319_accuracy: 0.6749 - dense_321_accuracy: 0.7796 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7484 - dense_329_accuracy: 0.6749 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5559 - dense_335_accuracy: 0.8706 - loss: 120.3087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# k: 12, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step - dense_305_accuracy: 0.6365 - dense_307_accuracy: 0.7692 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6294 - dense_313_accuracy: 0.7308 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.5910 - dense_319_accuracy: 0.6645 - dense_321_accuracy: 0.7692 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7484 - dense_329_accuracy: 0.6645 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5455 - dense_335_accuracy: 0.8602 - loss: 115.1432
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# k: 13, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step - dense_305_accuracy: 0.6223 - dense_307_accuracy: 0.7412 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6398 - dense_313_accuracy: 0.7412 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.6223 - dense_319_accuracy: 0.6749 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7692 - dense_329_accuracy: 0.6749 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.5455 - dense_335_accuracy: 0.8706 - loss: 109.6503
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# k: 14, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 838ms/step - dense_305_accuracy: 0.7516 - dense_307_accuracy: 0.8251 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6398 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.6502 - dense_319_accuracy: 0.7061 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.9090 - dense_327_accuracy: 0.7900 - dense_329_accuracy: 0.7166 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.5768 - dense_335_accuracy: 0.8810 - loss: 104.5402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# k: 15, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 916ms/step - dense_305_accuracy: 0.7971 - dense_307_accuracy: 0.8322 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6190 - dense_313_accuracy: 0.8076 - dense_315_accuracy: 0.8355 - dense_317_accuracy: 0.6678 - dense_319_accuracy: 0.6957 - dense_321_accuracy: 0.8004 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.9090 - dense_327_accuracy: 0.7796 - dense_329_accuracy: 0.6957 - dense_331_accuracy: 0.9370 - dense_333_accuracy: 0.5663 - dense_335_accuracy: 0.8810 - loss: 99.8742
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# k: 16, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - dense_305_accuracy: 0.7412 - dense_307_accuracy: 0.8043 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6853 - dense_313_accuracy: 0.8251 - dense_315_accuracy: 0.8355 - dense_317_accuracy: 0.7061 - dense_319_accuracy: 0.6957 - dense_321_accuracy: 0.7796 - dense_323_accuracy: 0.8531 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7692 - dense_329_accuracy: 0.7029 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.5943 - dense_335_accuracy: 0.8706 - loss: 95.5481
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# k: 17, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step - dense_305_accuracy: 0.7867 - dense_307_accuracy: 0.8427 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7237 - dense_313_accuracy: 0.8251 - dense_315_accuracy: 0.8043 - dense_317_accuracy: 0.6957 - dense_319_accuracy: 0.6678 - dense_321_accuracy: 0.7484 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7484 - dense_329_accuracy: 0.7029 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.6645 - dense_335_accuracy: 0.8706 - loss: 91.9540
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 18, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - dense_305_accuracy: 0.7971 - dense_307_accuracy: 0.8531 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7308 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.6398 - dense_319_accuracy: 0.6853 - dense_321_accuracy: 0.7867 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.7971 - dense_335_accuracy: 0.8706 - loss: 87.4053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# k: 19, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - dense_305_accuracy: 0.7867 - dense_307_accuracy: 0.8706 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.7412 - dense_313_accuracy: 0.7308 - dense_315_accuracy: 0.8251 - dense_317_accuracy: 0.6573 - dense_319_accuracy: 0.6957 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7692 - dense_329_accuracy: 0.6957 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.5104 - dense_335_accuracy: 0.8706 - loss: 83.4116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# k: 20, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - dense_305_accuracy: 0.6957 - dense_307_accuracy: 0.8706 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.7412 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8251 - dense_317_accuracy: 0.6398 - dense_319_accuracy: 0.6853 - dense_321_accuracy: 0.7796 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7692 - dense_329_accuracy: 0.6749 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.6118 - dense_335_accuracy: 0.8706 - loss: 79.4463
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 21, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 856ms/step - dense_305_accuracy: 0.7308 - dense_307_accuracy: 0.7166 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.7308 - dense_313_accuracy: 0.8355 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.6957 - dense_319_accuracy: 0.6853 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.6678 - dense_335_accuracy: 0.8810 - loss: 76.1434
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# k: 22, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 731ms/step - dense_305_accuracy: 0.7867 - dense_307_accuracy: 0.8147 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7308 - dense_313_accuracy: 0.8706 - dense_315_accuracy: 0.8043 - dense_317_accuracy: 0.6469 - dense_319_accuracy: 0.6924 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6749 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.6469 - dense_335_accuracy: 0.8602 - loss: 72.7051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 23, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step - dense_305_accuracy: 0.8322 - dense_307_accuracy: 0.7204 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7588 - dense_313_accuracy: 0.8251 - dense_315_accuracy: 0.8043 - dense_317_accuracy: 0.7971 - dense_319_accuracy: 0.7308 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.7029 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.6573 - dense_335_accuracy: 0.8706 - loss: 69.3695
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# k: 24, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 498ms/step - dense_305_accuracy: 0.7588 - dense_307_accuracy: 0.7029 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7204 - dense_313_accuracy: 0.8427 - dense_315_accuracy: 0.8251 - dense_317_accuracy: 0.5175 - dense_319_accuracy: 0.6678 - dense_321_accuracy: 0.7692 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.6957 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.5839 - dense_335_accuracy: 0.8706 - loss: 67.0430
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# k: 25, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - dense_305_accuracy: 0.8147 - dense_307_accuracy: 0.6924 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6924 - dense_313_accuracy: 0.8322 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.7412 - dense_319_accuracy: 0.7029 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7484 - dense_329_accuracy: 0.6469 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.6853 - dense_335_accuracy: 0.8706 - loss: 63.7090
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# k: 26, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step - dense_305_accuracy: 0.7692 - dense_307_accuracy: 0.7237 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.7029 - dense_313_accuracy: 0.7204 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.8355 - dense_319_accuracy: 0.6645 - dense_321_accuracy: 0.7692 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7692 - dense_329_accuracy: 0.7412 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.5280 - dense_335_accuracy: 0.9090 - loss: 61.2004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 27, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step - dense_305_accuracy: 0.8322 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7796 - dense_313_accuracy: 0.8706 - dense_315_accuracy: 0.8322 - dense_317_accuracy: 0.7133 - dense_319_accuracy: 0.7971 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7867 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.6469 - dense_335_accuracy: 0.9720 - loss: 57.9700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# k: 28, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step - dense_305_accuracy: 0.8706 - dense_307_accuracy: 0.8147 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6469 - dense_313_accuracy: 0.8810 - dense_315_accuracy: 0.8322 - dense_317_accuracy: 0.7971 - dense_319_accuracy: 0.8147 - dense_321_accuracy: 0.7484 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7867 - dense_329_accuracy: 0.8043 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.6294 - dense_335_accuracy: 0.9161 - loss: 55.6346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# k: 29, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 879ms/step - dense_305_accuracy: 0.8043 - dense_307_accuracy: 0.8602 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6294 - dense_313_accuracy: 0.8043 - dense_315_accuracy: 0.8043 - dense_317_accuracy: 0.7308 - dense_319_accuracy: 0.7308 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7692 - dense_329_accuracy: 0.7133 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5630 - dense_335_accuracy: 0.9649 - loss: 54.0291
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# k: 30, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 509ms/step - dense_305_accuracy: 0.8531 - dense_307_accuracy: 0.8914 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7588 - dense_313_accuracy: 0.8322 - dense_315_accuracy: 0.8043 - dense_317_accuracy: 0.8043 - dense_319_accuracy: 0.6957 - dense_321_accuracy: 0.7484 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7867 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5559 - dense_335_accuracy: 1.0000 - loss: 51.1075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# k: 31, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step - dense_305_accuracy: 0.7692 - dense_307_accuracy: 0.8706 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7516 - dense_313_accuracy: 0.8427 - dense_315_accuracy: 0.8322 - dense_317_accuracy: 0.8427 - dense_319_accuracy: 0.7763 - dense_321_accuracy: 0.7796 - dense_323_accuracy: 0.8427 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.8076 - dense_329_accuracy: 0.7308 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5351 - dense_335_accuracy: 0.8882 - loss: 49.0745
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# k: 32, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - dense_305_accuracy: 0.8076 - dense_307_accuracy: 0.8602 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6398 - dense_313_accuracy: 0.8706 - dense_315_accuracy: 0.8147 - dense_317_accuracy: 0.8706 - dense_319_accuracy: 0.8076 - dense_321_accuracy: 0.7692 - dense_323_accuracy: 0.8322 - dense_325_accuracy: 0.8986 - dense_327_accuracy: 0.7796 - dense_329_accuracy: 0.7621 - dense_331_accuracy: 0.9265 - dense_333_accuracy: 0.5839 - dense_335_accuracy: 0.8986 - loss: 46.8463
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 33, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - dense_305_accuracy: 0.8531 - dense_307_accuracy: 0.8427 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.5592 - dense_313_accuracy: 0.8706 - dense_315_accuracy: 0.8427 - dense_317_accuracy: 0.8882 - dense_319_accuracy: 0.7588 - dense_321_accuracy: 0.7588 - dense_323_accuracy: 0.8635 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7692 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.7308 - dense_335_accuracy: 0.8882 - loss: 44.7572
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# k: 34, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - dense_305_accuracy: 0.7204 - dense_307_accuracy: 0.8531 - dense_309_accuracy: 0.9370 - dense_311_accuracy: 0.6573 - dense_313_accuracy: 0.8986 - dense_315_accuracy: 0.8986 - dense_317_accuracy: 0.8427 - dense_319_accuracy: 0.7763 - dense_321_accuracy: 0.7867 - dense_323_accuracy: 0.8635 - dense_325_accuracy: 0.8882 - dense_327_accuracy: 0.7692 - dense_329_accuracy: 0.6853 - dense_331_accuracy: 0.9161 - dense_333_accuracy: 0.5806 - dense_335_accuracy: 0.9441 - loss: 43.2377
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# k: 35, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Test Loss iteration 1: 49.35170564428346
# input_train : (38, 120, 47)
# output_train : (38, 16, 4)
# input_val : (14, 120, 47)
# output_val : (14, 16, 4)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - dense_353_accuracy: 0.2308 - dense_355_accuracy: 0.1541 - dense_357_accuracy: 0.0702 - dense_359_accuracy: 0.1645 - dense_361_accuracy: 0.1436 - dense_363_accuracy: 0.1190 - dense_365_accuracy: 0.4441 - dense_367_accuracy: 0.3043 - dense_369_accuracy: 0.4128 - dense_371_accuracy: 0.4896 - dense_373_accuracy: 0.3289 - dense_375_accuracy: 0.7692 - dense_377_accuracy: 0.1086 - dense_379_accuracy: 0.1612 - dense_381_accuracy: 0.1853 - dense_383_accuracy: 0.0981 - loss: 212.1730
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# k: 0, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 845ms/step - dense_353_accuracy: 0.5071 - dense_355_accuracy: 0.7484 - dense_357_accuracy: 0.8882 - dense_359_accuracy: 0.6086 - dense_361_accuracy: 0.8147 - dense_363_accuracy: 0.8043 - dense_365_accuracy: 0.6749 - dense_367_accuracy: 0.6190 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8602 - dense_377_accuracy: 0.7308 - dense_379_accuracy: 0.8602 - dense_381_accuracy: 0.6086 - dense_383_accuracy: 0.8706 - loss: 199.2474
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# k: 1, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - dense_353_accuracy: 0.4616 - dense_355_accuracy: 0.7692 - dense_357_accuracy: 0.9090 - dense_359_accuracy: 0.6398 - dense_361_accuracy: 0.8043 - dense_363_accuracy: 0.8043 - dense_365_accuracy: 0.6853 - dense_367_accuracy: 0.6294 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8602 - dense_377_accuracy: 0.7204 - dense_379_accuracy: 0.8602 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.8706 - loss: 187.9601
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# k: 2, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - dense_353_accuracy: 0.4616 - dense_355_accuracy: 0.7484 - dense_357_accuracy: 0.8882 - dense_359_accuracy: 0.6294 - dense_361_accuracy: 0.8043 - dense_363_accuracy: 0.8147 - dense_365_accuracy: 0.6853 - dense_367_accuracy: 0.6294 - dense_369_accuracy: 0.8322 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8602 - dense_377_accuracy: 0.7412 - dense_379_accuracy: 0.8602 - dense_381_accuracy: 0.6190 - dense_383_accuracy: 0.8602 - loss: 178.4980
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# k: 3, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 880ms/step - dense_353_accuracy: 0.4616 - dense_355_accuracy: 0.7692 - dense_357_accuracy: 0.8882 - dense_359_accuracy: 0.6294 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8147 - dense_365_accuracy: 0.6749 - dense_367_accuracy: 0.6190 - dense_369_accuracy: 0.8635 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8810 - dense_377_accuracy: 0.7412 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.8706 - loss: 170.9170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# k: 4, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 927ms/step - dense_353_accuracy: 0.4512 - dense_355_accuracy: 0.7588 - dense_357_accuracy: 0.8882 - dense_359_accuracy: 0.6294 - dense_361_accuracy: 0.8043 - dense_363_accuracy: 0.8043 - dense_365_accuracy: 0.6749 - dense_367_accuracy: 0.6086 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7308 - dense_379_accuracy: 0.8602 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.8706 - loss: 164.5721
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# k: 5, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - dense_353_accuracy: 0.4720 - dense_355_accuracy: 0.7900 - dense_357_accuracy: 0.8986 - dense_359_accuracy: 0.6294 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8147 - dense_365_accuracy: 0.6749 - dense_367_accuracy: 0.6398 - dense_369_accuracy: 0.8531 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8810 - dense_377_accuracy: 0.7412 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.8706 - loss: 157.1296
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 6, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - dense_353_accuracy: 0.4825 - dense_355_accuracy: 0.7692 - dense_357_accuracy: 0.8986 - dense_359_accuracy: 0.6398 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8043 - dense_365_accuracy: 0.6957 - dense_367_accuracy: 0.6398 - dense_369_accuracy: 0.8531 - dense_371_accuracy: 0.8531 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7412 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.8706 - loss: 150.2806
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# k: 7, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 490ms/step - dense_353_accuracy: 0.5000 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.8882 - dense_359_accuracy: 0.6469 - dense_361_accuracy: 0.8459 - dense_363_accuracy: 0.8251 - dense_365_accuracy: 0.6957 - dense_367_accuracy: 0.6398 - dense_369_accuracy: 0.8531 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7516 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.8706 - loss: 143.3623
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# k: 8, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step - dense_353_accuracy: 0.6469 - dense_355_accuracy: 0.8602 - dense_357_accuracy: 0.8882 - dense_359_accuracy: 0.6014 - dense_361_accuracy: 0.8147 - dense_363_accuracy: 0.8147 - dense_365_accuracy: 0.6853 - dense_367_accuracy: 0.6294 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7412 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6190 - dense_383_accuracy: 0.8810 - loss: 137.4155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# k: 9, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 495ms/step - dense_353_accuracy: 0.4720 - dense_355_accuracy: 0.8147 - dense_357_accuracy: 0.8882 - dense_359_accuracy: 0.7133 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8147 - dense_365_accuracy: 0.6853 - dense_367_accuracy: 0.6294 - dense_369_accuracy: 0.8531 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7516 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6190 - dense_383_accuracy: 0.8810 - loss: 131.5212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# k: 10, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - dense_353_accuracy: 0.3394 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9090 - dense_359_accuracy: 0.6606 - dense_361_accuracy: 0.8043 - dense_363_accuracy: 0.8147 - dense_365_accuracy: 0.6749 - dense_367_accuracy: 0.6294 - dense_369_accuracy: 0.8322 - dense_371_accuracy: 0.8843 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7237 - dense_379_accuracy: 0.8602 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.8602 - loss: 125.7313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# k: 11, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 837ms/step - dense_353_accuracy: 0.6223 - dense_355_accuracy: 0.7692 - dense_357_accuracy: 0.9090 - dense_359_accuracy: 0.6749 - dense_361_accuracy: 0.8147 - dense_363_accuracy: 0.8355 - dense_365_accuracy: 0.6853 - dense_367_accuracy: 0.6118 - dense_369_accuracy: 0.8531 - dense_371_accuracy: 0.8531 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8810 - dense_377_accuracy: 0.7516 - dense_379_accuracy: 0.8810 - dense_381_accuracy: 0.6398 - dense_383_accuracy: 0.8706 - loss: 119.7456
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# k: 12, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 900ms/step - dense_353_accuracy: 0.5735 - dense_355_accuracy: 0.7692 - dense_357_accuracy: 0.8986 - dense_359_accuracy: 0.7484 - dense_361_accuracy: 0.8147 - dense_363_accuracy: 0.8147 - dense_365_accuracy: 0.6853 - dense_367_accuracy: 0.6294 - dense_369_accuracy: 0.8322 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7308 - dense_379_accuracy: 0.8602 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.8602 - loss: 115.0771
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# k: 13, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 499ms/step - dense_353_accuracy: 0.6118 - dense_355_accuracy: 0.7692 - dense_357_accuracy: 0.9090 - dense_359_accuracy: 0.8602 - dense_361_accuracy: 0.8043 - dense_363_accuracy: 0.8251 - dense_365_accuracy: 0.7029 - dense_367_accuracy: 0.6398 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8602 - dense_377_accuracy: 0.7412 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6502 - dense_383_accuracy: 0.8706 - loss: 109.6764
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# k: 14, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step - dense_353_accuracy: 0.4512 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.8986 - dense_359_accuracy: 0.7588 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8251 - dense_365_accuracy: 0.7237 - dense_367_accuracy: 0.6190 - dense_369_accuracy: 0.8635 - dense_371_accuracy: 0.8531 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7412 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6398 - dense_383_accuracy: 0.8810 - loss: 104.3756
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# k: 15, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step - dense_353_accuracy: 0.4929 - dense_355_accuracy: 0.8882 - dense_357_accuracy: 0.8882 - dense_359_accuracy: 0.7763 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8355 - dense_365_accuracy: 0.7692 - dense_367_accuracy: 0.6502 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7412 - dense_379_accuracy: 0.8810 - dense_381_accuracy: 0.6957 - dense_383_accuracy: 0.8706 - loss: 100.0125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# k: 16, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step - dense_353_accuracy: 0.4720 - dense_355_accuracy: 0.9265 - dense_357_accuracy: 0.8986 - dense_359_accuracy: 0.8531 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8043 - dense_365_accuracy: 0.7133 - dense_367_accuracy: 0.6398 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7204 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6190 - dense_383_accuracy: 0.8602 - loss: 95.4591
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# k: 17, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step - dense_353_accuracy: 0.5455 - dense_355_accuracy: 0.9265 - dense_357_accuracy: 0.8986 - dense_359_accuracy: 0.8147 - dense_361_accuracy: 0.8147 - dense_363_accuracy: 0.8147 - dense_365_accuracy: 0.7029 - dense_367_accuracy: 0.6294 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7308 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6469 - dense_383_accuracy: 0.8706 - loss: 91.0785
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# k: 18, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - dense_353_accuracy: 0.5663 - dense_355_accuracy: 0.9161 - dense_357_accuracy: 0.8986 - dense_359_accuracy: 0.8322 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8355 - dense_365_accuracy: 0.7412 - dense_367_accuracy: 0.6711 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7516 - dense_379_accuracy: 0.8706 - dense_381_accuracy: 0.6606 - dense_383_accuracy: 0.8706 - loss: 86.9339
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# k: 19, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 865ms/step - dense_353_accuracy: 0.6190 - dense_355_accuracy: 0.9161 - dense_357_accuracy: 0.8882 - dense_359_accuracy: 0.8427 - dense_361_accuracy: 0.8147 - dense_363_accuracy: 0.8147 - dense_365_accuracy: 0.7588 - dense_367_accuracy: 0.6190 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8706 - dense_377_accuracy: 0.7412 - dense_379_accuracy: 0.8602 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.8602 - loss: 83.3532
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# k: 20, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Test Loss iteration 2: 36.40501476445244
# input_train : (38, 120, 47)
# output_train : (38, 16, 4)
# input_val : (14, 120, 47)
# output_val : (14, 16, 4)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 62s 526ms/step - dense_401_accuracy: 0.1749 - dense_403_accuracy: 0.1261 - dense_405_accuracy: 0.1053 - dense_407_accuracy: 0.1573 - dense_409_accuracy: 0.1436 - dense_411_accuracy: 0.2379 - dense_413_accuracy: 0.3706 - dense_415_accuracy: 0.1924 - dense_417_accuracy: 0.2555 - dense_419_accuracy: 0.1436 - dense_421_accuracy: 0.4232 - dense_423_accuracy: 0.2100 - dense_425_accuracy: 0.5559 - dense_427_accuracy: 0.0702 - dense_429_accuracy: 0.1853 - dense_431_accuracy: 0.7308 - loss: 212.5863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# k: 0, patience: 0
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# k: 9, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step - dense_449_accuracy: 0.5630 - dense_451_accuracy: 0.7308 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.6924 - dense_457_accuracy: 0.7588 - dense_459_accuracy: 0.8043 - dense_461_accuracy: 0.6573 - dense_463_accuracy: 0.6190 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8322 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8043 - dense_473_accuracy: 0.7029 - dense_475_accuracy: 0.8986 - dense_477_accuracy: 0.5247 - dense_479_accuracy: 0.8986 - loss: 130.9733
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# k: 10, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step - dense_449_accuracy: 0.5630 - dense_451_accuracy: 0.7412 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.6573 - dense_457_accuracy: 0.7692 - dense_459_accuracy: 0.8147 - dense_461_accuracy: 0.6573 - dense_463_accuracy: 0.6294 - dense_465_accuracy: 0.8043 - dense_467_accuracy: 0.8427 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8043 - dense_473_accuracy: 0.7029 - dense_475_accuracy: 0.8986 - dense_477_accuracy: 0.5455 - dense_479_accuracy: 0.8882 - loss: 124.9526
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# k: 11, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 960ms/step - dense_449_accuracy: 0.6924 - dense_451_accuracy: 0.7867 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.7308 - dense_457_accuracy: 0.7484 - dense_459_accuracy: 0.8043 - dense_461_accuracy: 0.6573 - dense_463_accuracy: 0.6190 - dense_465_accuracy: 0.8043 - dense_467_accuracy: 0.8427 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8043 - dense_473_accuracy: 0.7133 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.5247 - dense_479_accuracy: 0.8986 - loss: 119.4796
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# k: 12, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - dense_449_accuracy: 0.6118 - dense_451_accuracy: 0.8043 - dense_453_accuracy: 0.9265 - dense_455_accuracy: 0.7516 - dense_457_accuracy: 0.7692 - dense_459_accuracy: 0.8147 - dense_461_accuracy: 0.6469 - dense_463_accuracy: 0.6294 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8427 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8147 - dense_473_accuracy: 0.7029 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.5455 - dense_479_accuracy: 0.8882 - loss: 114.0947
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 13, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - dense_449_accuracy: 0.5943 - dense_451_accuracy: 0.8602 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.6190 - dense_457_accuracy: 0.7692 - dense_459_accuracy: 0.8251 - dense_461_accuracy: 0.6573 - dense_463_accuracy: 0.6502 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8322 - dense_469_accuracy: 0.9545 - dense_471_accuracy: 0.8147 - dense_473_accuracy: 0.7029 - dense_475_accuracy: 0.8986 - dense_477_accuracy: 0.5663 - dense_479_accuracy: 0.8986 - loss: 108.8653
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# k: 14, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step - dense_449_accuracy: 0.7412 - dense_451_accuracy: 0.8706 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.7133 - dense_457_accuracy: 0.7484 - dense_459_accuracy: 0.8043 - dense_461_accuracy: 0.6573 - dense_463_accuracy: 0.6294 - dense_465_accuracy: 0.8043 - dense_467_accuracy: 0.8427 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8043 - dense_473_accuracy: 0.6924 - dense_475_accuracy: 0.8986 - dense_477_accuracy: 0.6014 - dense_479_accuracy: 0.8882 - loss: 104.2894
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# k: 15, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step - dense_449_accuracy: 0.6853 - dense_451_accuracy: 0.8706 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.7308 - dense_457_accuracy: 0.7588 - dense_459_accuracy: 0.8043 - dense_461_accuracy: 0.6782 - dense_463_accuracy: 0.6294 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8322 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8147 - dense_473_accuracy: 0.7133 - dense_475_accuracy: 0.8986 - dense_477_accuracy: 0.6573 - dense_479_accuracy: 0.9194 - loss: 99.3150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 16, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step - dense_449_accuracy: 0.7867 - dense_451_accuracy: 0.8322 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.7971 - dense_457_accuracy: 0.7484 - dense_459_accuracy: 0.8043 - dense_461_accuracy: 0.6749 - dense_463_accuracy: 0.6190 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8427 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8355 - dense_473_accuracy: 0.7237 - dense_475_accuracy: 0.8986 - dense_477_accuracy: 0.7029 - dense_479_accuracy: 0.8986 - loss: 94.8309
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 17, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - dense_449_accuracy: 0.7029 - dense_451_accuracy: 0.8986 - dense_453_accuracy: 0.9265 - dense_455_accuracy: 0.8531 - dense_457_accuracy: 0.7692 - dense_459_accuracy: 0.8147 - dense_461_accuracy: 0.7029 - dense_463_accuracy: 0.6190 - dense_465_accuracy: 0.8251 - dense_467_accuracy: 0.8531 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8147 - dense_473_accuracy: 0.7237 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.6573 - dense_479_accuracy: 0.8986 - loss: 90.5161
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# k: 18, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 856ms/step - dense_449_accuracy: 0.6749 - dense_451_accuracy: 0.8810 - dense_453_accuracy: 0.9265 - dense_455_accuracy: 0.8355 - dense_457_accuracy: 0.7796 - dense_459_accuracy: 0.8355 - dense_461_accuracy: 0.7237 - dense_463_accuracy: 0.6398 - dense_465_accuracy: 0.8355 - dense_467_accuracy: 0.8531 - dense_469_accuracy: 0.9649 - dense_471_accuracy: 0.8355 - dense_473_accuracy: 0.7237 - dense_475_accuracy: 0.9090 - dense_477_accuracy: 0.5384 - dense_479_accuracy: 0.8986 - loss: 85.9596
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# k: 19, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 534ms/step - dense_449_accuracy: 0.7867 - dense_451_accuracy: 0.8706 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.8531 - dense_457_accuracy: 0.7692 - dense_459_accuracy: 0.8147 - dense_461_accuracy: 0.6853 - dense_463_accuracy: 0.6294 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8322 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8147 - dense_473_accuracy: 0.6469 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.6190 - dense_479_accuracy: 0.8986 - loss: 82.7066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# k: 20, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step - dense_449_accuracy: 0.6957 - dense_451_accuracy: 0.8602 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.7588 - dense_457_accuracy: 0.7588 - dense_459_accuracy: 0.8147 - dense_461_accuracy: 0.6749 - dense_463_accuracy: 0.6398 - dense_465_accuracy: 0.8043 - dense_467_accuracy: 0.8322 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8251 - dense_473_accuracy: 0.7133 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.6365 - dense_479_accuracy: 0.8882 - loss: 79.2103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# k: 21, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step - dense_449_accuracy: 0.7133 - dense_451_accuracy: 0.8882 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.8322 - dense_457_accuracy: 0.7588 - dense_459_accuracy: 0.8147 - dense_461_accuracy: 0.7516 - dense_463_accuracy: 0.6398 - dense_465_accuracy: 0.8043 - dense_467_accuracy: 0.8322 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8147 - dense_473_accuracy: 0.7237 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.6853 - dense_479_accuracy: 0.8986 - loss: 75.3092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# k: 22, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - dense_449_accuracy: 0.7308 - dense_451_accuracy: 0.8882 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.6294 - dense_457_accuracy: 0.7692 - dense_459_accuracy: 0.8251 - dense_461_accuracy: 0.7516 - dense_463_accuracy: 0.6398 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8427 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8251 - dense_473_accuracy: 0.7237 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.7412 - dense_479_accuracy: 0.8882 - loss: 72.1258
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# k: 23, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - dense_449_accuracy: 0.8531 - dense_451_accuracy: 0.8322 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.6853 - dense_457_accuracy: 0.7588 - dense_459_accuracy: 0.8251 - dense_461_accuracy: 0.6957 - dense_463_accuracy: 0.6398 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8427 - dense_469_accuracy: 0.9545 - dense_471_accuracy: 0.8355 - dense_473_accuracy: 0.7412 - dense_475_accuracy: 0.8986 - dense_477_accuracy: 0.7412 - dense_479_accuracy: 0.8986 - loss: 68.4498
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# k: 24, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 821ms/step - dense_449_accuracy: 0.8810 - dense_451_accuracy: 0.8882 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.8427 - dense_457_accuracy: 0.7692 - dense_459_accuracy: 0.8706 - dense_461_accuracy: 0.7029 - dense_463_accuracy: 0.6573 - dense_465_accuracy: 0.8251 - dense_467_accuracy: 0.8322 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8322 - dense_473_accuracy: 0.6645 - dense_475_accuracy: 0.8986 - dense_477_accuracy: 0.7692 - dense_479_accuracy: 0.8882 - loss: 65.4679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# k: 25, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 890ms/step - dense_449_accuracy: 0.8602 - dense_451_accuracy: 0.9090 - dense_453_accuracy: 0.9265 - dense_455_accuracy: 0.8147 - dense_457_accuracy: 0.7971 - dense_459_accuracy: 0.8531 - dense_461_accuracy: 0.7308 - dense_463_accuracy: 0.7237 - dense_465_accuracy: 0.8251 - dense_467_accuracy: 0.8427 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8602 - dense_473_accuracy: 0.6749 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.6957 - dense_479_accuracy: 0.8882 - loss: 62.5792
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# k: 26, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step - dense_449_accuracy: 0.8882 - dense_451_accuracy: 0.8882 - dense_453_accuracy: 0.9265 - dense_455_accuracy: 0.8147 - dense_457_accuracy: 0.8043 - dense_459_accuracy: 0.8322 - dense_461_accuracy: 0.7029 - dense_463_accuracy: 0.7133 - dense_465_accuracy: 0.8043 - dense_467_accuracy: 0.8427 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8427 - dense_473_accuracy: 0.6853 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.6678 - dense_479_accuracy: 0.8882 - loss: 59.7618
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# k: 27, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - dense_449_accuracy: 0.8251 - dense_451_accuracy: 0.8882 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.8251 - dense_457_accuracy: 0.8602 - dense_459_accuracy: 0.8322 - dense_461_accuracy: 0.7763 - dense_463_accuracy: 0.7484 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8706 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8147 - dense_473_accuracy: 0.7133 - dense_475_accuracy: 0.9090 - dense_477_accuracy: 0.8043 - dense_479_accuracy: 0.8882 - loss: 57.0515
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# k: 28, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - dense_449_accuracy: 0.8706 - dense_451_accuracy: 0.8986 - dense_453_accuracy: 0.9265 - dense_455_accuracy: 0.8810 - dense_457_accuracy: 0.7692 - dense_459_accuracy: 0.8602 - dense_461_accuracy: 0.8043 - dense_463_accuracy: 0.7692 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.9441 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8043 - dense_473_accuracy: 0.7308 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.8043 - dense_479_accuracy: 0.8882 - loss: 54.6143
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# k: 29, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - dense_449_accuracy: 0.8076 - dense_451_accuracy: 0.8882 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.8043 - dense_457_accuracy: 0.7692 - dense_459_accuracy: 0.8810 - dense_461_accuracy: 0.8147 - dense_463_accuracy: 0.7971 - dense_465_accuracy: 0.8251 - dense_467_accuracy: 0.8810 - dense_469_accuracy: 0.9649 - dense_471_accuracy: 0.8251 - dense_473_accuracy: 0.7971 - dense_475_accuracy: 0.9090 - dense_477_accuracy: 0.8427 - dense_479_accuracy: 0.8986 - loss: 51.8923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 30, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - dense_449_accuracy: 0.8882 - dense_451_accuracy: 0.9090 - dense_453_accuracy: 0.9545 - dense_455_accuracy: 0.8147 - dense_457_accuracy: 0.7484 - dense_459_accuracy: 0.8706 - dense_461_accuracy: 0.7484 - dense_463_accuracy: 0.7763 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8427 - dense_469_accuracy: 0.9720 - dense_471_accuracy: 0.8043 - dense_473_accuracy: 0.7412 - dense_475_accuracy: 0.9161 - dense_477_accuracy: 0.8427 - dense_479_accuracy: 0.8986 - loss: 49.7501
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# k: 31, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step - dense_449_accuracy: 0.9161 - dense_451_accuracy: 0.9161 - dense_453_accuracy: 0.9720 - dense_455_accuracy: 0.8986 - dense_457_accuracy: 0.8355 - dense_459_accuracy: 0.8986 - dense_461_accuracy: 0.8147 - dense_463_accuracy: 0.7308 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8531 - dense_469_accuracy: 1.0000 - dense_471_accuracy: 0.8147 - dense_473_accuracy: 0.6957 - dense_475_accuracy: 0.9441 - dense_477_accuracy: 0.9441 - dense_479_accuracy: 0.9161 - loss: 47.7681
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# k: 32, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 972ms/step - dense_449_accuracy: 0.8986 - dense_451_accuracy: 0.9441 - dense_453_accuracy: 0.9545 - dense_455_accuracy: 0.8322 - dense_457_accuracy: 0.8147 - dense_459_accuracy: 0.8810 - dense_461_accuracy: 0.8322 - dense_463_accuracy: 0.7588 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8531 - dense_469_accuracy: 0.9720 - dense_471_accuracy: 0.7867 - dense_473_accuracy: 0.8322 - dense_475_accuracy: 0.9545 - dense_477_accuracy: 0.9161 - dense_479_accuracy: 0.9161 - loss: 45.9161
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# k: 33, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 816ms/step - dense_449_accuracy: 0.9265 - dense_451_accuracy: 0.9545 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.8427 - dense_457_accuracy: 0.8251 - dense_459_accuracy: 0.8986 - dense_461_accuracy: 0.8986 - dense_463_accuracy: 0.8251 - dense_465_accuracy: 0.8147 - dense_467_accuracy: 0.8882 - dense_469_accuracy: 0.8882 - dense_471_accuracy: 0.8043 - dense_473_accuracy: 0.8322 - dense_475_accuracy: 0.8986 - dense_477_accuracy: 0.8810 - dense_479_accuracy: 0.8882 - loss: 44.0362
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# k: 34, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 744ms/step - dense_449_accuracy: 0.9090 - dense_451_accuracy: 0.9161 - dense_453_accuracy: 0.9161 - dense_455_accuracy: 0.8251 - dense_457_accuracy: 0.7484 - dense_459_accuracy: 0.8882 - dense_461_accuracy: 0.8043 - dense_463_accuracy: 0.8810 - dense_465_accuracy: 0.8043 - dense_467_accuracy: 0.9441 - dense_469_accuracy: 1.0000 - dense_471_accuracy: 0.8251 - dense_473_accuracy: 0.6853 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.9649 - dense_479_accuracy: 0.8882 - loss: 42.3825
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# k: 35, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - dense_449_accuracy: 0.8602 - dense_451_accuracy: 0.8706 - dense_453_accuracy: 0.9265 - dense_455_accuracy: 0.8986 - dense_457_accuracy: 0.7484 - dense_459_accuracy: 0.8882 - dense_461_accuracy: 0.8602 - dense_463_accuracy: 0.7484 - dense_465_accuracy: 0.8043 - dense_467_accuracy: 0.8986 - dense_469_accuracy: 0.9441 - dense_471_accuracy: 0.8043 - dense_473_accuracy: 0.7412 - dense_475_accuracy: 0.8882 - dense_477_accuracy: 0.9545 - dense_479_accuracy: 0.8882 - loss: 40.4282
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# k: 36, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Test Loss iteration 4: 47.01107103651224
# average_loss: 41.611242804546706
