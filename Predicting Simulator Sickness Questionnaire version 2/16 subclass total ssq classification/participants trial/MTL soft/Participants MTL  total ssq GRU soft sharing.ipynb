# %%
from google.colab import drive
import pandas as pd
from sklearn.preprocessing import StandardScaler
from scipy import stats
import numpy as np
import logging
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from datetime import datetime
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime
import matplotlib.dates as mdates
import os

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Set the base path to the desired directory on Google Drive
base_path = '/content/drive/MyDrive/Study_1_Data/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read_csv(file_path):
    data = pd.read_csv(file_path)
    return data

# %%
def process_data(data, columns_to_remove):
    processed_data = data.drop(columns=columns_to_remove).values
    return processed_data

# %%
def construct_3d_array(base_dir, participants, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye):
    """
    Construct 3D array from CSV files.
    """
    num_rows = 180  # Define number of rows to keep (last 180 rows)
    arrays_3d = []

    for participant in participants:
        participant_id = f"{int(participant):02d}"  # Format participant number to two digits

        valid_simulations = []

        for simulation in simulations:
            hr_file_path = os.path.join(base_dir, participant_id, simulation, f'HR{simulation.capitalize()}.csv')
            gsr_file_path = os.path.join(base_dir, participant_id, simulation, f'EDA{simulation.capitalize()}_downsampled.csv')
            head_file_path = os.path.join(base_dir, participant_id, simulation, 'head_tracking_downsampled.csv')
            eye_file_path = os.path.join(base_dir, participant_id, simulation, 'eye_tracking_downsampled.csv')

            # Check if all files exist
            if all(os.path.exists(file) for file in [hr_file_path, gsr_file_path, head_file_path, eye_file_path]):
                valid_simulations.append(simulation)

        num_valid_simulations = len(valid_simulations)
        if num_valid_simulations == 0:
            continue  # Skip this participant if no valid simulations are found

        array_3d = np.zeros((num_valid_simulations, num_rows, 47)) # hr=1, gsr=1, head=15-3, eye=41-8 total columns after removing columns= 48

        for s_idx, simulation in enumerate(valid_simulations):
            # Process hr data
            hr_file_path = os.path.join(base_dir, participant_id, simulation, f'HR{simulation.capitalize()}.csv')
            hr_data = read_csv(hr_file_path)
            processed_hr_data = process_data(hr_data, columns_to_remove_hr)
            processed_hr_data = processed_hr_data[-num_rows:]  # Keep only the last 180 rows

            # Process gsr data
            gsr_file_path = os.path.join(base_dir, participant_id, simulation, f'EDA{simulation.capitalize()}_downsampled.csv')
            gsr_data = read_csv(gsr_file_path)
            processed_gsr_data = process_data(gsr_data, columns_to_remove_gsr)
            processed_gsr_data = processed_gsr_data[-num_rows:]  # Keep only the last 180 rows

            # Process head data
            head_file_path = os.path.join(base_dir, participant_id, simulation, 'head_tracking_downsampled.csv')
            head_data = read_csv(head_file_path)
            processed_head_data = process_data(head_data, columns_to_remove_head)
            processed_head_data = processed_head_data[-num_rows:]  # Keep only the last 180 rows

            # Process eye data
            eye_file_path = os.path.join(base_dir, participant_id, simulation, 'eye_tracking_downsampled.csv')
            eye_data = read_csv(eye_file_path)
            processed_eye_data = process_data(eye_data, columns_to_remove_eye)
            processed_eye_data = processed_eye_data[-num_rows:]  # Keep only the last 180 rows

            # Combine processed data
            combined_data = np.concatenate((processed_hr_data, processed_gsr_data, processed_head_data, processed_eye_data), axis=1)

            array_3d[s_idx, :, :] = combined_data

        arrays_3d.append(array_3d)

    return arrays_3d

# %%
sample_size=30
simulations = ['flat','noise','bumps']
participants = [str(i) for i in range(1, 27)]  # Participants 101 to 127
columns_to_remove_hr = []
columns_to_remove_gsr = []
columns_to_remove_eye = ['#Frame','Time', 'Unnamed: 40','ConvergenceValid','Left_Eye_Closed','Right_Eye_Closed','LocalGazeValid','WorldGazeValid']
columns_to_remove_head = ['#Frame','Time', 'Unnamed: 14']

# %%
def calculate_total_ssq(csv_file):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    n_columns = [0, 5, 6, 7, 8, 14, 15]
    o_columns = [0, 1, 2, 3, 4, 8, 10]
    d_columns = [4, 7, 9, 10, 11, 12, 13]

    # Calculate sum for each specified set of columns
    n_val = df.iloc[0, n_columns].sum()
    o_val = df.iloc[0, o_columns].sum()
    d_val = df.iloc[0, d_columns].sum()

    return n_val, o_val, d_val

# %%
def merge_ssq_column(conditions,participants):
  directories = []
  total_ssq_values = []
  for participant in participants:
      participant = f"{int(participant):02d}"
      for condition in conditions:
          directory = os.path.join(base_path, participant, condition)
          directories.append(directory)

  # Loop through each directory
  for directory in directories:
      # Check if the directory exists
      if not os.path.exists(directory):
          continue

      # Get all CSV files in the directory that are named 'ssq.csv'
      csv_files = [file for file in os.listdir(directory) if file == 'ssq.csv']

      # Loop through each CSV file
      for csv_file in csv_files:
          csv_path = os.path.join(directory, csv_file)
          df = pd.read_csv(csv_path)
          # n_val,o_val,d_val = calculate_total_ssq(csv_path)
          # total_ssq_values.append([n_val, o_val, d_val])
          ssq_values_participant = df.iloc[:, 0:17].values.flatten()   # Assuming SSQ values are in columns 1 to 16
          total_ssq_values.append(ssq_values_participant)
  ssq_array = np.array(total_ssq_values)
  return ssq_array

def merge_total_ssq(conditions,participants):
  directories = []
  total_ssq_values = []
  for participant in participants:
      participant = f"{int(participant):02d}"
      for condition in conditions:
          directory = os.path.join(base_path, participant, condition)
          directories.append(directory)

  # Loop through each directory
  for directory in directories:
      # Check if the directory exists
      if not os.path.exists(directory):
          continue

      # Get all CSV files in the directory that are named 'ssq.csv'
      csv_files = [file for file in os.listdir(directory) if file == 'ssq.csv']

      # Loop through each CSV file
      for csv_file in csv_files:
          csv_path = os.path.join(directory, csv_file)
          n_val,o_val,d_val = calculate_total_ssq(csv_path)
          total_ssq = (n_val+o_val+d_val) * 3.74
          df = pd.read_csv(csv_path)
          df["total-ssq"] = total_ssq
          #print("csv_path: ",csv_path,"   ",total_ssq)
          total_ssq_values.append(total_ssq)
  # Create a DataFrame from the list of total SSQ values
  df_total_ssq = pd.DataFrame(total_ssq_values, columns=["total-ssq"])
  # Convert the list of total SSQ values to a NumPy array
  total_ssq_array = np.array(total_ssq_values)
  return total_ssq_array

# %%
participants_group_1 = [1,3,4,11,25]
participants_group_2 = [2,7,8,9,17]
participants_group_3 = [10,12,13,22,23]
participants_group_4 = [5,14,18,20,21]
participants_group_5 = [6,15,16,19,24,26]

arrays_group_1 = construct_3d_array(base_path, participants_group_1, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_2 = construct_3d_array(base_path, participants_group_2, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_3 = construct_3d_array(base_path, participants_group_3, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_4 = construct_3d_array(base_path, participants_group_4, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_5 = construct_3d_array(base_path, participants_group_5, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)

# %%
# Concatenate arrays along the first axis
input_group_1 = np.concatenate(arrays_group_1, axis=0)
input_group_2 = np.concatenate(arrays_group_2, axis=0)
input_group_3 = np.concatenate(arrays_group_3, axis=0)
input_group_4 = np.concatenate(arrays_group_4, axis=0)
input_group_5 = np.concatenate(arrays_group_5, axis=0)

# %%
output_group_1=merge_ssq_column(simulations,participants_group_1)
output_group_2=merge_ssq_column(simulations,participants_group_2)
output_group_3=merge_ssq_column(simulations,participants_group_3)
output_group_4=merge_ssq_column(simulations,participants_group_4)
output_group_5=merge_ssq_column(simulations,participants_group_5)

output_group_1 = np.squeeze(output_group_1)
output_group_2 = np.squeeze(output_group_2)
output_group_3 = np.squeeze(output_group_3)
output_group_4 = np.squeeze(output_group_4)
output_group_5 = np.squeeze(output_group_5)


output_total_ssq_group_1=merge_total_ssq(simulations,participants_group_1)
output_total_ssq_group_2=merge_total_ssq(simulations,participants_group_2)
output_total_ssq_group_3=merge_total_ssq(simulations,participants_group_3)
output_total_ssq_group_4=merge_total_ssq(simulations,participants_group_4)
output_total_ssq_group_5=merge_total_ssq(simulations,participants_group_5)

output_total_ssq_group_1=output_total_ssq_group_1.reshape(-1, 1)
output_total_ssq_group_2=output_total_ssq_group_2.reshape(-1, 1)
output_total_ssq_group_3=output_total_ssq_group_3.reshape(-1, 1)
output_total_ssq_group_4=output_total_ssq_group_4.reshape(-1, 1)
output_total_ssq_group_5=output_total_ssq_group_5.reshape(-1, 1)

# %%
def scale_input_data(input_train, input_test):
    # Get the shape of the input data
    num_samples_train, time_steps_train, num_features = input_train.shape
    num_samples_test, time_steps_test, _ = input_test.shape

    # Reshape the input data into 2D arrays
    flattened_train_data = input_train.reshape(-1, num_features)
    flattened_test_data = input_test.reshape(-1, num_features)

    # Initialize a MinMaxScaler object
    scaler = MinMaxScaler()

    # Fit the scaler on the training data and transform both train and test data
    scaled_train_data = scaler.fit_transform(flattened_train_data)
    scaled_test_data = scaler.transform(flattened_test_data)

    # Reshape the scaled data back to its original shape
    scaled_train_data = scaled_train_data.reshape(num_samples_train, time_steps_train, num_features)
    scaled_test_data = scaled_test_data.reshape(num_samples_test, time_steps_test, num_features)

    return scaled_train_data, scaled_test_data

def scale_target_var(target_data):
    min_val, max_val = np.min(target_data, axis=0), np.max(target_data, axis=0)
    target_data = (target_data-min_val)/(max_val-min_val)

    return target_data, min_val, max_val

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, GRU, Dense, Dropout
from keras.models import Model
import numpy as np
import sklearn
from keras.utils import to_categorical

def soft_parameter_sharing_regularizer(model, alpha=0.01):
    GRU_layers = [layer for layer in model.layers if isinstance(layer, GRU)]
    if not GRU_layers:
        return 0.0

    weights = [tf.convert_to_tensor(layer.weights[0]) for layer in GRU_layers]

    shared_weights = tf.reduce_mean(tf.stack(weights), axis=0)
    return alpha * tf.reduce_sum([tf.reduce_sum(tf.square(w - shared_weights)) for w in weights])


def get_individual_GRU(input_shape1, input_shape2):
    input_layer = Input(shape=(input_shape1, input_shape2))

    GRU_layers = []
    for _ in range(output_train.shape[1]):
        x = GRU(64, return_sequences=False)(input_layer)
        x = Dense(256, activation='relu')(x)
        x = Dropout(0.2)(x)
        GRU_layers.append(x)

    return GRU_layers, input_layer


def get_output_model(GRU_outputs, output_shape):
    output_models = []
    for i in range(output_shape[1]):
        output = Dense(256, activation='relu')(GRU_outputs[i])
        output = Dropout(0.2)(output)
        output = Dense(4, activation='softmax')(output)  # Output shape is (None, 4) for 4 classes
        output_models.append(output)
    return output_models

total_losses = []
for iteration in range(5):



  # Assuming input_groups and output_groups are lists of arrays for the 5 groups
    input_groups = [input_group_1, input_group_2, input_group_3, input_group_4, input_group_5]
    output_groups = [output_group_1, output_group_2, output_group_3, output_group_4, output_group_5]
    ssq_groups = [output_total_ssq_group_1, output_total_ssq_group_2, output_total_ssq_group_3, output_total_ssq_group_4, output_total_ssq_group_5]

    # Initialize lists for storing training, validation, and test sets
    X_train, X_val, X_test = [], [], []
    y_train, y_val, y_test = [], [], []
    ssq_train, ssq_val, ssq_test = [], [], []

    # Loop over each group
    for input_group, output_group, ssq_group in zip(input_groups, output_groups, ssq_groups):
        # Step 1: Split the group into a training/validation set (80%) and a test set (20%)
        X_temp, X_test_temp, y_temp, y_test_temp, ssq_temp, ssq_test_temp = train_test_split(
            input_group, output_group, ssq_group, test_size=0.2)

        # Step 2: Split the training/validation set into a training set (60%) and a validation set (20%)
        X_train_temp, X_val_temp, y_train_temp, y_val_temp, ssq_train_temp, ssq_val_temp = train_test_split(
            X_temp, y_temp, ssq_temp, test_size=0.25)  # 0.25 * 0.8 = 0.2

        # Step 3: Append the results to the corresponding lists
        X_train.append(X_train_temp)
        X_val.append(X_val_temp)
        X_test.append(X_test_temp)

        y_train.append(y_train_temp)
        y_val.append(y_val_temp)
        y_test.append(y_test_temp)

        ssq_train.append(ssq_train_temp)
        ssq_val.append(ssq_val_temp)
        ssq_test.append(ssq_test_temp)

    # After the loop, concatenate the data for all groups if needed
    input_train = np.concatenate(X_train, axis=0)
    input_val = np.concatenate(X_val, axis=0)
    input_test = np.concatenate(X_test, axis=0)

    output_train = np.concatenate(y_train, axis=0)
    output_val = np.concatenate(y_val, axis=0)
    output_test = np.concatenate(y_test, axis=0)


    output_val_total_ssq = np.concatenate(ssq_val, axis=0)
    output_test_total_ssq = np.concatenate(ssq_test, axis=0)
    # input_train, input_test= scale_input_data(input_train[:, (60-sample_size):(180-sample_size), :], input_test[:, (60-sample_size):(180-sample_size), :])
    # output_train, min_val, max_val = scale_target_var(output_train)


    #  this section for scaling both train and validation set simultaniously
      # Step 1: Combine the training and validation sets
    combined_input = np.concatenate([input_train, input_val], axis=0)
    combined_output = np.concatenate([output_train, output_val], axis=0)

    # Step 2: Scale the combined input data
    # Assuming scale_input_data scales the data based on the combined dataset
    combined_input, input_test = scale_input_data(
        combined_input[:, (60-sample_size):(180-sample_size), :],
        input_test[:, (60-sample_size):(180-sample_size), :]
    )

    # Convert the original labels to one-hot encoded format
    output_train_encoded = to_categorical(combined_output, num_classes=4)

    # Step 4: Split the combined data back into training and validation sets
    # Use the original shapes of input_train and input_val to slice the combined arrays
    input_train = combined_input[:input_train.shape[0], :, :]
    input_val = combined_input[input_train.shape[0]:, :, :]

    output_train = output_train_encoded[:output_train.shape[0], :]
    output_val = output_train_encoded[output_train.shape[0]:, :]



    print("input_train :", input_train.shape)
    print("output_train :", output_train.shape)
    print("input_val :", input_val.shape)
    print("output_val :", output_val.shape)
    print("input_test :", input_test.shape)
    print("output_test :", output_test.shape)



    train_input_reshaped = input_train.reshape((input_train.shape[0], input_train.shape[1], input_train.shape[2]))
    test_input_reshaped = input_test.reshape((input_test.shape[0], input_test.shape[1], input_test.shape[2]))
    val_input_reshaped = input_val.reshape((input_val.shape[0], input_val.shape[1], input_val.shape[2]))

    # Get individual GRU outputs
    GRU_outputs, input_layer = get_individual_GRU(input_train.shape[1], input_train.shape[2])

    # Create separate output models for each column
    output_models = get_output_model(GRU_outputs, output_train.shape)

    # Create combined model
    model = Model(inputs=input_layer, outputs=output_models)

    # Custom loss function
    def custom_loss(y_true, y_pred):
        cce = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        reg_loss = soft_parameter_sharing_regularizer(model)
        return cce + reg_loss

    # Compile and train the model
    model.compile(loss=custom_loss, optimizer='adam', metrics=[['accuracy'] for _ in range(output_train.shape[1])])

    best_val_loss = float('inf')
    patience = 0
    best_model = None

    for k in range(200):
        model.fit(train_input_reshaped, [output_train[:, i] for i in range(output_train.shape[1])], epochs=1, batch_size=32)
        pred_val = np.array(model.predict(val_input_reshaped))
        pred_val = np.transpose(pred_val.squeeze(), (1, 0, 2))
        pred_val = np.argmax(pred_val, axis=-1).reshape(pred_val.shape[:-1])

        print(f"k: {k}, patience: {patience}")

        # SSQ Calculation logic...


        # Evaluate the model based on SSQ for validation data
        losses = []
        for i in range(pred_val.shape[0]):
            total_ssq = 0
            for j in [0, 5, 6, 7, 8, 14, 15]:
                total_ssq += np.sum(pred_val[i, j])

            for j in [0, 1, 2, 3, 4, 8, 10]:
                total_ssq += np.sum(pred_val[i, j])

            for j in [4, 7, 9, 10, 11, 12, 13]:
                total_ssq += np.sum(pred_val[i, j])

            total_ssq *= 3.74
            output_val_ssq = output_val_total_ssq[i, 0]
            loss = sklearn.metrics.mean_squared_error([total_ssq], [output_val_ssq], squared=False)
            losses.append(loss)

        tmp_val_loss = np.mean(losses)
        if tmp_val_loss <= best_val_loss:
            best_val_loss = tmp_val_loss
            patience = 0
            best_model = model
        else:
            patience += 1
            if patience > 10:
                break

    # Predict and evaluate test data using the best model
    pred_test = np.array(best_model.predict(test_input_reshaped))
    pred_test = np.transpose(pred_test.squeeze(), (1, 0, 2))
    pred_test = np.argmax(pred_test, axis=-1).reshape(pred_test.shape[:-1])

    pred_total_ssq = []
    for i in range(pred_test.shape[0]):
        total_ssq = 0
        for j in [0, 5, 6, 7, 8, 14, 15]:
            total_ssq += np.sum(pred_test[i, j])

        for j in [0, 1, 2, 3, 4, 8, 10]:
            total_ssq += np.sum(pred_test[i, j])

        for j in [4, 7, 9, 10, 11, 12, 13]:
            total_ssq += np.sum(pred_test[i, j])

        total_ssq *= 3.74
        pred_total_ssq.append(total_ssq)

    # Overall Test Loss
    loss = sklearn.metrics.mean_squared_error(pred_total_ssq, output_test_total_ssq, squared=False)
    print(f"Test Loss iteration {iteration}: {loss}")
    total_losses.append(loss)
average_loss = sum(total_losses) / len(total_losses)
total_losses.append(average_loss)
print("average_loss:", average_loss)
# Out:
# input_train : (38, 120, 47)
# output_train : (38, 16, 4)
# input_val : (14, 120, 47)
# output_val : (14, 16, 4)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - dense_305_accuracy: 0.1469 - dense_307_accuracy: 0.2100 - dense_309_accuracy: 0.2275 - dense_311_accuracy: 0.0806 - dense_313_accuracy: 0.3849 - dense_315_accuracy: 0.1612 - dense_317_accuracy: 0.3882 - dense_319_accuracy: 0.3114 - dense_321_accuracy: 0.7204 - dense_323_accuracy: 0.1436 - dense_325_accuracy: 0.1891 - dense_327_accuracy: 0.2275 - dense_329_accuracy: 0.3114 - dense_331_accuracy: 0.0526 - dense_333_accuracy: 0.2379 - dense_335_accuracy: 0.7029 - loss: 202.9456
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# k: 0, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 694ms/step - dense_305_accuracy: 0.4929 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6573 - dense_313_accuracy: 0.7588 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.5104 - dense_319_accuracy: 0.6294 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.9090 - dense_333_accuracy: 0.6398 - dense_335_accuracy: 0.8602 - loss: 190.6770
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# k: 1, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 684ms/step - dense_305_accuracy: 0.5175 - dense_307_accuracy: 0.7484 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6678 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.4896 - dense_319_accuracy: 0.6294 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7484 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6190 - dense_335_accuracy: 0.8706 - loss: 180.8843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# k: 2, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 690ms/step - dense_305_accuracy: 0.4720 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6573 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.4896 - dense_319_accuracy: 0.6190 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6190 - dense_335_accuracy: 0.8602 - loss: 173.5252
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# k: 3, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_305_accuracy: 0.4616 - dense_307_accuracy: 0.7692 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6365 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.4896 - dense_319_accuracy: 0.6190 - dense_321_accuracy: 0.9194 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.8986 - dense_333_accuracy: 0.6190 - dense_335_accuracy: 0.8706 - loss: 166.9451
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# k: 4, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 662ms/step - dense_305_accuracy: 0.4512 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6469 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.5000 - dense_319_accuracy: 0.6086 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7516 - dense_329_accuracy: 0.7484 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6190 - dense_335_accuracy: 0.8706 - loss: 161.5345
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# k: 5, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 660ms/step - dense_305_accuracy: 0.4720 - dense_307_accuracy: 0.7900 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6990 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.5000 - dense_319_accuracy: 0.6190 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9370 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.8986 - dense_333_accuracy: 0.6190 - dense_335_accuracy: 0.8706 - loss: 155.1002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# k: 6, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 781ms/step - dense_305_accuracy: 0.4720 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6469 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.4792 - dense_319_accuracy: 0.6294 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6294 - dense_335_accuracy: 0.8706 - loss: 149.4511
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# k: 7, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_305_accuracy: 0.4825 - dense_307_accuracy: 0.7692 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6853 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8810 - dense_317_accuracy: 0.5104 - dense_319_accuracy: 0.6398 - dense_321_accuracy: 0.9090 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7204 - dense_329_accuracy: 0.7692 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6294 - dense_335_accuracy: 0.8602 - loss: 143.0966
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# k: 8, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 658ms/step - dense_305_accuracy: 0.4720 - dense_307_accuracy: 0.7692 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6573 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.5104 - dense_319_accuracy: 0.6294 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6398 - dense_335_accuracy: 0.8706 - loss: 137.7265
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# k: 9, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step - dense_305_accuracy: 0.4616 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6749 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.5104 - dense_319_accuracy: 0.6294 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6398 - dense_335_accuracy: 0.8706 - loss: 132.4989
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# k: 10, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 663ms/step - dense_305_accuracy: 0.4616 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6573 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.4792 - dense_319_accuracy: 0.6190 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7204 - dense_329_accuracy: 0.7484 - dense_331_accuracy: 0.9090 - dense_333_accuracy: 0.6190 - dense_335_accuracy: 0.8602 - loss: 127.6003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# k: 11, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - dense_305_accuracy: 0.5000 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6645 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.5559 - dense_319_accuracy: 0.6398 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7692 - dense_331_accuracy: 0.8986 - dense_333_accuracy: 0.6398 - dense_335_accuracy: 0.8810 - loss: 122.4998
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# k: 12, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 966ms/step - dense_305_accuracy: 0.5384 - dense_307_accuracy: 0.7692 - dense_309_accuracy: 0.9370 - dense_311_accuracy: 0.6782 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.5104 - dense_319_accuracy: 0.6502 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.9090 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7621 - dense_329_accuracy: 0.7692 - dense_331_accuracy: 0.9090 - dense_333_accuracy: 0.6398 - dense_335_accuracy: 0.8810 - loss: 117.3614
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# k: 13, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 654ms/step - dense_305_accuracy: 0.5071 - dense_307_accuracy: 0.7484 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6678 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.5455 - dense_319_accuracy: 0.6294 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6190 - dense_335_accuracy: 0.8602 - loss: 113.4395
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# k: 14, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 653ms/step - dense_305_accuracy: 0.4720 - dense_307_accuracy: 0.7484 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6469 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.5208 - dense_319_accuracy: 0.6398 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7692 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6606 - dense_335_accuracy: 0.8810 - loss: 108.8502
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# k: 15, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 650ms/step - dense_305_accuracy: 0.4720 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6469 - dense_313_accuracy: 0.8076 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.5630 - dense_319_accuracy: 0.6398 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7692 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6294 - dense_335_accuracy: 0.8706 - loss: 104.5997
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# k: 16, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_305_accuracy: 0.4616 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6678 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.5806 - dense_319_accuracy: 0.6190 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7516 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6294 - dense_335_accuracy: 0.8706 - loss: 100.6240
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# k: 17, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 671ms/step - dense_305_accuracy: 0.4896 - dense_307_accuracy: 0.7588 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6886 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.5839 - dense_319_accuracy: 0.6398 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7484 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6190 - dense_335_accuracy: 0.8602 - loss: 96.6722
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# k: 18, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 699ms/step - dense_305_accuracy: 0.5000 - dense_307_accuracy: 0.7692 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6573 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.5735 - dense_319_accuracy: 0.6398 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.8986 - dense_333_accuracy: 0.6190 - dense_335_accuracy: 0.8602 - loss: 92.8969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# k: 19, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 686ms/step - dense_305_accuracy: 0.5000 - dense_307_accuracy: 0.7692 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6190 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8810 - dense_317_accuracy: 0.5735 - dense_319_accuracy: 0.6294 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9370 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.8986 - dense_333_accuracy: 0.6398 - dense_335_accuracy: 0.8706 - loss: 89.0891
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# k: 20, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_305_accuracy: 0.5663 - dense_307_accuracy: 0.8986 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6853 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8810 - dense_317_accuracy: 0.5943 - dense_319_accuracy: 0.6502 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7692 - dense_331_accuracy: 0.9090 - dense_333_accuracy: 0.6398 - dense_335_accuracy: 0.8706 - loss: 85.4450
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# k: 21, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 645ms/step - dense_305_accuracy: 0.5735 - dense_307_accuracy: 0.8602 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7484 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.5839 - dense_319_accuracy: 0.6678 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7796 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6398 - dense_335_accuracy: 0.8706 - loss: 82.2497
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# k: 22, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 652ms/step - dense_305_accuracy: 0.6118 - dense_307_accuracy: 0.8706 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6924 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8810 - dense_317_accuracy: 0.6398 - dense_319_accuracy: 0.7308 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7692 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6502 - dense_335_accuracy: 0.8602 - loss: 79.1479
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# k: 23, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - dense_305_accuracy: 0.5735 - dense_307_accuracy: 0.7971 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6782 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8810 - dense_317_accuracy: 0.6678 - dense_319_accuracy: 0.6749 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7796 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.7133 - dense_335_accuracy: 0.8706 - loss: 76.1724
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# k: 24, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_305_accuracy: 0.5630 - dense_307_accuracy: 0.7867 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.6853 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.7237 - dense_319_accuracy: 0.7133 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7692 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.7237 - dense_335_accuracy: 0.8706 - loss: 73.2594
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# k: 25, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 679ms/step - dense_305_accuracy: 0.5839 - dense_307_accuracy: 0.7867 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.6749 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.8706 - dense_317_accuracy: 0.7029 - dense_319_accuracy: 0.7029 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7588 - dense_329_accuracy: 0.7763 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6469 - dense_335_accuracy: 0.8602 - loss: 70.1300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# k: 26, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 656ms/step - dense_305_accuracy: 0.6118 - dense_307_accuracy: 0.8706 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.7029 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.7308 - dense_319_accuracy: 0.6294 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7588 - dense_331_accuracy: 0.9090 - dense_333_accuracy: 0.6294 - dense_335_accuracy: 0.8602 - loss: 67.3379
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# k: 27, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - dense_305_accuracy: 0.6469 - dense_307_accuracy: 0.8706 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7133 - dense_313_accuracy: 0.7867 - dense_315_accuracy: 0.8602 - dense_317_accuracy: 0.5735 - dense_319_accuracy: 0.6190 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7692 - dense_329_accuracy: 0.7484 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6190 - dense_335_accuracy: 0.8602 - loss: 64.8310
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 28, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_305_accuracy: 0.6014 - dense_307_accuracy: 0.8986 - dense_309_accuracy: 0.9265 - dense_311_accuracy: 0.7971 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8810 - dense_317_accuracy: 0.5839 - dense_319_accuracy: 0.6573 - dense_321_accuracy: 0.9090 - dense_323_accuracy: 0.9265 - dense_325_accuracy: 0.9370 - dense_327_accuracy: 0.7971 - dense_329_accuracy: 0.7692 - dense_331_accuracy: 0.9090 - dense_333_accuracy: 0.6294 - dense_335_accuracy: 0.8810 - loss: 61.8821
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# k: 29, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 750ms/step - dense_305_accuracy: 0.6678 - dense_307_accuracy: 0.8882 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7867 - dense_313_accuracy: 0.7971 - dense_315_accuracy: 0.8986 - dense_317_accuracy: 0.6223 - dense_319_accuracy: 0.7061 - dense_321_accuracy: 0.8986 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9265 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7796 - dense_331_accuracy: 0.8986 - dense_333_accuracy: 0.6606 - dense_335_accuracy: 0.8810 - loss: 59.2906
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# k: 30, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 670ms/step - dense_305_accuracy: 0.7308 - dense_307_accuracy: 0.8043 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7484 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.9265 - dense_317_accuracy: 0.6014 - dense_319_accuracy: 0.7029 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9441 - dense_327_accuracy: 0.7484 - dense_329_accuracy: 0.7484 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.7308 - dense_335_accuracy: 0.8602 - loss: 57.5094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# k: 31, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 662ms/step - dense_305_accuracy: 0.7412 - dense_307_accuracy: 0.8706 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7133 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.9161 - dense_317_accuracy: 0.6573 - dense_319_accuracy: 0.7204 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8986 - dense_325_accuracy: 0.9441 - dense_327_accuracy: 0.7412 - dense_329_accuracy: 0.7867 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.8147 - dense_335_accuracy: 0.8882 - loss: 55.4333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# k: 32, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 670ms/step - dense_305_accuracy: 0.6469 - dense_307_accuracy: 0.8882 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7308 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.8882 - dense_317_accuracy: 0.7308 - dense_319_accuracy: 0.6924 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7308 - dense_329_accuracy: 0.7484 - dense_331_accuracy: 0.8986 - dense_333_accuracy: 0.7763 - dense_335_accuracy: 0.8882 - loss: 53.1315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# k: 33, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - dense_305_accuracy: 0.6190 - dense_307_accuracy: 0.9161 - dense_309_accuracy: 0.9161 - dense_311_accuracy: 0.7588 - dense_313_accuracy: 0.7763 - dense_315_accuracy: 0.8810 - dense_317_accuracy: 0.7029 - dense_319_accuracy: 0.6469 - dense_321_accuracy: 0.8882 - dense_323_accuracy: 0.8882 - dense_325_accuracy: 0.9161 - dense_327_accuracy: 0.7484 - dense_329_accuracy: 0.7692 - dense_331_accuracy: 0.8882 - dense_333_accuracy: 0.6398 - dense_335_accuracy: 0.8706 - loss: 51.1589
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# k: 34, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Test Loss iteration 0: 37.87615641798941
# input_train : (38, 120, 47)
# output_train : (38, 16, 4)
# input_val : (14, 120, 47)
# output_val : (14, 16, 4)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 76s 705ms/step - dense_353_accuracy: 0.2204 - dense_355_accuracy: 0.7133 - dense_357_accuracy: 0.1157 - dense_359_accuracy: 0.2484 - dense_361_accuracy: 0.3498 - dense_363_accuracy: 0.8147 - dense_365_accuracy: 0.2834 - dense_367_accuracy: 0.1957 - dense_369_accuracy: 0.5910 - dense_371_accuracy: 0.1541 - dense_373_accuracy: 0.2730 - dense_375_accuracy: 0.3673 - dense_377_accuracy: 0.2555 - dense_379_accuracy: 0.5526 - dense_381_accuracy: 0.2484 - dense_383_accuracy: 0.3569 - loss: 202.6501
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# k: 0, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_353_accuracy: 0.5384 - dense_355_accuracy: 0.8076 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.6014 - dense_361_accuracy: 0.6573 - dense_363_accuracy: 0.8635 - dense_365_accuracy: 0.6398 - dense_367_accuracy: 0.6118 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.7133 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.5839 - dense_383_accuracy: 0.9441 - loss: 190.3337
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# k: 1, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 683ms/step - dense_353_accuracy: 0.5000 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6118 - dense_361_accuracy: 0.6678 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6294 - dense_367_accuracy: 0.5735 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8635 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.6853 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.5735 - dense_383_accuracy: 0.9441 - loss: 180.5707
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# k: 2, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 694ms/step - dense_353_accuracy: 0.4128 - dense_355_accuracy: 0.7763 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.5910 - dense_361_accuracy: 0.6365 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6086 - dense_367_accuracy: 0.5630 - dense_369_accuracy: 0.8043 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.6853 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.5735 - dense_383_accuracy: 0.9441 - loss: 172.9107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# k: 3, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 689ms/step - dense_353_accuracy: 0.5280 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6118 - dense_361_accuracy: 0.7061 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6294 - dense_367_accuracy: 0.5839 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.6853 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.5839 - dense_383_accuracy: 0.9441 - loss: 165.7468
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# k: 4, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 687ms/step - dense_353_accuracy: 0.5455 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6014 - dense_361_accuracy: 0.6573 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6086 - dense_367_accuracy: 0.5630 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8531 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.6853 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.5630 - dense_383_accuracy: 0.9441 - loss: 159.8460
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# k: 5, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 790ms/step - dense_353_accuracy: 0.5559 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.5910 - dense_361_accuracy: 0.7029 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6398 - dense_367_accuracy: 0.5735 - dense_369_accuracy: 0.8043 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.6645 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.5630 - dense_383_accuracy: 0.9441 - loss: 154.0084
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# k: 6, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_353_accuracy: 0.4441 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6014 - dense_361_accuracy: 0.7061 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6294 - dense_367_accuracy: 0.5839 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8076 - dense_377_accuracy: 0.6957 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.5943 - dense_383_accuracy: 0.9441 - loss: 147.9951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# k: 7, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 694ms/step - dense_353_accuracy: 0.6678 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6223 - dense_361_accuracy: 0.7061 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6398 - dense_367_accuracy: 0.5839 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.6749 - dense_379_accuracy: 0.9370 - dense_381_accuracy: 0.5943 - dense_383_accuracy: 0.9545 - loss: 142.3191
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# k: 8, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 696ms/step - dense_353_accuracy: 0.5280 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.5910 - dense_361_accuracy: 0.7763 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6190 - dense_367_accuracy: 0.5735 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.6957 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.5839 - dense_383_accuracy: 0.9441 - loss: 137.2150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# k: 9, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 692ms/step - dense_353_accuracy: 0.5000 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6118 - dense_361_accuracy: 0.6398 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6294 - dense_367_accuracy: 0.5455 - dense_369_accuracy: 0.8043 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8043 - dense_377_accuracy: 0.6749 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6118 - dense_383_accuracy: 0.9545 - loss: 132.0351
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# k: 10, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_353_accuracy: 0.5839 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.6573 - dense_361_accuracy: 0.7692 - dense_363_accuracy: 0.8531 - dense_365_accuracy: 0.6398 - dense_367_accuracy: 0.6294 - dense_369_accuracy: 0.8355 - dense_371_accuracy: 0.8531 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.7204 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.5839 - dense_383_accuracy: 0.9441 - loss: 126.2851
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# k: 11, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 662ms/step - dense_353_accuracy: 0.5351 - dense_355_accuracy: 0.7763 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6118 - dense_361_accuracy: 0.7692 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6398 - dense_367_accuracy: 0.6223 - dense_369_accuracy: 0.8043 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.6853 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.9441 - loss: 121.7022
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# k: 12, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 681ms/step - dense_353_accuracy: 0.5104 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6398 - dense_361_accuracy: 0.6853 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6294 - dense_367_accuracy: 0.6118 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8531 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.6853 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.6749 - dense_383_accuracy: 0.9441 - loss: 116.7976
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# k: 13, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 689ms/step - dense_353_accuracy: 0.5175 - dense_355_accuracy: 0.7763 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.5839 - dense_361_accuracy: 0.7204 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6294 - dense_367_accuracy: 0.5630 - dense_369_accuracy: 0.8043 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7763 - dense_377_accuracy: 0.7029 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.5910 - dense_383_accuracy: 0.9441 - loss: 112.4164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# k: 14, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_353_accuracy: 0.4792 - dense_355_accuracy: 0.7763 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.7133 - dense_361_accuracy: 0.6749 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6190 - dense_367_accuracy: 0.5526 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7763 - dense_377_accuracy: 0.6645 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.5735 - dense_383_accuracy: 0.9441 - loss: 107.9691
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# k: 15, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 680ms/step - dense_353_accuracy: 0.5559 - dense_355_accuracy: 0.7763 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6853 - dense_361_accuracy: 0.7588 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6086 - dense_367_accuracy: 0.5526 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8076 - dense_377_accuracy: 0.7133 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.5839 - dense_383_accuracy: 0.9441 - loss: 103.8375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# k: 16, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 655ms/step - dense_353_accuracy: 0.5663 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6573 - dense_361_accuracy: 0.6853 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6294 - dense_367_accuracy: 0.5839 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.7061 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.5735 - dense_383_accuracy: 0.9545 - loss: 99.5943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# k: 17, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 687ms/step - dense_353_accuracy: 0.5351 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6014 - dense_361_accuracy: 0.7133 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6294 - dense_367_accuracy: 0.5630 - dense_369_accuracy: 0.8355 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.7029 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.5735 - dense_383_accuracy: 0.9441 - loss: 96.1288
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# k: 18, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_353_accuracy: 0.5943 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6223 - dense_361_accuracy: 0.7763 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6398 - dense_367_accuracy: 0.5735 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.7588 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.5839 - dense_383_accuracy: 0.9545 - loss: 92.1403
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# k: 19, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 838ms/step - dense_353_accuracy: 0.4408 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6294 - dense_361_accuracy: 0.7867 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6398 - dense_367_accuracy: 0.5735 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7763 - dense_377_accuracy: 0.7867 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.5839 - dense_383_accuracy: 0.9441 - loss: 88.7516
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# k: 20, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 662ms/step - dense_353_accuracy: 0.5768 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.7412 - dense_361_accuracy: 0.8043 - dense_363_accuracy: 0.8635 - dense_365_accuracy: 0.6573 - dense_367_accuracy: 0.5839 - dense_369_accuracy: 0.7971 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.8355 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.6398 - dense_383_accuracy: 0.9441 - loss: 84.8728
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# k: 21, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 670ms/step - dense_353_accuracy: 0.5000 - dense_355_accuracy: 0.8076 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.8147 - dense_361_accuracy: 0.8147 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6749 - dense_367_accuracy: 0.5735 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8531 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7763 - dense_377_accuracy: 0.7412 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6014 - dense_383_accuracy: 0.9441 - loss: 81.6888
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# k: 22, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - dense_353_accuracy: 0.5384 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.7341 - dense_361_accuracy: 0.8043 - dense_363_accuracy: 0.8635 - dense_365_accuracy: 0.6957 - dense_367_accuracy: 0.6853 - dense_369_accuracy: 0.8355 - dense_371_accuracy: 0.8635 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.7971 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.7166 - dense_383_accuracy: 0.9441 - loss: 78.2309
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# k: 23, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_353_accuracy: 0.6118 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6469 - dense_361_accuracy: 0.7484 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6398 - dense_367_accuracy: 0.6469 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7763 - dense_377_accuracy: 0.7484 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.9441 - loss: 75.4517
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# k: 24, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 680ms/step - dense_353_accuracy: 0.6014 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.7971 - dense_361_accuracy: 0.8147 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6190 - dense_367_accuracy: 0.5735 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.7971 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6645 - dense_383_accuracy: 0.9545 - loss: 72.4447
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# k: 25, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 665ms/step - dense_353_accuracy: 0.5910 - dense_355_accuracy: 0.7763 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6645 - dense_361_accuracy: 0.8322 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6086 - dense_367_accuracy: 0.5630 - dense_369_accuracy: 0.8043 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8076 - dense_377_accuracy: 0.8251 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6014 - dense_383_accuracy: 0.9441 - loss: 69.8078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# k: 26, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 681ms/step - dense_353_accuracy: 0.6014 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.6502 - dense_361_accuracy: 0.8427 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6502 - dense_367_accuracy: 0.5943 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8076 - dense_377_accuracy: 0.8147 - dense_379_accuracy: 0.9370 - dense_381_accuracy: 0.5839 - dense_383_accuracy: 0.9441 - loss: 66.7523
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# k: 27, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 679ms/step - dense_353_accuracy: 0.5559 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.7029 - dense_361_accuracy: 0.7692 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6190 - dense_367_accuracy: 0.5735 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7763 - dense_377_accuracy: 0.7484 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.5839 - dense_383_accuracy: 0.9441 - loss: 64.2430
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 28, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 902ms/step - dense_353_accuracy: 0.5630 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.7237 - dense_361_accuracy: 0.8706 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6678 - dense_367_accuracy: 0.5839 - dense_369_accuracy: 0.8355 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.8427 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6190 - dense_383_accuracy: 0.9441 - loss: 61.5227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# k: 29, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_353_accuracy: 0.6502 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.7308 - dense_361_accuracy: 0.7971 - dense_363_accuracy: 0.8531 - dense_365_accuracy: 0.7412 - dense_367_accuracy: 0.6398 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.7971 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.6398 - dense_383_accuracy: 0.9441 - loss: 59.2949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# k: 30, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 682ms/step - dense_353_accuracy: 0.6190 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.7867 - dense_361_accuracy: 0.7412 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.7029 - dense_367_accuracy: 0.6645 - dense_369_accuracy: 0.7971 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.8147 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.7029 - dense_383_accuracy: 0.9441 - loss: 57.1659
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# k: 31, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 692ms/step - dense_353_accuracy: 0.6469 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.7412 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.6573 - dense_367_accuracy: 0.6957 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.8322 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.6190 - dense_383_accuracy: 0.9441 - loss: 54.7697
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# k: 32, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 707ms/step - dense_353_accuracy: 0.6190 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.7692 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.7308 - dense_367_accuracy: 0.6014 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.7588 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.6118 - dense_383_accuracy: 0.9545 - loss: 52.4842
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# k: 33, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 806ms/step - dense_353_accuracy: 0.6398 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.8043 - dense_361_accuracy: 0.7412 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.7516 - dense_367_accuracy: 0.6502 - dense_369_accuracy: 0.8147 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8076 - dense_377_accuracy: 0.8531 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.6014 - dense_383_accuracy: 0.9441 - loss: 50.4208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# k: 34, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_353_accuracy: 0.6469 - dense_355_accuracy: 0.7763 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.7484 - dense_361_accuracy: 0.7204 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6398 - dense_367_accuracy: 0.6294 - dense_369_accuracy: 0.8043 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7763 - dense_377_accuracy: 0.7516 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6294 - dense_383_accuracy: 0.9441 - loss: 48.8162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# k: 35, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 698ms/step - dense_353_accuracy: 0.6853 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.8427 - dense_361_accuracy: 0.8602 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6118 - dense_367_accuracy: 0.6398 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.7588 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6853 - dense_383_accuracy: 0.9545 - loss: 46.7699
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# k: 36, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 694ms/step - dense_353_accuracy: 0.6014 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.7971 - dense_361_accuracy: 0.8251 - dense_363_accuracy: 0.8531 - dense_365_accuracy: 0.8147 - dense_367_accuracy: 0.7133 - dense_369_accuracy: 0.8602 - dense_371_accuracy: 0.8531 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.8322 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6749 - dense_383_accuracy: 0.9441 - loss: 44.8742
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# k: 37, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 745ms/step - dense_353_accuracy: 0.6678 - dense_355_accuracy: 0.7971 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.8427 - dense_361_accuracy: 0.8355 - dense_363_accuracy: 0.8531 - dense_365_accuracy: 0.7621 - dense_367_accuracy: 0.7621 - dense_369_accuracy: 0.8251 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.7867 - dense_379_accuracy: 0.9370 - dense_381_accuracy: 0.6853 - dense_383_accuracy: 0.9441 - loss: 43.0372
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# k: 38, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_353_accuracy: 0.6118 - dense_355_accuracy: 0.8147 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.8706 - dense_361_accuracy: 0.7971 - dense_363_accuracy: 0.8531 - dense_365_accuracy: 0.8147 - dense_367_accuracy: 0.7763 - dense_369_accuracy: 0.8706 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7971 - dense_377_accuracy: 0.8602 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.7133 - dense_383_accuracy: 0.9545 - loss: 41.3450
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# k: 39, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 695ms/step - dense_353_accuracy: 0.6678 - dense_355_accuracy: 0.8427 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.7796 - dense_361_accuracy: 0.8706 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.7867 - dense_367_accuracy: 0.6853 - dense_369_accuracy: 0.8914 - dense_371_accuracy: 0.8531 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.8986 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.6957 - dense_383_accuracy: 0.9441 - loss: 39.8849
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# k: 40, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 715ms/step - dense_353_accuracy: 0.7692 - dense_355_accuracy: 0.8427 - dense_357_accuracy: 0.9545 - dense_359_accuracy: 0.8531 - dense_361_accuracy: 0.8427 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.6853 - dense_367_accuracy: 0.6294 - dense_369_accuracy: 0.8810 - dense_371_accuracy: 0.8531 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8043 - dense_377_accuracy: 0.8427 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.6853 - dense_383_accuracy: 0.9441 - loss: 38.2564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# k: 41, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 699ms/step - dense_353_accuracy: 0.8043 - dense_355_accuracy: 0.7763 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.8427 - dense_361_accuracy: 0.8322 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.7061 - dense_367_accuracy: 0.6957 - dense_369_accuracy: 0.8602 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.8251 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.7412 - dense_383_accuracy: 0.9441 - loss: 36.9570
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# k: 42, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 703ms/step - dense_353_accuracy: 0.7204 - dense_355_accuracy: 0.7763 - dense_357_accuracy: 0.9441 - dense_359_accuracy: 0.8251 - dense_361_accuracy: 0.8706 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.7204 - dense_367_accuracy: 0.6469 - dense_369_accuracy: 0.8602 - dense_371_accuracy: 0.8322 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.8322 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.7204 - dense_383_accuracy: 0.9545 - loss: 35.9324
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# k: 43, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_353_accuracy: 0.7204 - dense_355_accuracy: 0.7763 - dense_357_accuracy: 0.9720 - dense_359_accuracy: 0.7412 - dense_361_accuracy: 0.9090 - dense_363_accuracy: 0.8322 - dense_365_accuracy: 0.8043 - dense_367_accuracy: 0.6573 - dense_369_accuracy: 0.8706 - dense_371_accuracy: 0.8602 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.7867 - dense_377_accuracy: 0.8251 - dense_379_accuracy: 0.9161 - dense_381_accuracy: 0.7308 - dense_383_accuracy: 0.9441 - loss: 34.4407
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# k: 44, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 674ms/step - dense_353_accuracy: 0.7588 - dense_355_accuracy: 0.7867 - dense_357_accuracy: 1.0000 - dense_359_accuracy: 0.7621 - dense_361_accuracy: 0.8986 - dense_363_accuracy: 0.8427 - dense_365_accuracy: 0.7237 - dense_367_accuracy: 0.7588 - dense_369_accuracy: 0.7867 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9545 - dense_375_accuracy: 0.8531 - dense_377_accuracy: 0.8147 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.7588 - dense_383_accuracy: 0.9545 - loss: 32.7845
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# k: 45, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - dense_353_accuracy: 0.8531 - dense_355_accuracy: 0.8427 - dense_357_accuracy: 0.9720 - dense_359_accuracy: 0.7867 - dense_361_accuracy: 0.8602 - dense_363_accuracy: 0.8602 - dense_365_accuracy: 0.7796 - dense_367_accuracy: 0.7796 - dense_369_accuracy: 0.8427 - dense_371_accuracy: 0.8427 - dense_373_accuracy: 0.9441 - dense_375_accuracy: 0.8322 - dense_377_accuracy: 0.8427 - dense_379_accuracy: 0.9265 - dense_381_accuracy: 0.7412 - dense_383_accuracy: 0.9720 - loss: 31.6919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# k: 46, patience: 6
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# k: 28, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 663ms/step - dense_497_accuracy: 0.7763 - dense_499_accuracy: 0.8810 - dense_501_accuracy: 0.9265 - dense_503_accuracy: 0.8251 - dense_505_accuracy: 0.8251 - dense_507_accuracy: 0.8427 - dense_509_accuracy: 0.6957 - dense_511_accuracy: 0.7516 - dense_513_accuracy: 0.8706 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8810 - dense_521_accuracy: 0.7763 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.6853 - dense_527_accuracy: 0.9161 - loss: 60.0946
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# k: 29, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - dense_497_accuracy: 0.7867 - dense_499_accuracy: 0.8810 - dense_501_accuracy: 0.9265 - dense_503_accuracy: 0.8043 - dense_505_accuracy: 0.8355 - dense_507_accuracy: 0.8427 - dense_509_accuracy: 0.6573 - dense_511_accuracy: 0.7237 - dense_513_accuracy: 0.8810 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9825 - dense_519_accuracy: 0.7867 - dense_521_accuracy: 0.7412 - dense_523_accuracy: 0.9545 - dense_525_accuracy: 0.7133 - dense_527_accuracy: 0.9161 - loss: 57.8482
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# k: 30, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - dense_497_accuracy: 0.7867 - dense_499_accuracy: 0.8810 - dense_501_accuracy: 0.9370 - dense_503_accuracy: 0.8635 - dense_505_accuracy: 0.8043 - dense_507_accuracy: 0.8322 - dense_509_accuracy: 0.7061 - dense_511_accuracy: 0.7796 - dense_513_accuracy: 0.8882 - dense_515_accuracy: 0.8810 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.7867 - dense_521_accuracy: 0.7308 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.7133 - dense_527_accuracy: 0.9265 - loss: 55.4674
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# k: 31, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 702ms/step - dense_497_accuracy: 0.7763 - dense_499_accuracy: 0.9441 - dense_501_accuracy: 0.9441 - dense_503_accuracy: 0.7867 - dense_505_accuracy: 0.8147 - dense_507_accuracy: 0.8531 - dense_509_accuracy: 0.7308 - dense_511_accuracy: 0.8706 - dense_513_accuracy: 0.9090 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.7900 - dense_521_accuracy: 0.8986 - dense_523_accuracy: 0.9545 - dense_525_accuracy: 0.7308 - dense_527_accuracy: 0.9161 - loss: 53.5067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# k: 32, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 717ms/step - dense_497_accuracy: 0.7867 - dense_499_accuracy: 0.9441 - dense_501_accuracy: 0.9265 - dense_503_accuracy: 0.8427 - dense_505_accuracy: 0.8251 - dense_507_accuracy: 0.8602 - dense_509_accuracy: 0.7971 - dense_511_accuracy: 0.8810 - dense_513_accuracy: 0.8706 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.7971 - dense_521_accuracy: 0.9265 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.7412 - dense_527_accuracy: 0.9161 - loss: 51.1328
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# k: 33, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 720ms/step - dense_497_accuracy: 0.8427 - dense_499_accuracy: 0.8810 - dense_501_accuracy: 0.9545 - dense_503_accuracy: 0.7867 - dense_505_accuracy: 0.8043 - dense_507_accuracy: 0.8882 - dense_509_accuracy: 0.7588 - dense_511_accuracy: 0.8810 - dense_513_accuracy: 0.8602 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.7867 - dense_521_accuracy: 0.8531 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.6749 - dense_527_accuracy: 0.9161 - loss: 48.9514
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# k: 34, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - dense_497_accuracy: 0.6924 - dense_499_accuracy: 0.8706 - dense_501_accuracy: 0.9161 - dense_503_accuracy: 0.7588 - dense_505_accuracy: 0.8043 - dense_507_accuracy: 0.8602 - dense_509_accuracy: 0.6924 - dense_511_accuracy: 0.7867 - dense_513_accuracy: 0.8602 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.7484 - dense_521_accuracy: 0.8322 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.6645 - dense_527_accuracy: 0.9161 - loss: 47.4756
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# k: 35, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_497_accuracy: 0.7412 - dense_499_accuracy: 0.8602 - dense_501_accuracy: 0.9161 - dense_503_accuracy: 0.8986 - dense_505_accuracy: 0.8147 - dense_507_accuracy: 0.8322 - dense_509_accuracy: 0.7029 - dense_511_accuracy: 0.7484 - dense_513_accuracy: 0.8706 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8531 - dense_521_accuracy: 0.7971 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.7484 - dense_527_accuracy: 0.9161 - loss: 45.3866
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# k: 36, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 721ms/step - dense_497_accuracy: 0.9265 - dense_499_accuracy: 0.9265 - dense_501_accuracy: 0.9441 - dense_503_accuracy: 0.7516 - dense_505_accuracy: 0.8147 - dense_507_accuracy: 0.8427 - dense_509_accuracy: 0.7029 - dense_511_accuracy: 0.7796 - dense_513_accuracy: 0.8602 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8810 - dense_521_accuracy: 0.7763 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.7308 - dense_527_accuracy: 0.9161 - loss: 43.6975
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# k: 37, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 760ms/step - dense_497_accuracy: 0.8706 - dense_499_accuracy: 0.9161 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.7867 - dense_505_accuracy: 0.8427 - dense_507_accuracy: 0.8706 - dense_509_accuracy: 0.7308 - dense_511_accuracy: 0.8043 - dense_513_accuracy: 0.8810 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.9265 - dense_521_accuracy: 0.8882 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.7588 - dense_527_accuracy: 0.9161 - loss: 41.5957
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# k: 38, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - dense_497_accuracy: 0.8706 - dense_499_accuracy: 0.9441 - dense_501_accuracy: 0.9825 - dense_503_accuracy: 0.6645 - dense_505_accuracy: 0.8043 - dense_507_accuracy: 0.9265 - dense_509_accuracy: 0.7692 - dense_511_accuracy: 0.8531 - dense_513_accuracy: 0.8882 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8882 - dense_521_accuracy: 0.8602 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.7692 - dense_527_accuracy: 0.9265 - loss: 40.2778
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# k: 39, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_497_accuracy: 0.8322 - dense_499_accuracy: 0.9161 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.8706 - dense_505_accuracy: 0.8602 - dense_507_accuracy: 0.8602 - dense_509_accuracy: 0.7029 - dense_511_accuracy: 0.8706 - dense_513_accuracy: 0.9441 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8043 - dense_521_accuracy: 0.8427 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.6957 - dense_527_accuracy: 0.9265 - loss: 38.8378
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# k: 40, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 715ms/step - dense_497_accuracy: 0.9265 - dense_499_accuracy: 0.9265 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.8043 - dense_505_accuracy: 0.8251 - dense_507_accuracy: 0.8882 - dense_509_accuracy: 0.7204 - dense_511_accuracy: 0.8322 - dense_513_accuracy: 0.8986 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.7763 - dense_521_accuracy: 0.8602 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.8322 - dense_527_accuracy: 0.9161 - loss: 37.0359
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# k: 41, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 649ms/step - dense_497_accuracy: 0.8147 - dense_499_accuracy: 0.9161 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.7971 - dense_505_accuracy: 0.8251 - dense_507_accuracy: 0.8706 - dense_509_accuracy: 0.7308 - dense_511_accuracy: 0.8355 - dense_513_accuracy: 0.8602 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8531 - dense_521_accuracy: 0.9265 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.6749 - dense_527_accuracy: 0.9161 - loss: 35.6638
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# k: 42, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 694ms/step - dense_497_accuracy: 0.8986 - dense_499_accuracy: 0.9545 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.8986 - dense_505_accuracy: 0.8810 - dense_507_accuracy: 0.8810 - dense_509_accuracy: 0.7692 - dense_511_accuracy: 0.8147 - dense_513_accuracy: 0.8810 - dense_515_accuracy: 0.8810 - dense_517_accuracy: 0.9825 - dense_519_accuracy: 0.8322 - dense_521_accuracy: 0.8914 - dense_523_accuracy: 0.9545 - dense_525_accuracy: 0.7133 - dense_527_accuracy: 0.9161 - loss: 34.0173
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# k: 43, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 920ms/step - dense_497_accuracy: 0.8882 - dense_499_accuracy: 0.9545 - dense_501_accuracy: 0.9441 - dense_503_accuracy: 0.8531 - dense_505_accuracy: 0.8531 - dense_507_accuracy: 0.8882 - dense_509_accuracy: 0.7692 - dense_511_accuracy: 0.8322 - dense_513_accuracy: 0.8882 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8706 - dense_521_accuracy: 0.8706 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.8043 - dense_527_accuracy: 0.9370 - loss: 32.8624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# k: 44, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_497_accuracy: 0.9161 - dense_499_accuracy: 0.9545 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.8706 - dense_505_accuracy: 0.8427 - dense_507_accuracy: 0.8147 - dense_509_accuracy: 0.7763 - dense_511_accuracy: 0.8602 - dense_513_accuracy: 0.9441 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8706 - dense_521_accuracy: 0.5455 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.7692 - dense_527_accuracy: 0.9161 - loss: 32.0885
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# k: 45, patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 681ms/step - dense_497_accuracy: 0.9265 - dense_499_accuracy: 0.9161 - dense_501_accuracy: 0.9825 - dense_503_accuracy: 0.8706 - dense_505_accuracy: 0.8147 - dense_507_accuracy: 0.8427 - dense_509_accuracy: 0.7796 - dense_511_accuracy: 0.8531 - dense_513_accuracy: 0.9161 - dense_515_accuracy: 0.8810 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8706 - dense_521_accuracy: 0.8986 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.8355 - dense_527_accuracy: 0.9545 - loss: 30.5879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# k: 46, patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 658ms/step - dense_497_accuracy: 0.9441 - dense_499_accuracy: 0.8706 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.8882 - dense_505_accuracy: 0.8147 - dense_507_accuracy: 0.8986 - dense_509_accuracy: 0.7588 - dense_511_accuracy: 0.8810 - dense_513_accuracy: 0.9090 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9825 - dense_519_accuracy: 0.8355 - dense_521_accuracy: 0.7516 - dense_523_accuracy: 0.9649 - dense_525_accuracy: 0.8147 - dense_527_accuracy: 0.9441 - loss: 29.5449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# k: 47, patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 747ms/step - dense_497_accuracy: 0.8882 - dense_499_accuracy: 0.9441 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.8706 - dense_505_accuracy: 0.8602 - dense_507_accuracy: 0.8810 - dense_509_accuracy: 0.7588 - dense_511_accuracy: 0.8602 - dense_513_accuracy: 0.8602 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8810 - dense_521_accuracy: 0.8043 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.8635 - dense_527_accuracy: 0.9441 - loss: 28.3919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# k: 48, patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 740ms/step - dense_497_accuracy: 0.8882 - dense_499_accuracy: 0.8986 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.8602 - dense_505_accuracy: 0.8531 - dense_507_accuracy: 0.8706 - dense_509_accuracy: 0.7692 - dense_511_accuracy: 0.8810 - dense_513_accuracy: 0.9441 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9825 - dense_519_accuracy: 0.6086 - dense_521_accuracy: 0.9161 - dense_523_accuracy: 0.9545 - dense_525_accuracy: 0.7971 - dense_527_accuracy: 0.9545 - loss: 27.5685
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# k: 49, patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_497_accuracy: 0.9545 - dense_499_accuracy: 0.9441 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.9265 - dense_505_accuracy: 0.8810 - dense_507_accuracy: 0.8882 - dense_509_accuracy: 0.7867 - dense_511_accuracy: 0.8427 - dense_513_accuracy: 0.9441 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.7763 - dense_521_accuracy: 0.8322 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.7867 - dense_527_accuracy: 0.9265 - loss: 26.3471
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# k: 50, patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - dense_497_accuracy: 0.9545 - dense_499_accuracy: 0.9161 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.8602 - dense_505_accuracy: 0.9161 - dense_507_accuracy: 0.8986 - dense_509_accuracy: 0.7588 - dense_511_accuracy: 0.8602 - dense_513_accuracy: 0.9161 - dense_515_accuracy: 0.8602 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8531 - dense_521_accuracy: 0.8322 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.8147 - dense_527_accuracy: 0.9441 - loss: 25.1911
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# k: 51, patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 694ms/step - dense_497_accuracy: 0.8986 - dense_499_accuracy: 0.8986 - dense_501_accuracy: 0.9720 - dense_503_accuracy: 0.9441 - dense_505_accuracy: 0.8147 - dense_507_accuracy: 0.8882 - dense_509_accuracy: 0.7308 - dense_511_accuracy: 0.8427 - dense_513_accuracy: 0.8706 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8251 - dense_521_accuracy: 0.9265 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.8322 - dense_527_accuracy: 0.9441 - loss: 24.2867
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# k: 52, patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 703ms/step - dense_497_accuracy: 0.9265 - dense_499_accuracy: 0.8986 - dense_501_accuracy: 0.9825 - dense_503_accuracy: 0.9545 - dense_505_accuracy: 0.8251 - dense_507_accuracy: 0.8882 - dense_509_accuracy: 0.7867 - dense_511_accuracy: 0.7588 - dense_513_accuracy: 0.8882 - dense_515_accuracy: 0.8706 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.9441 - dense_521_accuracy: 0.7867 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.8602 - dense_527_accuracy: 0.9441 - loss: 23.5474
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# k: 53, patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - dense_497_accuracy: 0.9545 - dense_499_accuracy: 0.9545 - dense_501_accuracy: 0.9545 - dense_503_accuracy: 0.9441 - dense_505_accuracy: 0.9161 - dense_507_accuracy: 0.8602 - dense_509_accuracy: 0.7484 - dense_511_accuracy: 0.8322 - dense_513_accuracy: 0.9825 - dense_515_accuracy: 0.9265 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.8810 - dense_521_accuracy: 0.7412 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.8882 - dense_527_accuracy: 0.9441 - loss: 22.8483
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# k: 54, patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 687ms/step - dense_497_accuracy: 0.8986 - dense_499_accuracy: 0.9441 - dense_501_accuracy: 1.0000 - dense_503_accuracy: 0.9161 - dense_505_accuracy: 0.7692 - dense_507_accuracy: 0.8706 - dense_509_accuracy: 0.7588 - dense_511_accuracy: 0.8882 - dense_513_accuracy: 0.8882 - dense_515_accuracy: 0.9545 - dense_517_accuracy: 0.9720 - dense_519_accuracy: 0.9161 - dense_521_accuracy: 0.7588 - dense_523_accuracy: 0.9441 - dense_525_accuracy: 0.8882 - dense_527_accuracy: 0.9441 - loss: 22.2014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# k: 55, patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Test Loss iteration 4: 49.86277068114045
# average_loss: 38.52462970161726
