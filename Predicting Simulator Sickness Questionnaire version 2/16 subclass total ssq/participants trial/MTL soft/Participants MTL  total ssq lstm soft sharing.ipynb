# %%
from google.colab import drive
import pandas as pd
from sklearn.preprocessing import StandardScaler
from scipy import stats
import numpy as np
import logging
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from datetime import datetime
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime
import matplotlib.dates as mdates
import os

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Set the base path to the desired directory on Google Drive
base_path = '/content/drive/MyDrive/Study_1_Data/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read_csv(file_path):
    data = pd.read_csv(file_path)
    return data

# %%
def process_data(data, columns_to_remove):
    processed_data = data.drop(columns=columns_to_remove).values
    return processed_data

# %%
def construct_3d_array(base_dir, participants, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye):
    """
    Construct 3D array from CSV files.
    """
    num_rows = 180  # Define number of rows to keep (last 180 rows)
    arrays_3d = []

    for participant in participants:
        participant_id = f"{int(participant):02d}"  # Format participant number to two digits

        valid_simulations = []

        for simulation in simulations:
            hr_file_path = os.path.join(base_dir, participant_id, simulation, f'HR{simulation.capitalize()}.csv')
            gsr_file_path = os.path.join(base_dir, participant_id, simulation, f'EDA{simulation.capitalize()}_downsampled.csv')
            head_file_path = os.path.join(base_dir, participant_id, simulation, 'head_tracking_downsampled.csv')
            eye_file_path = os.path.join(base_dir, participant_id, simulation, 'eye_tracking_downsampled.csv')

            # Check if all files exist
            if all(os.path.exists(file) for file in [hr_file_path, gsr_file_path, head_file_path, eye_file_path]):
                valid_simulations.append(simulation)

        num_valid_simulations = len(valid_simulations)
        if num_valid_simulations == 0:
            continue  # Skip this participant if no valid simulations are found

        array_3d = np.zeros((num_valid_simulations, num_rows, 47)) # hr=1, gsr=1, head=15-3, eye=41-8 total columns after removing columns= 48

        for s_idx, simulation in enumerate(valid_simulations):
            # Process hr data
            hr_file_path = os.path.join(base_dir, participant_id, simulation, f'HR{simulation.capitalize()}.csv')
            hr_data = read_csv(hr_file_path)
            processed_hr_data = process_data(hr_data, columns_to_remove_hr)
            processed_hr_data = processed_hr_data[-num_rows:]  # Keep only the last 180 rows

            # Process gsr data
            gsr_file_path = os.path.join(base_dir, participant_id, simulation, f'EDA{simulation.capitalize()}_downsampled.csv')
            gsr_data = read_csv(gsr_file_path)
            processed_gsr_data = process_data(gsr_data, columns_to_remove_gsr)
            processed_gsr_data = processed_gsr_data[-num_rows:]  # Keep only the last 180 rows

            # Process head data
            head_file_path = os.path.join(base_dir, participant_id, simulation, 'head_tracking_downsampled.csv')
            head_data = read_csv(head_file_path)
            processed_head_data = process_data(head_data, columns_to_remove_head)
            processed_head_data = processed_head_data[-num_rows:]  # Keep only the last 180 rows

            # Process eye data
            eye_file_path = os.path.join(base_dir, participant_id, simulation, 'eye_tracking_downsampled.csv')
            eye_data = read_csv(eye_file_path)
            processed_eye_data = process_data(eye_data, columns_to_remove_eye)
            processed_eye_data = processed_eye_data[-num_rows:]  # Keep only the last 180 rows

            # Combine processed data
            combined_data = np.concatenate((processed_hr_data, processed_gsr_data, processed_head_data, processed_eye_data), axis=1)

            array_3d[s_idx, :, :] = combined_data

        arrays_3d.append(array_3d)

    return arrays_3d

# %%
sample_size=60
simulations = ['flat','noise','bumps']
participants = [str(i) for i in range(1, 27)]  # Participants 101 to 127
columns_to_remove_hr = []
columns_to_remove_gsr = []
columns_to_remove_eye = ['#Frame','Time', 'Unnamed: 40','ConvergenceValid','Left_Eye_Closed','Right_Eye_Closed','LocalGazeValid','WorldGazeValid']
columns_to_remove_head = ['#Frame','Time', 'Unnamed: 14']

# %%
def calculate_total_ssq(csv_file):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    n_columns = [0, 5, 6, 7, 8, 14, 15]
    o_columns = [0, 1, 2, 3, 4, 8, 10]
    d_columns = [4, 7, 9, 10, 11, 12, 13]

    # Calculate sum for each specified set of columns
    n_val = df.iloc[0, n_columns].sum()
    o_val = df.iloc[0, o_columns].sum()
    d_val = df.iloc[0, d_columns].sum()

    return n_val, o_val, d_val

# %%
def merge_ssq_column(conditions,participants):
  directories = []
  total_ssq_values = []
  for participant in participants:
      participant = f"{int(participant):02d}"
      for condition in conditions:
          directory = os.path.join(base_path, participant, condition)
          directories.append(directory)

  # Loop through each directory
  for directory in directories:
      # Check if the directory exists
      if not os.path.exists(directory):
          continue

      # Get all CSV files in the directory that are named 'ssq.csv'
      csv_files = [file for file in os.listdir(directory) if file == 'ssq.csv']

      # Loop through each CSV file
      for csv_file in csv_files:
          csv_path = os.path.join(directory, csv_file)
          df = pd.read_csv(csv_path)
          # n_val,o_val,d_val = calculate_total_ssq(csv_path)
          # total_ssq_values.append([n_val, o_val, d_val])
          ssq_values_participant = df.iloc[:, 0:17].values.flatten()   # Assuming SSQ values are in columns 1 to 16
          total_ssq_values.append(ssq_values_participant)
  ssq_array = np.array(total_ssq_values)
  return ssq_array

def merge_total_ssq(conditions,participants):
  directories = []
  total_ssq_values = []
  for participant in participants:
      participant = f"{int(participant):02d}"
      for condition in conditions:
          directory = os.path.join(base_path, participant, condition)
          directories.append(directory)

  # Loop through each directory
  for directory in directories:
      # Check if the directory exists
      if not os.path.exists(directory):
          continue

      # Get all CSV files in the directory that are named 'ssq.csv'
      csv_files = [file for file in os.listdir(directory) if file == 'ssq.csv']

      # Loop through each CSV file
      for csv_file in csv_files:
          csv_path = os.path.join(directory, csv_file)
          n_val,o_val,d_val = calculate_total_ssq(csv_path)
          total_ssq = (n_val+o_val+d_val) * 3.74
          df = pd.read_csv(csv_path)
          df["total-ssq"] = total_ssq
          #print("csv_path: ",csv_path,"   ",total_ssq)
          total_ssq_values.append(total_ssq)
  # Create a DataFrame from the list of total SSQ values
  df_total_ssq = pd.DataFrame(total_ssq_values, columns=["total-ssq"])
  # Convert the list of total SSQ values to a NumPy array
  total_ssq_array = np.array(total_ssq_values)
  return total_ssq_array

# %%
participants_group_1 = [1,3,4,11,25]
participants_group_2 = [2,7,8,9,17]
participants_group_3 = [10,12,13,22,23]
participants_group_4 = [5,14,18,20,21]
participants_group_5 = [6,15,16,19,24,26]

arrays_group_1 = construct_3d_array(base_path, participants_group_1, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_2 = construct_3d_array(base_path, participants_group_2, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_3 = construct_3d_array(base_path, participants_group_3, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_4 = construct_3d_array(base_path, participants_group_4, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)
arrays_group_5 = construct_3d_array(base_path, participants_group_5, simulations, columns_to_remove_hr, columns_to_remove_gsr, columns_to_remove_head, columns_to_remove_eye)

# %%
# Concatenate arrays along the first axis
input_group_1 = np.concatenate(arrays_group_1, axis=0)
input_group_2 = np.concatenate(arrays_group_2, axis=0)
input_group_3 = np.concatenate(arrays_group_3, axis=0)
input_group_4 = np.concatenate(arrays_group_4, axis=0)
input_group_5 = np.concatenate(arrays_group_5, axis=0)

# %%
output_group_1=merge_ssq_column(simulations,participants_group_1)
output_group_2=merge_ssq_column(simulations,participants_group_2)
output_group_3=merge_ssq_column(simulations,participants_group_3)
output_group_4=merge_ssq_column(simulations,participants_group_4)
output_group_5=merge_ssq_column(simulations,participants_group_5)

output_group_1 = np.squeeze(output_group_1)
output_group_2 = np.squeeze(output_group_2)
output_group_3 = np.squeeze(output_group_3)
output_group_4 = np.squeeze(output_group_4)
output_group_5 = np.squeeze(output_group_5)


output_total_ssq_group_1=merge_total_ssq(simulations,participants_group_1)
output_total_ssq_group_2=merge_total_ssq(simulations,participants_group_2)
output_total_ssq_group_3=merge_total_ssq(simulations,participants_group_3)
output_total_ssq_group_4=merge_total_ssq(simulations,participants_group_4)
output_total_ssq_group_5=merge_total_ssq(simulations,participants_group_5)

output_total_ssq_group_1=output_total_ssq_group_1.reshape(-1, 1)
output_total_ssq_group_2=output_total_ssq_group_2.reshape(-1, 1)
output_total_ssq_group_3=output_total_ssq_group_3.reshape(-1, 1)
output_total_ssq_group_4=output_total_ssq_group_4.reshape(-1, 1)
output_total_ssq_group_5=output_total_ssq_group_5.reshape(-1, 1)

# %%
def scale_input_data(input_train, input_test):
    # Get the shape of the input data
    num_samples_train, time_steps_train, num_features = input_train.shape
    num_samples_test, time_steps_test, _ = input_test.shape

    # Reshape the input data into 2D arrays
    flattened_train_data = input_train.reshape(-1, num_features)
    flattened_test_data = input_test.reshape(-1, num_features)

    # Initialize a MinMaxScaler object
    scaler = MinMaxScaler()

    # Fit the scaler on the training data and transform both train and test data
    scaled_train_data = scaler.fit_transform(flattened_train_data)
    scaled_test_data = scaler.transform(flattened_test_data)

    # Reshape the scaled data back to its original shape
    scaled_train_data = scaled_train_data.reshape(num_samples_train, time_steps_train, num_features)
    scaled_test_data = scaled_test_data.reshape(num_samples_test, time_steps_test, num_features)

    return scaled_train_data, scaled_test_data

def scale_target_var(target_data):
    min_val, max_val = np.min(target_data, axis=0), np.max(target_data, axis=0)
    target_data = (target_data-min_val)/(max_val-min_val)

    return target_data, min_val, max_val

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, LSTM, Dense, Dropout
from keras.models import Model
import numpy as np
import sklearn

def soft_parameter_sharing_regularizer(model, alpha=0.01):
    lstm_layers = [layer for layer in model.layers if isinstance(layer, LSTM)]
    if not lstm_layers:
        return 0.0

    weights = [tf.convert_to_tensor(layer.weights[0]) for layer in lstm_layers]

    shared_weights = tf.reduce_mean(tf.stack(weights), axis=0)
    return alpha * tf.reduce_sum([tf.reduce_sum(tf.square(w - shared_weights)) for w in weights])

def get_individual_lstm(input_shape1, input_shape2):
    input_layer = Input(shape=(input_shape1, input_shape2))

    lstm_layers = []
    for _ in range(output_train.shape[1]):
        x = LSTM(64, return_sequences=False)(input_layer)
        x = Dense(256, activation='relu')(x)
        x = Dropout(0.2)(x)
        lstm_layers.append(x)

    return lstm_layers, input_layer

def get_output_model(lstm_outputs, output_shape):
    output_models = []
    for i in range(output_shape[1]):
        output_model = Sequential()
        output_model.add(Dense(256, activation='relu'))
        output_model.add(Dropout(0.2))
        output_model.add(Dense(1))
        output_model_output = output_model(lstm_outputs[i])
        output_models.append(output_model_output)
    return output_models

total_losses = []
for iteration in range(5):


  # Assuming input_groups and output_groups are lists of arrays for the 5 groups
    input_groups = [input_group_1, input_group_2, input_group_3, input_group_4, input_group_5]
    output_groups = [output_group_1, output_group_2, output_group_3, output_group_4, output_group_5]
    ssq_groups = [output_total_ssq_group_1, output_total_ssq_group_2, output_total_ssq_group_3, output_total_ssq_group_4, output_total_ssq_group_5]

    # Initialize lists for storing training, validation, and test sets
    X_train, X_val, X_test = [], [], []
    y_train, y_val, y_test = [], [], []
    ssq_train, ssq_val, ssq_test = [], [], []

    # Loop over each group
    for input_group, output_group, ssq_group in zip(input_groups, output_groups, ssq_groups):
        # Step 1: Split the group into a training/validation set (80%) and a test set (20%)
        X_temp, X_test_temp, y_temp, y_test_temp, ssq_temp, ssq_test_temp = train_test_split(
            input_group, output_group, ssq_group, test_size=0.2)

        # Step 2: Split the training/validation set into a training set (60%) and a validation set (20%)
        X_train_temp, X_val_temp, y_train_temp, y_val_temp, ssq_train_temp, ssq_val_temp = train_test_split(
            X_temp, y_temp, ssq_temp, test_size=0.25)  # 0.25 * 0.8 = 0.2

        # Step 3: Append the results to the corresponding lists
        X_train.append(X_train_temp)
        X_val.append(X_val_temp)
        X_test.append(X_test_temp)

        y_train.append(y_train_temp)
        y_val.append(y_val_temp)
        y_test.append(y_test_temp)

        ssq_train.append(ssq_train_temp)
        ssq_val.append(ssq_val_temp)
        ssq_test.append(ssq_test_temp)

    # After the loop, concatenate the data for all groups if needed
    input_train = np.concatenate(X_train, axis=0)
    input_val = np.concatenate(X_val, axis=0)
    input_test = np.concatenate(X_test, axis=0)

    output_train = np.concatenate(y_train, axis=0)
    output_val = np.concatenate(y_val, axis=0)
    output_test = np.concatenate(y_test, axis=0)

    output_test_total_ssq = np.concatenate(ssq_test, axis=0)
    # input_train, input_test= scale_input_data(input_train[:, (60-sample_size):(180-sample_size), :], input_test[:, (60-sample_size):(180-sample_size), :])
    # output_train, min_val, max_val = scale_target_var(output_train)


    #  this section for scaling both train and validation set simultaniously
      # Step 1: Combine the training and validation sets
    combined_input = np.concatenate([input_train, input_val], axis=0)
    combined_output = np.concatenate([output_train, output_val], axis=0)

    # Step 2: Scale the combined input data
    # Assuming scale_input_data scales the data based on the combined dataset
    combined_input, input_test = scale_input_data(
        combined_input[:, (60-sample_size):(180-sample_size), :],
        input_test[:, (60-sample_size):(180-sample_size), :]
    )

    # Step 3: Scale the combined output data
    # Assuming scale_target_var scales the data and returns min_val, max_val
    combined_output, min_val, max_val = scale_target_var(combined_output)

    # Step 4: Split the combined data back into training and validation sets
    # Use the original shapes of input_train and input_val to slice the combined arrays
    input_train = combined_input[:input_train.shape[0], :, :]
    input_val = combined_input[input_train.shape[0]:, :, :]

    output_train = combined_output[:output_train.shape[0], :]
    output_val = combined_output[output_train.shape[0]:, :]



    print("input_train :", input_train.shape)
    print("output_train :", output_train.shape)
    print("input_val :", input_val.shape)
    print("output_val :", output_val.shape)
    print("input_test :", input_test.shape)
    print("output_test :", output_test.shape)

    # Reshape inputs
    train_input_reshaped = input_train.reshape((input_train.shape[0], input_train.shape[1], input_train.shape[2]))
    test_input_reshaped = input_test.reshape((input_test.shape[0], input_test.shape[1], input_test.shape[2]))
    val_input_reshaped = input_val.reshape((input_val.shape[0], input_val.shape[1], input_val.shape[2]))

    # Get individual LSTM outputs
    lstm_outputs, input_layer = get_individual_lstm(input_train.shape[1], input_train.shape[2])

    # Create separate output models for each column
    output_models = get_output_model(lstm_outputs, output_train.shape)

    # Create combined model
    model = Model(inputs=input_layer, outputs=output_models)

    # Custom loss function
    def custom_loss(y_true, y_pred):
        mse = tf.keras.losses.mse(y_true, y_pred)
        reg_loss = soft_parameter_sharing_regularizer(model)
        return mse + reg_loss

    # Compile and train the model
    model.compile(loss=custom_loss, optimizer='adam', metrics=[['mse'] for _ in range(output_train.shape[1])])

    best_val = 1000000
    patience = 0
    best_model = None

    for k in range(200):
      model.fit(train_input_reshaped, [output_train[:, i] for i in range(output_train.shape[1])], epochs=1, batch_size=32)
      pred_val = np.array(model.predict(val_input_reshaped))
      pred_val = np.transpose(pred_val.squeeze(), (1, 0))
      print("k:", k, "patience:", patience)

      losses = []
      for i in range(pred_val.shape[0]):
        total_ssq=0
        for j in [0,5,6,7,8,14,15]:
          total_ssq=np.sum(pred_val[i,j]*(max_val[j]-min_val[j]) + min_val[j])+total_ssq

        for j in [0,1,2,3,4,8,10]:
          total_ssq=np.sum(pred_val[i,j]*(max_val[j]-min_val[j]) + min_val[j])+total_ssq

        for j in [4,7,9,10,11,12,13]:
          total_ssq=np.sum(pred_val[i,j]*(max_val[j]-min_val[j]) + min_val[j])+total_ssq
        total_ssq=total_ssq*3.74
        output_val_ssq= output_val[i,0]
        #print("total_ssq",total_ssq)
        #print("output_val_ssq",output_val_ssq)
        loss = sklearn.metrics.mean_squared_error([total_ssq], [output_val_ssq], squared=False)
        losses.append(loss)
      tmp_val_loss = np.mean(losses)
      if tmp_val_loss <= best_val:
          best_val = tmp_val_loss
          patience = 0
          best_model = model
      else:
          patience +=1
          if patience > 10:
            break

    # Predict test data
    pred_test = np.array(best_model.predict(test_input_reshaped))
    pred_test = np.transpose(pred_test.squeeze(), (1, 0))
    # Evaluate the model
    pred_total_ssq = []
    #losses=[]
    for i in range(pred_test.shape[0]):
        total_ssq=0
        for j in [0,5,6,7,8,14,15]:
          total_ssq=np.sum(pred_test[i,j]*(max_val[j]-min_val[j]) + min_val[j])+total_ssq

        for j in [0,1,2,3,4,8,10]:
          total_ssq=np.sum(pred_test[i,j]*(max_val[j]-min_val[j]) + min_val[j])+total_ssq

        for j in [4,7,9,10,11,12,13]:
          total_ssq=np.sum(pred_test[i,j]*(max_val[j]-min_val[j]) + min_val[j])+total_ssq
        total_ssq=total_ssq*3.74

        pred_total_ssq.append(total_ssq)


    # Overall Test Loss
    loss = sklearn.metrics.mean_squared_error(pred_total_ssq, output_test_total_ssq, squared = False)
    print("Test Loss no ",iteration,":" ,loss)
    total_losses.append(loss)

average_loss = sum(total_losses) / len(total_losses)
total_losses.append(average_loss)
print("average_loss:", average_loss)
# Out:
# input_train : (38, 120, 47)
# output_train : (38, 16)
# input_val : (14, 120, 47)
# output_val : (14, 16)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 56s 531ms/step - loss: 191.7581 - sequential_80_mse: 0.2126 - sequential_81_mse: 0.1578 - sequential_82_mse: 0.0934 - sequential_83_mse: 0.1621 - sequential_84_mse: 0.0486 - sequential_85_mse: 0.0736 - sequential_86_mse: 0.1696 - sequential_87_mse: 0.0980 - sequential_88_mse: 0.0419 - sequential_89_mse: 0.1217 - sequential_90_mse: 0.0541 - sequential_91_mse: 0.0799 - sequential_92_mse: 0.0586 - sequential_93_mse: 0.0607 - sequential_94_mse: 0.0763 - sequential_95_mse: 0.0623
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# k: 0 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - loss: 183.5800 - sequential_80_mse: 0.1117 - sequential_81_mse: 0.0927 - sequential_82_mse: 0.0983 - sequential_83_mse: 0.0820 - sequential_84_mse: 0.0407 - sequential_85_mse: 0.0731 - sequential_86_mse: 0.1753 - sequential_87_mse: 0.1983 - sequential_88_mse: 0.0394 - sequential_89_mse: 0.0678 - sequential_90_mse: 0.0534 - sequential_91_mse: 0.0977 - sequential_92_mse: 0.0780 - sequential_93_mse: 0.0456 - sequential_94_mse: 0.1262 - sequential_95_mse: 0.1089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 1 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - loss: 175.3856 - sequential_80_mse: 0.1279 - sequential_81_mse: 0.1045 - sequential_82_mse: 0.0688 - sequential_83_mse: 0.0732 - sequential_84_mse: 0.0383 - sequential_85_mse: 0.0572 - sequential_86_mse: 0.1170 - sequential_87_mse: 0.1090 - sequential_88_mse: 0.0447 - sequential_89_mse: 0.0578 - sequential_90_mse: 0.0380 - sequential_91_mse: 0.0589 - sequential_92_mse: 0.0365 - sequential_93_mse: 0.0444 - sequential_94_mse: 0.0929 - sequential_95_mse: 0.0607
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# k: 2 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - loss: 167.7199 - sequential_80_mse: 0.0717 - sequential_81_mse: 0.0821 - sequential_82_mse: 0.0755 - sequential_83_mse: 0.0670 - sequential_84_mse: 0.0310 - sequential_85_mse: 0.0517 - sequential_86_mse: 0.1003 - sequential_87_mse: 0.1371 - sequential_88_mse: 0.0365 - sequential_89_mse: 0.0559 - sequential_90_mse: 0.0368 - sequential_91_mse: 0.0562 - sequential_92_mse: 0.0454 - sequential_93_mse: 0.0520 - sequential_94_mse: 0.0798 - sequential_95_mse: 0.0843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# k: 3 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - loss: 160.2971 - sequential_80_mse: 0.0768 - sequential_81_mse: 0.0728 - sequential_82_mse: 0.0565 - sequential_83_mse: 0.0735 - sequential_84_mse: 0.0308 - sequential_85_mse: 0.0411 - sequential_86_mse: 0.1119 - sequential_87_mse: 0.1060 - sequential_88_mse: 0.0390 - sequential_89_mse: 0.0508 - sequential_90_mse: 0.0365 - sequential_91_mse: 0.0522 - sequential_92_mse: 0.0336 - sequential_93_mse: 0.0589 - sequential_94_mse: 0.0755 - sequential_95_mse: 0.0827
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# k: 4 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step - loss: 153.1365 - sequential_80_mse: 0.0930 - sequential_81_mse: 0.0784 - sequential_82_mse: 0.0480 - sequential_83_mse: 0.0748 - sequential_84_mse: 0.0349 - sequential_85_mse: 0.0460 - sequential_86_mse: 0.1128 - sequential_87_mse: 0.0749 - sequential_88_mse: 0.0374 - sequential_89_mse: 0.0565 - sequential_90_mse: 0.0304 - sequential_91_mse: 0.0631 - sequential_92_mse: 0.0384 - sequential_93_mse: 0.0396 - sequential_94_mse: 0.0568 - sequential_95_mse: 0.0658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# k: 5 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 872ms/step - loss: 146.3085 - sequential_80_mse: 0.0857 - sequential_81_mse: 0.0761 - sequential_82_mse: 0.0630 - sequential_83_mse: 0.0654 - sequential_84_mse: 0.0241 - sequential_85_mse: 0.0490 - sequential_86_mse: 0.1154 - sequential_87_mse: 0.1106 - sequential_88_mse: 0.0342 - sequential_89_mse: 0.0592 - sequential_90_mse: 0.0340 - sequential_91_mse: 0.0469 - sequential_92_mse: 0.0458 - sequential_93_mse: 0.0358 - sequential_94_mse: 0.0780 - sequential_95_mse: 0.0666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# k: 6 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 986ms/step - loss: 139.6111 - sequential_80_mse: 0.0768 - sequential_81_mse: 0.0699 - sequential_82_mse: 0.0622 - sequential_83_mse: 0.0645 - sequential_84_mse: 0.0344 - sequential_85_mse: 0.0507 - sequential_86_mse: 0.0841 - sequential_87_mse: 0.1073 - sequential_88_mse: 0.0276 - sequential_89_mse: 0.0598 - sequential_90_mse: 0.0311 - sequential_91_mse: 0.0475 - sequential_92_mse: 0.0355 - sequential_93_mse: 0.0356 - sequential_94_mse: 0.0613 - sequential_95_mse: 0.0654
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# k: 7 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - loss: 133.2227 - sequential_80_mse: 0.0799 - sequential_81_mse: 0.0726 - sequential_82_mse: 0.0526 - sequential_83_mse: 0.0607 - sequential_84_mse: 0.0307 - sequential_85_mse: 0.0501 - sequential_86_mse: 0.0937 - sequential_87_mse: 0.0815 - sequential_88_mse: 0.0293 - sequential_89_mse: 0.0484 - sequential_90_mse: 0.0385 - sequential_91_mse: 0.0474 - sequential_92_mse: 0.0418 - sequential_93_mse: 0.0415 - sequential_94_mse: 0.0776 - sequential_95_mse: 0.0579
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 8 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step - loss: 127.0793 - sequential_80_mse: 0.0706 - sequential_81_mse: 0.0625 - sequential_82_mse: 0.0566 - sequential_83_mse: 0.0643 - sequential_84_mse: 0.0346 - sequential_85_mse: 0.0606 - sequential_86_mse: 0.1036 - sequential_87_mse: 0.0840 - sequential_88_mse: 0.0304 - sequential_89_mse: 0.0502 - sequential_90_mse: 0.0369 - sequential_91_mse: 0.0384 - sequential_92_mse: 0.0301 - sequential_93_mse: 0.0376 - sequential_94_mse: 0.0822 - sequential_95_mse: 0.0589
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 9 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - loss: 121.1021 - sequential_80_mse: 0.0763 - sequential_81_mse: 0.0619 - sequential_82_mse: 0.0471 - sequential_83_mse: 0.0575 - sequential_84_mse: 0.0303 - sequential_85_mse: 0.0421 - sequential_86_mse: 0.0925 - sequential_87_mse: 0.0867 - sequential_88_mse: 0.0302 - sequential_89_mse: 0.0495 - sequential_90_mse: 0.0264 - sequential_91_mse: 0.0429 - sequential_92_mse: 0.0320 - sequential_93_mse: 0.0348 - sequential_94_mse: 0.0600 - sequential_95_mse: 0.0601
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# k: 10 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step - loss: 115.4375 - sequential_80_mse: 0.0783 - sequential_81_mse: 0.0726 - sequential_82_mse: 0.0470 - sequential_83_mse: 0.0548 - sequential_84_mse: 0.0216 - sequential_85_mse: 0.0489 - sequential_86_mse: 0.0977 - sequential_87_mse: 0.0954 - sequential_88_mse: 0.0324 - sequential_89_mse: 0.0468 - sequential_90_mse: 0.0288 - sequential_91_mse: 0.0416 - sequential_92_mse: 0.0246 - sequential_93_mse: 0.0351 - sequential_94_mse: 0.0621 - sequential_95_mse: 0.0524
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 11 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - loss: 109.9412 - sequential_80_mse: 0.0578 - sequential_81_mse: 0.0606 - sequential_82_mse: 0.0436 - sequential_83_mse: 0.0621 - sequential_84_mse: 0.0256 - sequential_85_mse: 0.0456 - sequential_86_mse: 0.0947 - sequential_87_mse: 0.0761 - sequential_88_mse: 0.0210 - sequential_89_mse: 0.0497 - sequential_90_mse: 0.0272 - sequential_91_mse: 0.0426 - sequential_92_mse: 0.0389 - sequential_93_mse: 0.0387 - sequential_94_mse: 0.0610 - sequential_95_mse: 0.0458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# k: 12 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step - loss: 104.6974 - sequential_80_mse: 0.0617 - sequential_81_mse: 0.0664 - sequential_82_mse: 0.0452 - sequential_83_mse: 0.0517 - sequential_84_mse: 0.0273 - sequential_85_mse: 0.0413 - sequential_86_mse: 0.0952 - sequential_87_mse: 0.0860 - sequential_88_mse: 0.0285 - sequential_89_mse: 0.0457 - sequential_90_mse: 0.0306 - sequential_91_mse: 0.0368 - sequential_92_mse: 0.0279 - sequential_93_mse: 0.0355 - sequential_94_mse: 0.0507 - sequential_95_mse: 0.0423
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# k: 13 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 922ms/step - loss: 99.6806 - sequential_80_mse: 0.0534 - sequential_81_mse: 0.0639 - sequential_82_mse: 0.0503 - sequential_83_mse: 0.0549 - sequential_84_mse: 0.0214 - sequential_85_mse: 0.0415 - sequential_86_mse: 0.0924 - sequential_87_mse: 0.0879 - sequential_88_mse: 0.0236 - sequential_89_mse: 0.0569 - sequential_90_mse: 0.0290 - sequential_91_mse: 0.0331 - sequential_92_mse: 0.0218 - sequential_93_mse: 0.0392 - sequential_94_mse: 0.0567 - sequential_95_mse: 0.0388
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# k: 14 patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Test Loss no  0 : 25.01488548421402
# input_train : (38, 120, 47)
# output_train : (38, 16)
# input_val : (14, 120, 47)
# output_val : (14, 16)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 59s 522ms/step - loss: 191.5574 - sequential_100_mse: 0.0894 - sequential_101_mse: 0.0615 - sequential_102_mse: 0.1377 - sequential_103_mse: 0.1534 - sequential_104_mse: 0.0364 - sequential_105_mse: 0.0663 - sequential_106_mse: 0.0265 - sequential_107_mse: 0.1098 - sequential_108_mse: 0.1223 - sequential_109_mse: 0.0179 - sequential_110_mse: 0.0930 - sequential_111_mse: 0.0768 - sequential_96_mse: 0.1389 - sequential_97_mse: 0.2263 - sequential_98_mse: 0.0691 - sequential_99_mse: 0.1376
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# k: 0 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step - loss: 183.6727 - sequential_100_mse: 0.0587 - sequential_101_mse: 0.0630 - sequential_102_mse: 0.1338 - sequential_103_mse: 0.1447 - sequential_104_mse: 0.1352 - sequential_105_mse: 0.0712 - sequential_106_mse: 0.1180 - sequential_107_mse: 0.1700 - sequential_108_mse: 0.1351 - sequential_109_mse: 0.0661 - sequential_110_mse: 0.1332 - sequential_111_mse: 0.1260 - sequential_96_mse: 0.1260 - sequential_97_mse: 0.0668 - sequential_98_mse: 0.1069 - sequential_99_mse: 0.0994
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# k: 1 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step - loss: 175.3064 - sequential_100_mse: 0.0408 - sequential_101_mse: 0.0849 - sequential_102_mse: 0.1109 - sequential_103_mse: 0.1368 - sequential_104_mse: 0.0328 - sequential_105_mse: 0.0468 - sequential_106_mse: 0.0398 - sequential_107_mse: 0.0907 - sequential_108_mse: 0.0755 - sequential_109_mse: 0.0356 - sequential_110_mse: 0.0909 - sequential_111_mse: 0.0778 - sequential_96_mse: 0.0930 - sequential_97_mse: 0.0835 - sequential_98_mse: 0.0571 - sequential_99_mse: 0.0855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 2 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 902ms/step - loss: 167.7841 - sequential_100_mse: 0.0418 - sequential_101_mse: 0.0641 - sequential_102_mse: 0.1215 - sequential_103_mse: 0.0897 - sequential_104_mse: 0.0632 - sequential_105_mse: 0.0496 - sequential_106_mse: 0.0871 - sequential_107_mse: 0.0808 - sequential_108_mse: 0.0633 - sequential_109_mse: 0.0453 - sequential_110_mse: 0.0829 - sequential_111_mse: 0.0858 - sequential_96_mse: 0.0984 - sequential_97_mse: 0.0755 - sequential_98_mse: 0.0767 - sequential_99_mse: 0.1043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# k: 3 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 892ms/step - loss: 160.3744 - sequential_100_mse: 0.0369 - sequential_101_mse: 0.0541 - sequential_102_mse: 0.1035 - sequential_103_mse: 0.1090 - sequential_104_mse: 0.0436 - sequential_105_mse: 0.0458 - sequential_106_mse: 0.0641 - sequential_107_mse: 0.0986 - sequential_108_mse: 0.0855 - sequential_109_mse: 0.0330 - sequential_110_mse: 0.1189 - sequential_111_mse: 0.0960 - sequential_96_mse: 0.0752 - sequential_97_mse: 0.0561 - sequential_98_mse: 0.0524 - sequential_99_mse: 0.0874
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# k: 4 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step - loss: 153.0344 - sequential_100_mse: 0.0323 - sequential_101_mse: 0.0428 - sequential_102_mse: 0.0824 - sequential_103_mse: 0.1088 - sequential_104_mse: 0.0176 - sequential_105_mse: 0.0348 - sequential_106_mse: 0.0298 - sequential_107_mse: 0.0859 - sequential_108_mse: 0.0671 - sequential_109_mse: 0.0197 - sequential_110_mse: 0.0855 - sequential_111_mse: 0.0666 - sequential_96_mse: 0.0749 - sequential_97_mse: 0.0484 - sequential_98_mse: 0.0429 - sequential_99_mse: 0.0821
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 5 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step - loss: 146.2805 - sequential_100_mse: 0.0406 - sequential_101_mse: 0.0525 - sequential_102_mse: 0.0978 - sequential_103_mse: 0.1073 - sequential_104_mse: 0.0374 - sequential_105_mse: 0.0430 - sequential_106_mse: 0.0378 - sequential_107_mse: 0.0850 - sequential_108_mse: 0.0589 - sequential_109_mse: 0.0385 - sequential_110_mse: 0.0713 - sequential_111_mse: 0.0785 - sequential_96_mse: 0.0752 - sequential_97_mse: 0.0615 - sequential_98_mse: 0.0588 - sequential_99_mse: 0.0792
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# k: 6 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step - loss: 139.5723 - sequential_100_mse: 0.0289 - sequential_101_mse: 0.0395 - sequential_102_mse: 0.0831 - sequential_103_mse: 0.0909 - sequential_104_mse: 0.0355 - sequential_105_mse: 0.0504 - sequential_106_mse: 0.0472 - sequential_107_mse: 0.0710 - sequential_108_mse: 0.0586 - sequential_109_mse: 0.0332 - sequential_110_mse: 0.0780 - sequential_111_mse: 0.0735 - sequential_96_mse: 0.0641 - sequential_97_mse: 0.0522 - sequential_98_mse: 0.0485 - sequential_99_mse: 0.0705
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# k: 7 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step - loss: 133.2050 - sequential_100_mse: 0.0317 - sequential_101_mse: 0.0449 - sequential_102_mse: 0.0868 - sequential_103_mse: 0.0921 - sequential_104_mse: 0.0326 - sequential_105_mse: 0.0399 - sequential_106_mse: 0.0459 - sequential_107_mse: 0.0653 - sequential_108_mse: 0.0504 - sequential_109_mse: 0.0269 - sequential_110_mse: 0.0878 - sequential_111_mse: 0.0833 - sequential_96_mse: 0.0678 - sequential_97_mse: 0.0579 - sequential_98_mse: 0.0389 - sequential_99_mse: 0.0782
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# k: 8 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step - loss: 127.0665 - sequential_100_mse: 0.0359 - sequential_101_mse: 0.0386 - sequential_102_mse: 0.0825 - sequential_103_mse: 0.0914 - sequential_104_mse: 0.0293 - sequential_105_mse: 0.0448 - sequential_106_mse: 0.0370 - sequential_107_mse: 0.0863 - sequential_108_mse: 0.0453 - sequential_109_mse: 0.0270 - sequential_110_mse: 0.0756 - sequential_111_mse: 0.0820 - sequential_96_mse: 0.0640 - sequential_97_mse: 0.0621 - sequential_98_mse: 0.0444 - sequential_99_mse: 0.0824
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# k: 9 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - loss: 121.1149 - sequential_100_mse: 0.0362 - sequential_101_mse: 0.0363 - sequential_102_mse: 0.0671 - sequential_103_mse: 0.0797 - sequential_104_mse: 0.0295 - sequential_105_mse: 0.0372 - sequential_106_mse: 0.0393 - sequential_107_mse: 0.0770 - sequential_108_mse: 0.0495 - sequential_109_mse: 0.0285 - sequential_110_mse: 0.0775 - sequential_111_mse: 0.0754 - sequential_96_mse: 0.0743 - sequential_97_mse: 0.0560 - sequential_98_mse: 0.0530 - sequential_99_mse: 0.0620
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# k: 10 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 860ms/step - loss: 115.4322 - sequential_100_mse: 0.0326 - sequential_101_mse: 0.0409 - sequential_102_mse: 0.0649 - sequential_103_mse: 0.0908 - sequential_104_mse: 0.0331 - sequential_105_mse: 0.0344 - sequential_106_mse: 0.0414 - sequential_107_mse: 0.0702 - sequential_108_mse: 0.0449 - sequential_109_mse: 0.0224 - sequential_110_mse: 0.0671 - sequential_111_mse: 0.0776 - sequential_96_mse: 0.0748 - sequential_97_mse: 0.0555 - sequential_98_mse: 0.0484 - sequential_99_mse: 0.0679
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# k: 11 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 556ms/step - loss: 109.9316 - sequential_100_mse: 0.0325 - sequential_101_mse: 0.0378 - sequential_102_mse: 0.0499 - sequential_103_mse: 0.0940 - sequential_104_mse: 0.0262 - sequential_105_mse: 0.0381 - sequential_106_mse: 0.0463 - sequential_107_mse: 0.0672 - sequential_108_mse: 0.0450 - sequential_109_mse: 0.0286 - sequential_110_mse: 0.0635 - sequential_111_mse: 0.0733 - sequential_96_mse: 0.0594 - sequential_97_mse: 0.0537 - sequential_98_mse: 0.0358 - sequential_99_mse: 0.0595
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# k: 12 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step - loss: 104.7620 - sequential_100_mse: 0.0387 - sequential_101_mse: 0.0450 - sequential_102_mse: 0.0635 - sequential_103_mse: 0.0996 - sequential_104_mse: 0.0246 - sequential_105_mse: 0.0452 - sequential_106_mse: 0.0431 - sequential_107_mse: 0.0700 - sequential_108_mse: 0.0464 - sequential_109_mse: 0.0295 - sequential_110_mse: 0.0811 - sequential_111_mse: 0.0676 - sequential_96_mse: 0.0683 - sequential_97_mse: 0.0523 - sequential_98_mse: 0.0436 - sequential_99_mse: 0.0458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# k: 13 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - loss: 99.6778 - sequential_100_mse: 0.0394 - sequential_101_mse: 0.0384 - sequential_102_mse: 0.0436 - sequential_103_mse: 0.0795 - sequential_104_mse: 0.0226 - sequential_105_mse: 0.0436 - sequential_106_mse: 0.0402 - sequential_107_mse: 0.0660 - sequential_108_mse: 0.0516 - sequential_109_mse: 0.0246 - sequential_110_mse: 0.0663 - sequential_111_mse: 0.0629 - sequential_96_mse: 0.0559 - sequential_97_mse: 0.0533 - sequential_98_mse: 0.0421 - sequential_99_mse: 0.0571
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# k: 14 patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Test Loss no  1 : 26.057208636902818
# input_train : (38, 120, 47)
# output_train : (38, 16)
# input_val : (14, 120, 47)
# output_val : (14, 16)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 55s 540ms/step - loss: 191.9432 - sequential_112_mse: 0.2336 - sequential_113_mse: 0.1054 - sequential_114_mse: 0.0208 - sequential_115_mse: 0.1907 - sequential_116_mse: 0.0696 - sequential_117_mse: 0.0939 - sequential_118_mse: 0.2758 - sequential_119_mse: 0.2742 - sequential_120_mse: 0.0527 - sequential_121_mse: 0.0666 - sequential_122_mse: 0.0536 - sequential_123_mse: 0.0882 - sequential_124_mse: 0.0836 - sequential_125_mse: 0.0345 - sequential_126_mse: 0.1685 - sequential_127_mse: 0.1042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# k: 0 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step - loss: 183.2137 - sequential_112_mse: 0.1041 - sequential_113_mse: 0.0817 - sequential_114_mse: 0.0178 - sequential_115_mse: 0.0946 - sequential_116_mse: 0.0636 - sequential_117_mse: 0.0768 - sequential_118_mse: 0.1333 - sequential_119_mse: 0.1275 - sequential_120_mse: 0.0308 - sequential_121_mse: 0.0442 - sequential_122_mse: 0.0728 - sequential_123_mse: 0.1084 - sequential_124_mse: 0.0539 - sequential_125_mse: 0.0603 - sequential_126_mse: 0.0985 - sequential_127_mse: 0.0760
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# k: 1 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 898ms/step - loss: 175.3238 - sequential_112_mse: 0.1094 - sequential_113_mse: 0.0607 - sequential_114_mse: 0.0330 - sequential_115_mse: 0.0861 - sequential_116_mse: 0.0483 - sequential_117_mse: 0.0645 - sequential_118_mse: 0.1257 - sequential_119_mse: 0.1256 - sequential_120_mse: 0.0509 - sequential_121_mse: 0.0591 - sequential_122_mse: 0.0385 - sequential_123_mse: 0.0823 - sequential_124_mse: 0.0584 - sequential_125_mse: 0.0545 - sequential_126_mse: 0.0976 - sequential_127_mse: 0.0710
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# k: 2 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 947ms/step - loss: 167.6624 - sequential_112_mse: 0.1148 - sequential_113_mse: 0.0598 - sequential_114_mse: 0.0141 - sequential_115_mse: 0.0701 - sequential_116_mse: 0.0500 - sequential_117_mse: 0.0677 - sequential_118_mse: 0.1119 - sequential_119_mse: 0.1025 - sequential_120_mse: 0.0330 - sequential_121_mse: 0.0400 - sequential_122_mse: 0.0512 - sequential_123_mse: 0.0815 - sequential_124_mse: 0.0514 - sequential_125_mse: 0.0523 - sequential_126_mse: 0.0935 - sequential_127_mse: 0.0878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# k: 3 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step - loss: 160.2657 - sequential_112_mse: 0.0810 - sequential_113_mse: 0.0648 - sequential_114_mse: 0.0101 - sequential_115_mse: 0.0943 - sequential_116_mse: 0.0563 - sequential_117_mse: 0.0571 - sequential_118_mse: 0.1107 - sequential_119_mse: 0.1041 - sequential_120_mse: 0.0442 - sequential_121_mse: 0.0403 - sequential_122_mse: 0.0395 - sequential_123_mse: 0.0851 - sequential_124_mse: 0.0483 - sequential_125_mse: 0.0343 - sequential_126_mse: 0.0761 - sequential_127_mse: 0.0815
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# k: 4 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - loss: 153.1824 - sequential_112_mse: 0.0996 - sequential_113_mse: 0.0608 - sequential_114_mse: 0.0130 - sequential_115_mse: 0.0821 - sequential_116_mse: 0.0415 - sequential_117_mse: 0.0696 - sequential_118_mse: 0.1183 - sequential_119_mse: 0.1054 - sequential_120_mse: 0.0383 - sequential_121_mse: 0.0373 - sequential_122_mse: 0.0363 - sequential_123_mse: 0.0718 - sequential_124_mse: 0.0467 - sequential_125_mse: 0.0391 - sequential_126_mse: 0.1085 - sequential_127_mse: 0.0748
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# k: 5 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - loss: 146.2869 - sequential_112_mse: 0.0907 - sequential_113_mse: 0.0538 - sequential_114_mse: 0.0126 - sequential_115_mse: 0.0800 - sequential_116_mse: 0.0433 - sequential_117_mse: 0.0647 - sequential_118_mse: 0.1019 - sequential_119_mse: 0.0978 - sequential_120_mse: 0.0410 - sequential_121_mse: 0.0321 - sequential_122_mse: 0.0406 - sequential_123_mse: 0.0690 - sequential_124_mse: 0.0520 - sequential_125_mse: 0.0544 - sequential_126_mse: 0.1089 - sequential_127_mse: 0.0591
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# k: 6 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - loss: 139.6059 - sequential_112_mse: 0.1037 - sequential_113_mse: 0.0462 - sequential_114_mse: 0.0082 - sequential_115_mse: 0.0677 - sequential_116_mse: 0.0434 - sequential_117_mse: 0.0593 - sequential_118_mse: 0.1001 - sequential_119_mse: 0.0827 - sequential_120_mse: 0.0374 - sequential_121_mse: 0.0377 - sequential_122_mse: 0.0477 - sequential_123_mse: 0.0672 - sequential_124_mse: 0.0522 - sequential_125_mse: 0.0367 - sequential_126_mse: 0.0833 - sequential_127_mse: 0.0603
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# k: 7 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step - loss: 133.2203 - sequential_112_mse: 0.0915 - sequential_113_mse: 0.0529 - sequential_114_mse: 0.0109 - sequential_115_mse: 0.0610 - sequential_116_mse: 0.0428 - sequential_117_mse: 0.0753 - sequential_118_mse: 0.0970 - sequential_119_mse: 0.0873 - sequential_120_mse: 0.0278 - sequential_121_mse: 0.0307 - sequential_122_mse: 0.0360 - sequential_123_mse: 0.0776 - sequential_124_mse: 0.0426 - sequential_125_mse: 0.0344 - sequential_126_mse: 0.0864 - sequential_127_mse: 0.0683
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# k: 8 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - loss: 127.0437 - sequential_112_mse: 0.0803 - sequential_113_mse: 0.0505 - sequential_114_mse: 0.0092 - sequential_115_mse: 0.0662 - sequential_116_mse: 0.0436 - sequential_117_mse: 0.0664 - sequential_118_mse: 0.1104 - sequential_119_mse: 0.0830 - sequential_120_mse: 0.0299 - sequential_121_mse: 0.0288 - sequential_122_mse: 0.0281 - sequential_123_mse: 0.0522 - sequential_124_mse: 0.0394 - sequential_125_mse: 0.0372 - sequential_126_mse: 0.0971 - sequential_127_mse: 0.0610
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# k: 9 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 877ms/step - loss: 121.1392 - sequential_112_mse: 0.0708 - sequential_113_mse: 0.0493 - sequential_114_mse: 0.0084 - sequential_115_mse: 0.0806 - sequential_116_mse: 0.0427 - sequential_117_mse: 0.0624 - sequential_118_mse: 0.1016 - sequential_119_mse: 0.0828 - sequential_120_mse: 0.0289 - sequential_121_mse: 0.0301 - sequential_122_mse: 0.0459 - sequential_123_mse: 0.0670 - sequential_124_mse: 0.0395 - sequential_125_mse: 0.0314 - sequential_126_mse: 0.0899 - sequential_127_mse: 0.0482
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# k: 10 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 830ms/step - loss: 115.4028 - sequential_112_mse: 0.0658 - sequential_113_mse: 0.0537 - sequential_114_mse: 0.0070 - sequential_115_mse: 0.0632 - sequential_116_mse: 0.0419 - sequential_117_mse: 0.0614 - sequential_118_mse: 0.0891 - sequential_119_mse: 0.0846 - sequential_120_mse: 0.0264 - sequential_121_mse: 0.0279 - sequential_122_mse: 0.0332 - sequential_123_mse: 0.0694 - sequential_124_mse: 0.0390 - sequential_125_mse: 0.0248 - sequential_126_mse: 0.0712 - sequential_127_mse: 0.0535
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# k: 11 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step - loss: 109.9874 - sequential_112_mse: 0.0923 - sequential_113_mse: 0.0499 - sequential_114_mse: 0.0068 - sequential_115_mse: 0.0538 - sequential_116_mse: 0.0299 - sequential_117_mse: 0.0642 - sequential_118_mse: 0.0881 - sequential_119_mse: 0.0843 - sequential_120_mse: 0.0301 - sequential_121_mse: 0.0264 - sequential_122_mse: 0.0320 - sequential_123_mse: 0.0724 - sequential_124_mse: 0.0369 - sequential_125_mse: 0.0386 - sequential_126_mse: 0.0785 - sequential_127_mse: 0.0522
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# k: 12 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step - loss: 104.7200 - sequential_112_mse: 0.0776 - sequential_113_mse: 0.0414 - sequential_114_mse: 0.0061 - sequential_115_mse: 0.0636 - sequential_116_mse: 0.0364 - sequential_117_mse: 0.0624 - sequential_118_mse: 0.0858 - sequential_119_mse: 0.0688 - sequential_120_mse: 0.0286 - sequential_121_mse: 0.0187 - sequential_122_mse: 0.0352 - sequential_123_mse: 0.0584 - sequential_124_mse: 0.0366 - sequential_125_mse: 0.0333 - sequential_126_mse: 0.0781 - sequential_127_mse: 0.0535
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# k: 13 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step - loss: 99.6537 - sequential_112_mse: 0.0645 - sequential_113_mse: 0.0435 - sequential_114_mse: 0.0059 - sequential_115_mse: 0.0451 - sequential_116_mse: 0.0369 - sequential_117_mse: 0.0480 - sequential_118_mse: 0.0766 - sequential_119_mse: 0.0715 - sequential_120_mse: 0.0265 - sequential_121_mse: 0.0162 - sequential_122_mse: 0.0347 - sequential_123_mse: 0.0733 - sequential_124_mse: 0.0380 - sequential_125_mse: 0.0237 - sequential_126_mse: 0.0677 - sequential_127_mse: 0.0448
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# k: 14 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - loss: 94.8521 - sequential_112_mse: 0.0786 - sequential_113_mse: 0.0521 - sequential_114_mse: 0.0060 - sequential_115_mse: 0.0497 - sequential_116_mse: 0.0399 - sequential_117_mse: 0.0514 - sequential_118_mse: 0.0764 - sequential_119_mse: 0.0576 - sequential_120_mse: 0.0218 - sequential_121_mse: 0.0225 - sequential_122_mse: 0.0253 - sequential_123_mse: 0.0508 - sequential_124_mse: 0.0288 - sequential_125_mse: 0.0289 - sequential_126_mse: 0.0684 - sequential_127_mse: 0.0452
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# k: 15 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step - loss: 90.2668 - sequential_112_mse: 0.0620 - sequential_113_mse: 0.0420 - sequential_114_mse: 0.0064 - sequential_115_mse: 0.0536 - sequential_116_mse: 0.0355 - sequential_117_mse: 0.0636 - sequential_118_mse: 0.0792 - sequential_119_mse: 0.0659 - sequential_120_mse: 0.0275 - sequential_121_mse: 0.0210 - sequential_122_mse: 0.0260 - sequential_123_mse: 0.0552 - sequential_124_mse: 0.0238 - sequential_125_mse: 0.0257 - sequential_126_mse: 0.0651 - sequential_127_mse: 0.0459
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# k: 16 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 907ms/step - loss: 85.8807 - sequential_112_mse: 0.0697 - sequential_113_mse: 0.0482 - sequential_114_mse: 0.0057 - sequential_115_mse: 0.0507 - sequential_116_mse: 0.0354 - sequential_117_mse: 0.0469 - sequential_118_mse: 0.0689 - sequential_119_mse: 0.0593 - sequential_120_mse: 0.0227 - sequential_121_mse: 0.0251 - sequential_122_mse: 0.0308 - sequential_123_mse: 0.0475 - sequential_124_mse: 0.0280 - sequential_125_mse: 0.0279 - sequential_126_mse: 0.0603 - sequential_127_mse: 0.0661
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# k: 17 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 871ms/step - loss: 81.7129 - sequential_112_mse: 0.0601 - sequential_113_mse: 0.0440 - sequential_114_mse: 0.0063 - sequential_115_mse: 0.0567 - sequential_116_mse: 0.0456 - sequential_117_mse: 0.0608 - sequential_118_mse: 0.0808 - sequential_119_mse: 0.0734 - sequential_120_mse: 0.0221 - sequential_121_mse: 0.0137 - sequential_122_mse: 0.0307 - sequential_123_mse: 0.0557 - sequential_124_mse: 0.0284 - sequential_125_mse: 0.0270 - sequential_126_mse: 0.0676 - sequential_127_mse: 0.0419
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# k: 18 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - loss: 77.6477 - sequential_112_mse: 0.0589 - sequential_113_mse: 0.0352 - sequential_114_mse: 0.0065 - sequential_115_mse: 0.0441 - sequential_116_mse: 0.0387 - sequential_117_mse: 0.0616 - sequential_118_mse: 0.0762 - sequential_119_mse: 0.0593 - sequential_120_mse: 0.0187 - sequential_121_mse: 0.0194 - sequential_122_mse: 0.0305 - sequential_123_mse: 0.0395 - sequential_124_mse: 0.0207 - sequential_125_mse: 0.0275 - sequential_126_mse: 0.0571 - sequential_127_mse: 0.0600
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# k: 19 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step - loss: 73.7911 - sequential_112_mse: 0.0544 - sequential_113_mse: 0.0380 - sequential_114_mse: 0.0052 - sequential_115_mse: 0.0399 - sequential_116_mse: 0.0312 - sequential_117_mse: 0.0496 - sequential_118_mse: 0.0673 - sequential_119_mse: 0.0733 - sequential_120_mse: 0.0208 - sequential_121_mse: 0.0275 - sequential_122_mse: 0.0212 - sequential_123_mse: 0.0479 - sequential_124_mse: 0.0285 - sequential_125_mse: 0.0232 - sequential_126_mse: 0.0554 - sequential_127_mse: 0.0374
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# k: 20 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - loss: 70.0955 - sequential_112_mse: 0.0475 - sequential_113_mse: 0.0360 - sequential_114_mse: 0.0038 - sequential_115_mse: 0.0457 - sequential_116_mse: 0.0330 - sequential_117_mse: 0.0482 - sequential_118_mse: 0.0650 - sequential_119_mse: 0.0522 - sequential_120_mse: 0.0161 - sequential_121_mse: 0.0147 - sequential_122_mse: 0.0192 - sequential_123_mse: 0.0502 - sequential_124_mse: 0.0198 - sequential_125_mse: 0.0160 - sequential_126_mse: 0.0578 - sequential_127_mse: 0.0487
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# k: 21 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - loss: 66.6520 - sequential_112_mse: 0.0480 - sequential_113_mse: 0.0420 - sequential_114_mse: 0.0066 - sequential_115_mse: 0.0346 - sequential_116_mse: 0.0347 - sequential_117_mse: 0.0734 - sequential_118_mse: 0.0489 - sequential_119_mse: 0.0622 - sequential_120_mse: 0.0204 - sequential_121_mse: 0.0151 - sequential_122_mse: 0.0254 - sequential_123_mse: 0.0407 - sequential_124_mse: 0.0185 - sequential_125_mse: 0.0289 - sequential_126_mse: 0.0572 - sequential_127_mse: 0.0538
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# k: 22 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step - loss: 63.3076 - sequential_112_mse: 0.0540 - sequential_113_mse: 0.0348 - sequential_114_mse: 0.0067 - sequential_115_mse: 0.0414 - sequential_116_mse: 0.0318 - sequential_117_mse: 0.0531 - sequential_118_mse: 0.0621 - sequential_119_mse: 0.0570 - sequential_120_mse: 0.0185 - sequential_121_mse: 0.0119 - sequential_122_mse: 0.0145 - sequential_123_mse: 0.0628 - sequential_124_mse: 0.0171 - sequential_125_mse: 0.0268 - sequential_126_mse: 0.0599 - sequential_127_mse: 0.0321
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 23 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 780ms/step - loss: 60.1210 - sequential_112_mse: 0.0412 - sequential_113_mse: 0.0369 - sequential_114_mse: 0.0060 - sequential_115_mse: 0.0479 - sequential_116_mse: 0.0374 - sequential_117_mse: 0.0525 - sequential_118_mse: 0.0464 - sequential_119_mse: 0.0553 - sequential_120_mse: 0.0189 - sequential_121_mse: 0.0130 - sequential_122_mse: 0.0248 - sequential_123_mse: 0.0398 - sequential_124_mse: 0.0165 - sequential_125_mse: 0.0283 - sequential_126_mse: 0.0579 - sequential_127_mse: 0.0391
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# k: 24 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 964ms/step - loss: 57.0841 - sequential_112_mse: 0.0393 - sequential_113_mse: 0.0359 - sequential_114_mse: 0.0054 - sequential_115_mse: 0.0368 - sequential_116_mse: 0.0319 - sequential_117_mse: 0.0565 - sequential_118_mse: 0.0542 - sequential_119_mse: 0.0439 - sequential_120_mse: 0.0197 - sequential_121_mse: 0.0115 - sequential_122_mse: 0.0167 - sequential_123_mse: 0.0523 - sequential_124_mse: 0.0220 - sequential_125_mse: 0.0280 - sequential_126_mse: 0.0560 - sequential_127_mse: 0.0313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# k: 25 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - loss: 54.2337 - sequential_112_mse: 0.0493 - sequential_113_mse: 0.0295 - sequential_114_mse: 0.0045 - sequential_115_mse: 0.0697 - sequential_116_mse: 0.0320 - sequential_117_mse: 0.0521 - sequential_118_mse: 0.0536 - sequential_119_mse: 0.0564 - sequential_120_mse: 0.0147 - sequential_121_mse: 0.0250 - sequential_122_mse: 0.0124 - sequential_123_mse: 0.0336 - sequential_124_mse: 0.0148 - sequential_125_mse: 0.0294 - sequential_126_mse: 0.0578 - sequential_127_mse: 0.0315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# k: 26 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - loss: 51.4680 - sequential_112_mse: 0.0521 - sequential_113_mse: 0.0348 - sequential_114_mse: 0.0053 - sequential_115_mse: 0.0350 - sequential_116_mse: 0.0365 - sequential_117_mse: 0.0514 - sequential_118_mse: 0.0475 - sequential_119_mse: 0.0417 - sequential_120_mse: 0.0181 - sequential_121_mse: 0.0206 - sequential_122_mse: 0.0254 - sequential_123_mse: 0.0413 - sequential_124_mse: 0.0258 - sequential_125_mse: 0.0228 - sequential_126_mse: 0.0509 - sequential_127_mse: 0.0308
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# k: 27 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - loss: 48.8263 - sequential_112_mse: 0.0441 - sequential_113_mse: 0.0317 - sequential_114_mse: 0.0062 - sequential_115_mse: 0.0548 - sequential_116_mse: 0.0263 - sequential_117_mse: 0.0514 - sequential_118_mse: 0.0374 - sequential_119_mse: 0.0477 - sequential_120_mse: 0.0120 - sequential_121_mse: 0.0190 - sequential_122_mse: 0.0118 - sequential_123_mse: 0.0579 - sequential_124_mse: 0.0141 - sequential_125_mse: 0.0215 - sequential_126_mse: 0.0532 - sequential_127_mse: 0.0177
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# k: 28 patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Test Loss no  2 : 27.97741278308284
# input_train : (38, 120, 47)
# output_train : (38, 16)
# input_val : (14, 120, 47)
# output_val : (14, 16)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 57s 509ms/step - loss: 191.6131 - sequential_128_mse: 0.1653 - sequential_129_mse: 0.0956 - sequential_130_mse: 0.0578 - sequential_131_mse: 0.1038 - sequential_132_mse: 0.0594 - sequential_133_mse: 0.0709 - sequential_134_mse: 0.1393 - sequential_135_mse: 0.2868 - sequential_136_mse: 0.0504 - sequential_137_mse: 0.0873 - sequential_138_mse: 0.0401 - sequential_139_mse: 0.1399 - sequential_140_mse: 0.0802 - sequential_141_mse: 0.0508 - sequential_142_mse: 0.1438 - sequential_143_mse: 0.0645
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# k: 0 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step - loss: 183.2773 - sequential_128_mse: 0.1083 - sequential_129_mse: 0.1034 - sequential_130_mse: 0.0478 - sequential_131_mse: 0.1061 - sequential_132_mse: 0.0920 - sequential_133_mse: 0.0870 - sequential_134_mse: 0.1131 - sequential_135_mse: 0.1057 - sequential_136_mse: 0.0425 - sequential_137_mse: 0.0679 - sequential_138_mse: 0.0462 - sequential_139_mse: 0.1269 - sequential_140_mse: 0.0635 - sequential_141_mse: 0.0630 - sequential_142_mse: 0.1176 - sequential_143_mse: 0.0593
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 1 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step - loss: 175.2305 - sequential_128_mse: 0.0996 - sequential_129_mse: 0.0455 - sequential_130_mse: 0.0434 - sequential_131_mse: 0.1189 - sequential_132_mse: 0.0505 - sequential_133_mse: 0.0597 - sequential_134_mse: 0.1005 - sequential_135_mse: 0.1108 - sequential_136_mse: 0.0462 - sequential_137_mse: 0.0447 - sequential_138_mse: 0.0509 - sequential_139_mse: 0.0940 - sequential_140_mse: 0.0472 - sequential_141_mse: 0.0300 - sequential_142_mse: 0.0893 - sequential_143_mse: 0.0717
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# k: 2 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - loss: 167.5419 - sequential_128_mse: 0.0798 - sequential_129_mse: 0.0593 - sequential_130_mse: 0.0314 - sequential_131_mse: 0.0944 - sequential_132_mse: 0.0369 - sequential_133_mse: 0.0705 - sequential_134_mse: 0.0930 - sequential_135_mse: 0.1026 - sequential_136_mse: 0.0677 - sequential_137_mse: 0.0478 - sequential_138_mse: 0.0375 - sequential_139_mse: 0.0908 - sequential_140_mse: 0.0344 - sequential_141_mse: 0.0196 - sequential_142_mse: 0.0865 - sequential_143_mse: 0.0297
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# k: 3 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - loss: 160.2116 - sequential_128_mse: 0.0863 - sequential_129_mse: 0.0450 - sequential_130_mse: 0.0406 - sequential_131_mse: 0.0879 - sequential_132_mse: 0.0447 - sequential_133_mse: 0.0557 - sequential_134_mse: 0.0953 - sequential_135_mse: 0.1023 - sequential_136_mse: 0.0368 - sequential_137_mse: 0.0516 - sequential_138_mse: 0.0254 - sequential_139_mse: 0.0867 - sequential_140_mse: 0.0455 - sequential_141_mse: 0.0316 - sequential_142_mse: 0.0847 - sequential_143_mse: 0.0563
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# k: 4 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - loss: 153.1372 - sequential_128_mse: 0.0766 - sequential_129_mse: 0.0488 - sequential_130_mse: 0.0338 - sequential_131_mse: 0.0953 - sequential_132_mse: 0.0493 - sequential_133_mse: 0.0697 - sequential_134_mse: 0.1229 - sequential_135_mse: 0.0903 - sequential_136_mse: 0.0392 - sequential_137_mse: 0.0438 - sequential_138_mse: 0.0474 - sequential_139_mse: 0.0771 - sequential_140_mse: 0.0445 - sequential_141_mse: 0.0239 - sequential_142_mse: 0.0912 - sequential_143_mse: 0.0364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 5 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - loss: 146.2655 - sequential_128_mse: 0.0841 - sequential_129_mse: 0.0574 - sequential_130_mse: 0.0348 - sequential_131_mse: 0.0763 - sequential_132_mse: 0.0516 - sequential_133_mse: 0.0597 - sequential_134_mse: 0.1011 - sequential_135_mse: 0.0956 - sequential_136_mse: 0.0404 - sequential_137_mse: 0.0400 - sequential_138_mse: 0.0358 - sequential_139_mse: 0.0980 - sequential_140_mse: 0.0409 - sequential_141_mse: 0.0323 - sequential_142_mse: 0.0879 - sequential_143_mse: 0.0350
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# k: 6 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 886ms/step - loss: 139.5766 - sequential_128_mse: 0.0723 - sequential_129_mse: 0.0348 - sequential_130_mse: 0.0352 - sequential_131_mse: 0.0685 - sequential_132_mse: 0.0457 - sequential_133_mse: 0.0573 - sequential_134_mse: 0.0833 - sequential_135_mse: 0.0778 - sequential_136_mse: 0.0439 - sequential_137_mse: 0.0525 - sequential_138_mse: 0.0370 - sequential_139_mse: 0.0931 - sequential_140_mse: 0.0465 - sequential_141_mse: 0.0325 - sequential_142_mse: 0.0815 - sequential_143_mse: 0.0343
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# k: 7 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 899ms/step - loss: 133.2009 - sequential_128_mse: 0.0699 - sequential_129_mse: 0.0467 - sequential_130_mse: 0.0364 - sequential_131_mse: 0.1006 - sequential_132_mse: 0.0512 - sequential_133_mse: 0.0539 - sequential_134_mse: 0.0945 - sequential_135_mse: 0.0802 - sequential_136_mse: 0.0316 - sequential_137_mse: 0.0387 - sequential_138_mse: 0.0289 - sequential_139_mse: 0.0800 - sequential_140_mse: 0.0315 - sequential_141_mse: 0.0274 - sequential_142_mse: 0.0786 - sequential_143_mse: 0.0451
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 8 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step - loss: 127.0340 - sequential_128_mse: 0.0595 - sequential_129_mse: 0.0544 - sequential_130_mse: 0.0370 - sequential_131_mse: 0.0889 - sequential_132_mse: 0.0479 - sequential_133_mse: 0.0501 - sequential_134_mse: 0.0868 - sequential_135_mse: 0.0762 - sequential_136_mse: 0.0361 - sequential_137_mse: 0.0305 - sequential_138_mse: 0.0310 - sequential_139_mse: 0.0844 - sequential_140_mse: 0.0390 - sequential_141_mse: 0.0270 - sequential_142_mse: 0.0777 - sequential_143_mse: 0.0386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# k: 9 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step - loss: 121.1198 - sequential_128_mse: 0.0637 - sequential_129_mse: 0.0480 - sequential_130_mse: 0.0342 - sequential_131_mse: 0.0540 - sequential_132_mse: 0.0431 - sequential_133_mse: 0.0580 - sequential_134_mse: 0.0861 - sequential_135_mse: 0.0859 - sequential_136_mse: 0.0346 - sequential_137_mse: 0.0414 - sequential_138_mse: 0.0329 - sequential_139_mse: 0.0893 - sequential_140_mse: 0.0419 - sequential_141_mse: 0.0265 - sequential_142_mse: 0.0779 - sequential_143_mse: 0.0359
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 10 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - loss: 115.3450 - sequential_128_mse: 0.0631 - sequential_129_mse: 0.0310 - sequential_130_mse: 0.0302 - sequential_131_mse: 0.0573 - sequential_132_mse: 0.0339 - sequential_133_mse: 0.0485 - sequential_134_mse: 0.0733 - sequential_135_mse: 0.0777 - sequential_136_mse: 0.0255 - sequential_137_mse: 0.0353 - sequential_138_mse: 0.0226 - sequential_139_mse: 0.0846 - sequential_140_mse: 0.0286 - sequential_141_mse: 0.0152 - sequential_142_mse: 0.0857 - sequential_143_mse: 0.0375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# k: 11 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step - loss: 109.9778 - sequential_128_mse: 0.0690 - sequential_129_mse: 0.0386 - sequential_130_mse: 0.0369 - sequential_131_mse: 0.0600 - sequential_132_mse: 0.0407 - sequential_133_mse: 0.0613 - sequential_134_mse: 0.0806 - sequential_135_mse: 0.0977 - sequential_136_mse: 0.0305 - sequential_137_mse: 0.0289 - sequential_138_mse: 0.0294 - sequential_139_mse: 0.0857 - sequential_140_mse: 0.0333 - sequential_141_mse: 0.0255 - sequential_142_mse: 0.0749 - sequential_143_mse: 0.0320
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 12 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - loss: 104.7207 - sequential_128_mse: 0.0692 - sequential_129_mse: 0.0368 - sequential_130_mse: 0.0304 - sequential_131_mse: 0.0597 - sequential_132_mse: 0.0364 - sequential_133_mse: 0.0597 - sequential_134_mse: 0.0743 - sequential_135_mse: 0.0720 - sequential_136_mse: 0.0257 - sequential_137_mse: 0.0338 - sequential_138_mse: 0.0257 - sequential_139_mse: 0.0855 - sequential_140_mse: 0.0320 - sequential_141_mse: 0.0268 - sequential_142_mse: 0.0829 - sequential_143_mse: 0.0359
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# k: 13 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 848ms/step - loss: 99.6485 - sequential_128_mse: 0.0515 - sequential_129_mse: 0.0312 - sequential_130_mse: 0.0320 - sequential_131_mse: 0.0459 - sequential_132_mse: 0.0363 - sequential_133_mse: 0.0520 - sequential_134_mse: 0.0691 - sequential_135_mse: 0.0725 - sequential_136_mse: 0.0274 - sequential_137_mse: 0.0320 - sequential_138_mse: 0.0242 - sequential_139_mse: 0.0811 - sequential_140_mse: 0.0396 - sequential_141_mse: 0.0220 - sequential_142_mse: 0.0685 - sequential_143_mse: 0.0329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# k: 14 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 963ms/step - loss: 94.8815 - sequential_128_mse: 0.0671 - sequential_129_mse: 0.0278 - sequential_130_mse: 0.0335 - sequential_131_mse: 0.0509 - sequential_132_mse: 0.0401 - sequential_133_mse: 0.0497 - sequential_134_mse: 0.0696 - sequential_135_mse: 0.0798 - sequential_136_mse: 0.0356 - sequential_137_mse: 0.0292 - sequential_138_mse: 0.0274 - sequential_139_mse: 0.0949 - sequential_140_mse: 0.0306 - sequential_141_mse: 0.0168 - sequential_142_mse: 0.0524 - sequential_143_mse: 0.0390
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# k: 15 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - loss: 90.2706 - sequential_128_mse: 0.0604 - sequential_129_mse: 0.0294 - sequential_130_mse: 0.0337 - sequential_131_mse: 0.0349 - sequential_132_mse: 0.0404 - sequential_133_mse: 0.0524 - sequential_134_mse: 0.0674 - sequential_135_mse: 0.0706 - sequential_136_mse: 0.0361 - sequential_137_mse: 0.0309 - sequential_138_mse: 0.0259 - sequential_139_mse: 0.0739 - sequential_140_mse: 0.0339 - sequential_141_mse: 0.0241 - sequential_142_mse: 0.0718 - sequential_143_mse: 0.0354
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# k: 16 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step - loss: 85.8145 - sequential_128_mse: 0.0472 - sequential_129_mse: 0.0263 - sequential_130_mse: 0.0235 - sequential_131_mse: 0.0364 - sequential_132_mse: 0.0350 - sequential_133_mse: 0.0455 - sequential_134_mse: 0.0577 - sequential_135_mse: 0.0685 - sequential_136_mse: 0.0320 - sequential_137_mse: 0.0289 - sequential_138_mse: 0.0273 - sequential_139_mse: 0.0713 - sequential_140_mse: 0.0327 - sequential_141_mse: 0.0211 - sequential_142_mse: 0.0651 - sequential_143_mse: 0.0363
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# k: 17 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step - loss: 81.6945 - sequential_128_mse: 0.0645 - sequential_129_mse: 0.0255 - sequential_130_mse: 0.0315 - sequential_131_mse: 0.0673 - sequential_132_mse: 0.0322 - sequential_133_mse: 0.0547 - sequential_134_mse: 0.0716 - sequential_135_mse: 0.0726 - sequential_136_mse: 0.0270 - sequential_137_mse: 0.0287 - sequential_138_mse: 0.0281 - sequential_139_mse: 0.0822 - sequential_140_mse: 0.0291 - sequential_141_mse: 0.0204 - sequential_142_mse: 0.0616 - sequential_143_mse: 0.0355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# k: 18 patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Test Loss no  3 : 28.54746512023864
# input_train : (38, 120, 47)
# output_train : (38, 16)
# input_val : (14, 120, 47)
# output_val : (14, 16)
# input_test : (16, 120, 47)
# output_test : (16, 16)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 61s 895ms/step - loss: 191.8044 - sequential_144_mse: 0.1064 - sequential_145_mse: 0.0303 - sequential_146_mse: 0.0458 - sequential_147_mse: 0.2087 - sequential_148_mse: 0.0821 - sequential_149_mse: 0.0806 - sequential_150_mse: 0.1047 - sequential_151_mse: 0.1894 - sequential_152_mse: 0.2335 - sequential_153_mse: 0.1132 - sequential_154_mse: 0.0829 - sequential_155_mse: 0.1116 - sequential_156_mse: 0.1024 - sequential_157_mse: 0.0996 - sequential_158_mse: 0.1138 - sequential_159_mse: 0.0615
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# k: 0 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - loss: 183.8527 - sequential_144_mse: 0.0904 - sequential_145_mse: 0.0805 - sequential_146_mse: 0.0176 - sequential_147_mse: 0.1629 - sequential_148_mse: 0.1028 - sequential_149_mse: 0.0871 - sequential_150_mse: 0.0871 - sequential_151_mse: 0.0924 - sequential_152_mse: 0.2558 - sequential_153_mse: 0.1553 - sequential_154_mse: 0.1681 - sequential_155_mse: 0.1302 - sequential_156_mse: 0.1373 - sequential_157_mse: 0.0914 - sequential_158_mse: 0.1347 - sequential_159_mse: 0.0860
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# k: 1 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step - loss: 175.7153 - sequential_144_mse: 0.0807 - sequential_145_mse: 0.0318 - sequential_146_mse: 0.0175 - sequential_147_mse: 0.2101 - sequential_148_mse: 0.0647 - sequential_149_mse: 0.0756 - sequential_150_mse: 0.0732 - sequential_151_mse: 0.1069 - sequential_152_mse: 0.2108 - sequential_153_mse: 0.1348 - sequential_154_mse: 0.1222 - sequential_155_mse: 0.0756 - sequential_156_mse: 0.1009 - sequential_157_mse: 0.0786 - sequential_158_mse: 0.0829 - sequential_159_mse: 0.0734
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# k: 2 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step - loss: 167.9996 - sequential_144_mse: 0.0808 - sequential_145_mse: 0.0319 - sequential_146_mse: 0.0211 - sequential_147_mse: 0.1060 - sequential_148_mse: 0.0841 - sequential_149_mse: 0.0722 - sequential_150_mse: 0.0809 - sequential_151_mse: 0.0972 - sequential_152_mse: 0.1823 - sequential_153_mse: 0.1192 - sequential_154_mse: 0.0893 - sequential_155_mse: 0.0894 - sequential_156_mse: 0.1073 - sequential_157_mse: 0.0853 - sequential_158_mse: 0.0783 - sequential_159_mse: 0.0689
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# k: 3 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - loss: 160.5155 - sequential_144_mse: 0.0732 - sequential_145_mse: 0.0240 - sequential_146_mse: 0.0068 - sequential_147_mse: 0.0942 - sequential_148_mse: 0.0693 - sequential_149_mse: 0.0729 - sequential_150_mse: 0.0667 - sequential_151_mse: 0.0936 - sequential_152_mse: 0.1834 - sequential_153_mse: 0.1090 - sequential_154_mse: 0.1035 - sequential_155_mse: 0.0960 - sequential_156_mse: 0.0655 - sequential_157_mse: 0.0662 - sequential_158_mse: 0.0701 - sequential_159_mse: 0.0523
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 4 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 891ms/step - loss: 153.4140 - sequential_144_mse: 0.0732 - sequential_145_mse: 0.0412 - sequential_146_mse: 0.0164 - sequential_147_mse: 0.0961 - sequential_148_mse: 0.0587 - sequential_149_mse: 0.0917 - sequential_150_mse: 0.0702 - sequential_151_mse: 0.0873 - sequential_152_mse: 0.1661 - sequential_153_mse: 0.1110 - sequential_154_mse: 0.0884 - sequential_155_mse: 0.0684 - sequential_156_mse: 0.0831 - sequential_157_mse: 0.0758 - sequential_158_mse: 0.0646 - sequential_159_mse: 0.0517
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# k: 5 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 968ms/step - loss: 146.4753 - sequential_144_mse: 0.0651 - sequential_145_mse: 0.0244 - sequential_146_mse: 0.0141 - sequential_147_mse: 0.1034 - sequential_148_mse: 0.0782 - sequential_149_mse: 0.0596 - sequential_150_mse: 0.0755 - sequential_151_mse: 0.0699 - sequential_152_mse: 0.1559 - sequential_153_mse: 0.1044 - sequential_154_mse: 0.0689 - sequential_155_mse: 0.0821 - sequential_156_mse: 0.0783 - sequential_157_mse: 0.0554 - sequential_158_mse: 0.0701 - sequential_159_mse: 0.0568
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 6 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - loss: 139.8070 - sequential_144_mse: 0.0619 - sequential_145_mse: 0.0241 - sequential_146_mse: 0.0094 - sequential_147_mse: 0.0933 - sequential_148_mse: 0.0676 - sequential_149_mse: 0.0601 - sequential_150_mse: 0.0742 - sequential_151_mse: 0.0732 - sequential_152_mse: 0.1369 - sequential_153_mse: 0.1111 - sequential_154_mse: 0.0698 - sequential_155_mse: 0.0764 - sequential_156_mse: 0.0631 - sequential_157_mse: 0.0559 - sequential_158_mse: 0.0680 - sequential_159_mse: 0.0581
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# k: 7 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step - loss: 133.4395 - sequential_144_mse: 0.0533 - sequential_145_mse: 0.0169 - sequential_146_mse: 0.0099 - sequential_147_mse: 0.0880 - sequential_148_mse: 0.0677 - sequential_149_mse: 0.0623 - sequential_150_mse: 0.0691 - sequential_151_mse: 0.0772 - sequential_152_mse: 0.1615 - sequential_153_mse: 0.1074 - sequential_154_mse: 0.0744 - sequential_155_mse: 0.0719 - sequential_156_mse: 0.0651 - sequential_157_mse: 0.0565 - sequential_158_mse: 0.0595 - sequential_159_mse: 0.0597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# k: 8 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - loss: 127.2912 - sequential_144_mse: 0.0389 - sequential_145_mse: 0.0287 - sequential_146_mse: 0.0146 - sequential_147_mse: 0.0810 - sequential_148_mse: 0.0548 - sequential_149_mse: 0.0713 - sequential_150_mse: 0.0672 - sequential_151_mse: 0.0781 - sequential_152_mse: 0.1579 - sequential_153_mse: 0.1075 - sequential_154_mse: 0.0774 - sequential_155_mse: 0.0701 - sequential_156_mse: 0.0527 - sequential_157_mse: 0.0751 - sequential_158_mse: 0.0535 - sequential_159_mse: 0.0476
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# k: 9 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - loss: 121.3571 - sequential_144_mse: 0.0479 - sequential_145_mse: 0.0225 - sequential_146_mse: 0.0152 - sequential_147_mse: 0.0736 - sequential_148_mse: 0.0586 - sequential_149_mse: 0.0626 - sequential_150_mse: 0.0571 - sequential_151_mse: 0.0707 - sequential_152_mse: 0.1526 - sequential_153_mse: 0.1076 - sequential_154_mse: 0.0677 - sequential_155_mse: 0.0666 - sequential_156_mse: 0.0573 - sequential_157_mse: 0.0713 - sequential_158_mse: 0.0532 - sequential_159_mse: 0.0458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# k: 10 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step - loss: 115.6746 - sequential_144_mse: 0.0498 - sequential_145_mse: 0.0255 - sequential_146_mse: 0.0097 - sequential_147_mse: 0.0796 - sequential_148_mse: 0.0522 - sequential_149_mse: 0.0515 - sequential_150_mse: 0.0724 - sequential_151_mse: 0.0645 - sequential_152_mse: 0.1384 - sequential_153_mse: 0.1106 - sequential_154_mse: 0.0793 - sequential_155_mse: 0.0613 - sequential_156_mse: 0.0534 - sequential_157_mse: 0.0603 - sequential_158_mse: 0.0458 - sequential_159_mse: 0.0475
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# k: 11 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - loss: 110.2288 - sequential_144_mse: 0.0404 - sequential_145_mse: 0.0228 - sequential_146_mse: 0.0055 - sequential_147_mse: 0.0774 - sequential_148_mse: 0.0542 - sequential_149_mse: 0.0547 - sequential_150_mse: 0.0551 - sequential_151_mse: 0.0821 - sequential_152_mse: 0.1402 - sequential_153_mse: 0.1005 - sequential_154_mse: 0.0674 - sequential_155_mse: 0.0675 - sequential_156_mse: 0.0570 - sequential_157_mse: 0.0702 - sequential_158_mse: 0.0479 - sequential_159_mse: 0.0386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# k: 12 patience: 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 957ms/step - loss: 105.0263 - sequential_144_mse: 0.0326 - sequential_145_mse: 0.0283 - sequential_146_mse: 0.0083 - sequential_147_mse: 0.0650 - sequential_148_mse: 0.0524 - sequential_149_mse: 0.0639 - sequential_150_mse: 0.0462 - sequential_151_mse: 0.0831 - sequential_152_mse: 0.1313 - sequential_153_mse: 0.0941 - sequential_154_mse: 0.0793 - sequential_155_mse: 0.0708 - sequential_156_mse: 0.0523 - sequential_157_mse: 0.0779 - sequential_158_mse: 0.0443 - sequential_159_mse: 0.0433
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# k: 13 patience: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 949ms/step - loss: 100.0875 - sequential_144_mse: 0.0349 - sequential_145_mse: 0.0223 - sequential_146_mse: 0.0076 - sequential_147_mse: 0.0764 - sequential_148_mse: 0.0630 - sequential_149_mse: 0.0471 - sequential_150_mse: 0.0805 - sequential_151_mse: 0.0693 - sequential_152_mse: 0.1343 - sequential_153_mse: 0.1045 - sequential_154_mse: 0.0729 - sequential_155_mse: 0.0653 - sequential_156_mse: 0.0587 - sequential_157_mse: 0.0618 - sequential_158_mse: 0.0518 - sequential_159_mse: 0.0536
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 14 patience: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - loss: 95.1830 - sequential_144_mse: 0.0263 - sequential_145_mse: 0.0161 - sequential_146_mse: 0.0064 - sequential_147_mse: 0.0660 - sequential_148_mse: 0.0560 - sequential_149_mse: 0.0552 - sequential_150_mse: 0.0729 - sequential_151_mse: 0.0556 - sequential_152_mse: 0.1109 - sequential_153_mse: 0.0954 - sequential_154_mse: 0.0652 - sequential_155_mse: 0.0604 - sequential_156_mse: 0.0443 - sequential_157_mse: 0.0441 - sequential_158_mse: 0.0465 - sequential_159_mse: 0.0379
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# k: 15 patience: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step - loss: 90.6062 - sequential_144_mse: 0.0335 - sequential_145_mse: 0.0167 - sequential_146_mse: 0.0051 - sequential_147_mse: 0.0686 - sequential_148_mse: 0.0444 - sequential_149_mse: 0.0409 - sequential_150_mse: 0.0462 - sequential_151_mse: 0.0568 - sequential_152_mse: 0.1260 - sequential_153_mse: 0.0900 - sequential_154_mse: 0.0657 - sequential_155_mse: 0.0538 - sequential_156_mse: 0.0573 - sequential_157_mse: 0.0524 - sequential_158_mse: 0.0455 - sequential_159_mse: 0.0353
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# k: 16 patience: 4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step - loss: 86.2706 - sequential_144_mse: 0.0299 - sequential_145_mse: 0.0166 - sequential_146_mse: 0.0057 - sequential_147_mse: 0.0649 - sequential_148_mse: 0.0425 - sequential_149_mse: 0.0326 - sequential_150_mse: 0.0510 - sequential_151_mse: 0.0582 - sequential_152_mse: 0.1445 - sequential_153_mse: 0.0927 - sequential_154_mse: 0.0560 - sequential_155_mse: 0.0617 - sequential_156_mse: 0.0500 - sequential_157_mse: 0.0525 - sequential_158_mse: 0.0487 - sequential_159_mse: 0.0547
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# k: 17 patience: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - loss: 82.0660 - sequential_144_mse: 0.0322 - sequential_145_mse: 0.0192 - sequential_146_mse: 0.0064 - sequential_147_mse: 0.0643 - sequential_148_mse: 0.0455 - sequential_149_mse: 0.0325 - sequential_150_mse: 0.0387 - sequential_151_mse: 0.0559 - sequential_152_mse: 0.1410 - sequential_153_mse: 0.0966 - sequential_154_mse: 0.0569 - sequential_155_mse: 0.0626 - sequential_156_mse: 0.0453 - sequential_157_mse: 0.0474 - sequential_158_mse: 0.0419 - sequential_159_mse: 0.0403
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# k: 18 patience: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step - loss: 78.0256 - sequential_144_mse: 0.0223 - sequential_145_mse: 0.0159 - sequential_146_mse: 0.0068 - sequential_147_mse: 0.0637 - sequential_148_mse: 0.0448 - sequential_149_mse: 0.0384 - sequential_150_mse: 0.0448 - sequential_151_mse: 0.0492 - sequential_152_mse: 0.1093 - sequential_153_mse: 0.0986 - sequential_154_mse: 0.0516 - sequential_155_mse: 0.0588 - sequential_156_mse: 0.0423 - sequential_157_mse: 0.0541 - sequential_158_mse: 0.0430 - sequential_159_mse: 0.0267
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# k: 19 patience: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 857ms/step - loss: 74.2863 - sequential_144_mse: 0.0245 - sequential_145_mse: 0.0142 - sequential_146_mse: 0.0064 - sequential_147_mse: 0.0617 - sequential_148_mse: 0.0449 - sequential_149_mse: 0.0359 - sequential_150_mse: 0.0487 - sequential_151_mse: 0.0490 - sequential_152_mse: 0.1206 - sequential_153_mse: 0.0985 - sequential_154_mse: 0.0557 - sequential_155_mse: 0.0897 - sequential_156_mse: 0.0347 - sequential_157_mse: 0.0568 - sequential_158_mse: 0.0505 - sequential_159_mse: 0.0459
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# k: 20 patience: 8
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 520ms/step - loss: 70.5538 - sequential_144_mse: 0.0180 - sequential_145_mse: 0.0168 - sequential_146_mse: 0.0030 - sequential_147_mse: 0.0523 - sequential_148_mse: 0.0472 - sequential_149_mse: 0.0381 - sequential_150_mse: 0.0375 - sequential_151_mse: 0.0449 - sequential_152_mse: 0.1015 - sequential_153_mse: 0.0908 - sequential_154_mse: 0.0542 - sequential_155_mse: 0.0750 - sequential_156_mse: 0.0403 - sequential_157_mse: 0.0533 - sequential_158_mse: 0.0312 - sequential_159_mse: 0.0364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# k: 21 patience: 9
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step - loss: 67.0926 - sequential_144_mse: 0.0363 - sequential_145_mse: 0.0170 - sequential_146_mse: 0.0061 - sequential_147_mse: 0.0559 - sequential_148_mse: 0.0371 - sequential_149_mse: 0.0316 - sequential_150_mse: 0.0393 - sequential_151_mse: 0.0714 - sequential_152_mse: 0.1084 - sequential_153_mse: 0.0931 - sequential_154_mse: 0.0493 - sequential_155_mse: 0.0518 - sequential_156_mse: 0.0354 - sequential_157_mse: 0.0381 - sequential_158_mse: 0.0463 - sequential_159_mse: 0.0316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# k: 22 patience: 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Test Loss no  4 : 43.04925083897582
# average_loss: 30.12924457268283
